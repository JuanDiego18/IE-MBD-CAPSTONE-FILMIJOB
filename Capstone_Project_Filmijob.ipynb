# %% [markdown]
# # Filmijob Capstone Project: Interview Question Scoring

# %%
import pandas as pd
import re

# %% [markdown]
# ## 1. EDA (Exploratory Data Analysis)

# %% [markdown]
# ### 1.1 Importing the Dataset and checking the data

# %%
df=pd.read_csv("Dataset.csv")
df
# Out:
#                            title  \
# 0          Collection Specialist
# 1                Billing Analyst
# 2                 Tax Accountant
# 3    Accounts Receivable Manager
# 4                Cost Accountant
# ..                           ...
# 278                Sales Advisor
# 279                 Retail Buyer
# 280             Category Manager
# 281                 Merchandiser
# 282                Store Manager
#
#                                        job description  \
# 0    <h4>Job brief</h4><p>We are looking for a comp...
# 1    <h4>Job brief</h4><p>We are looking for a Bill...
# 2    <h4>Job brief</h4><p>We are looking for a Tax ...
# 3    <h4>Job brief</h4><p>We are looking for an Acc...
# 4    <h4>Job brief</h4><p>We are looking for a Cost...
# ..                                                 ...
# 278  <h4>Job brief</h4><p><span style="font-weight:...
# 279  <h4>Job brief</h4><p><span style="font-weight:...
# 280  <h4>Job brief</h4><p><span style="font-weight:...
# 281  <h4>Job brief</h4><p>We are looking for an exp...
# 282  <h4>Job brief</h4><p>We are looking for a resu...
#
#                                              questions
# 0    ['A debtor has missed six months of payments. ...
# 1    ['How would you create a report on debts from ...
# 2    ['What would you do if you received a B-Notice...
# 3    ['What would be the first thing you’d check if...
# 4    ['If you could use only Excel, how would you o...
# ..                                                 ...
# 278  ['Imagine a customer asks you a question about...
# 279  ['If I asked you to eliminate one line of our ...
# 280  ['Here’s a spreadsheet with data. Can you spot...
# 281  ['As a merchandiser, what do you think is the ...
# 282  ['Who are our main competitors?', 'What tasks,...
#
# [283 rows x 3 columns]

# %% [markdown]
# ### 1.2 Counting the number of keywords and checking for repeated keywords

# %%
opened_file= open("keywords.txt")
from csv import reader
read_file = reader(opened_file)
keywords_data = list(read_file)

# %%
keywords_data
# Out:
# [['teaching'],
#  ['pharmaceutical'],
#  ['ERP'],
#  ['fulfillment'],
#  ['positioning'],
#  ['tax'],
#  ['service delivery'],
#  ['investigate'],
#  ['editorial'],
#  ['account management'],
#  ['business process'],
#  ['valid drivers license'],
#  ['electronics'],
#  ['PR'],
#  ['public relations'],
#  ['Javascript'],
#  ['assembly'],
#  ['digital marketing'],
#  ['Linux'],
#  ['Facebook'],
#  ['spreadsheets'],
#  ['recruit'],
#  ['proposal'],
#  ['SharePoint'],
#  ['data entry'],
#  ['hotel'],
#  ['ordering'],
#  ['branding'],
#  ['life cycle'],
#  ['real estate'],
#  ['relationship management'],
#  ['researching'],
#  ['process improvements'],
#  ['chemistry'],
#  ['SaaS'],
#  ['CAD'],
#  ['sales experience'],
#  ['mathematics'],
#  ['customer-facing'],
#  ['audio'],
#  ['project management skills'],
#  ['six sigma'],
#  ['hospitality'],
#  ['mechanical engineering'],
#  ['auditing'],
#  ['employee relations'],
#  ['android'],
#  ['security clearance'],
#  ['licensing'],
#  ['Adobe'],
#  ['fundraising'],
#  ['repairs'],
#  ['ISO'],
#  ['market research'],
#  ['warehouse'],
#  ['business strategy'],
#  ['PMP'],
#  ['data management'],
#  ['quality control'],
#  ['reconciliation'],
#  ['CSS'],
#  ['conversion'],
#  ['business analysis'],
#  ['financial analysis'],
#  ['ecommerce'],
#  ['business intelligence'],
#  ['C++'],
#  ['client service'],
#  ['publishing'],
#  ['supervising'],
#  ['complex projects'],
#  ['key performance indicators'],
#  ['scrum'],
#  ['Photoshop'],
#  ['sports'],
#  ['e-commerce'],
#  ['journalism'],
#  ['data collection'],
#  ['higher education'],
#  ['marketing programs'],
#  ['financial management'],
#  ['business plans'],
#  ['user experience'],
#  ['client relationships'],
#  ['cloud'],
#  ['analytical skills'],
#  ['Cisco'],
#  ['internal stakeholders'],
#  ['product marketing'],
#  ['regulatory requirements'],
#  ['ITIL'],
#  ['information security'],
#  ['aviation'],
#  ['supply chain management'],
#  ['Python'],
#  ['accounts payable'],
#  ['industry experience'],
#  ['AutoCAD'],
#  ['purchase orders'],
#  ['acquisitions'],
#  ['TV'],
#  ['instrumentation'],
#  ['strategic direction'],
#  ['law enforcement'],
#  ['call center'],
#  ['experiments'],
#  ['technical skills'],
#  ['human resource'],
#  ['business cases'],
#  ['build relationships'],
#  ['invoicing'],
#  ['support services'],
#  ['marketing strategy'],
#  ['operating systems'],
#  ['biology'],
#  ['start-up'],
#  ['electrical engineering'],
#  ['workflows'],
#  ['routing'],
#  ['non-profit'],
#  ['marketing plans'],
#  ['due diligence'],
#  ['business management'],
#  ['iPhone'],
#  ['algorithms'],
#  ['architectures'],
#  ['reconcile'],
#  ['dynamic environment'],
#  ['external partners'],
#  ['asset management'],
#  ['Microsoft Word'],
#  ['EMEA'],
#  ['intranet'],
#  ['SOPs'],
#  ['SAS'],
#  ['digital media'],
#  ['prospecting'],
#  ['financial reporting'],
#  ['project delivery'],
#  ['SEO'],
#  ['operational excellence'],
#  ['standard operating procedures'],
#  ['C#'],
#  ['technical knowledge'],
#  ['on-call'],
#  ['talent management'],
#  ['stakeholder management'],
#  ['tablets'],
#  ['CMS'],
#  ['analyze data'],
#  ['financial statements'],
#  ['Microsoft Office Suite'],
#  ['fitness'],
#  ['case management'],
#  ['value proposition'],
#  ['industry trends'],
#  ['RFP'],
#  ['broadcast'],
#  ['portfolio management'],
#  ['fabrication'],
#  ['UX'],
#  ['financial performance'],
#  ['customer requirements'],
#  ['psychology'],
#  ['marketing materials'],
#  ['resource management'],
#  ['physics'],
#  ['mortgage'],
#  ['development activities'],
#  ['end user'],
#  ['business planning'],
#  ['root cause'],
#  ['analysis'],
#  ['leadership development'],
#  ['relationship building'],
#  ['SDLC'],
#  ['on-boarding'],
#  ['quality standards'],
#  ['regulatory compliance'],
#  ['AWS'],
#  ['KPI'],
#  ['status reports'],
#  ['product line'],
#  ['drafting'],
#  ['JIRA'],
#  ['phone calls'],
#  ['product knowledge'],
#  ['business stakeholders'],
#  ['technical issues'],
#  ['admissions'],
#  ['supervisory experience'],
#  ['usability'],
#  ['pharmacy'],
#  ['commissioning'],
#  ['project plan'],
#  ['MS Excel'],
#  ['FDA'],
#  ['test plans'],
#  ['variances'],
#  ['UI'],
#  ['financing'],
#  ['travel arrangements'],
#  ['internal customers'],
#  ['medical device'],
#  ['counsel'],
#  ['inventory management'],
#  ['performance metrics'],
#  ['lighting'],
#  ['outsourcing'],
#  ['InDesign'],
#  ['performance improvement'],
#  ['management consulting'],
#  ['graphic design'],
#  ['transport'],
#  ['information management'],
#  ['.NET'],
#  ['startup'],
#  ['matrix'],
#  ['front-end'],
#  ['project planning'],
#  ['business systems'],
#  ['accounts receivable'],
#  ['public health'],
#  ['HRIS'],
#  ['German'],
#  ['instructional design'],
#  ['in-store'],
#  ['data center'],
#  ['MATLAB'],
#  ['employee engagement'],
#  ['cost effective'],
#  ['sales management'],
#  ['API'],
#  ['Adobe Creative Suite'],
#  ['Twitter'],
#  ['program development'],
#  ['event planning'],
#  ['cash flow'],
#  ['strategic plans'],
#  ['root cause'],
#  ['vendor management'],
#  ['trade shows'],
#  ['hotels'],
#  ['segmentation'],
#  ['contract management'],
#  ['GIS'],
#  ['talent acquisition'],
#  ['photography'],
#  ['internal communications'],
#  ['client services'],
#  ['IBM'],
#  ['financial reports'],
#  ['product quality'],
#  ['beverage'],
#  ['strong analytical skills'],
#  ['underwriting'],
#  ['CPR'],
#  ['mining'],
#  ['sales goals'],
#  ['chemicals'],
#  ['deposits'],
#  ['scripting'],
#  ['migration'],
#  ['software engineering'],
#  ['MIS'],
#  ['therapeutic'],
#  ['general ledger'],
#  ['Tableau'],
#  ['MS Project'],
#  ['standardization'],
#  ['retention'],
#  ['spelling'],
#  ['media relations'],
#  ['OS'],
#  ['daily operations'],
#  ['immigration'],
#  ['product design'],
#  ['ETL'],
#  ['field sales'],
#  ['driving record'],
#  ['PeopleSoft'],
#  ['benchmark'],
#  ['quality management'],
#  ['APIs'],
#  ['test cases'],
#  ['internal controls'],
#  ['telecom'],
#  ['business issues'],
#  ['research projects'],
#  ['data quality'],
#  ['strategic initiatives'],
#  ['office software'],
#  ['CFA'],
#  ['co-op'],
#  ['big data'],
#  ['journal entries'],
#  ['VMware'],
#  ['help desk'],
#  ['statistical analysis'],
#  ['datasets'],
#  ['alliances'],
#  ['SolidWorks'],
#  ['prototype'],
#  ['LAN'],
#  ['SCI'],
#  ['budget management'],
#  ['Unix'],
#  ['RFPs'],
#  ['Flex'],
#  ['GAAP'],
#  ['experimental'],
#  ['CPG'],
#  ['information system'],
#  ['customer facing'],
#  ['process development'],
#  ['web services'],
#  ['international'],
#  ['travel'],
#  ['revenue growth'],
#  ['software development life cycle'],
#  ['operations management'],
#  ['computer applications'],
#  ['risk assessments'],
#  ['sales operations'],
#  ['raw materials'],
#  ['internal audit'],
#  ['physical security'],
#  ['SQL server'],
#  ['affiliate'],
#  ['computer software'],
#  ['manage projects'],
#  ['business continuity'],
#  ['litigation'],
#  ['IT infrastructure'],
#  ['cost reduction'],
#  ['small business'],
#  ['annual budget'],
#  ['iOS'],
#  ['HTML5'],
#  ['real-time'],
#  ['consulting experience'],
#  ['circuits'],
#  ['machine learning'],
#  ['risk assessment'],
#  ['DNS'],
#  ['cross-functional team'],
#  ['public policy'],
#  ['analyzing data'],
#  ['consulting services'],
#  ['Photoshop'],
#  ['Cinema'],
#  ['Arts'],
#  ['Recursos Humanos'],
#  ['Excel'],
#  ['account management'],
#  ['accounting'],
#  ['accounts payable'],
#  ['accounts receivable'],
#  ['acquisition'],
#  ['acquisitions'],
#  ['administrative support'],
#  ['admissions'],
#  ['Adobe'],
#  ['Adobe Creative Suite'],
#  ['advertising'],
#  ['affiliate'],
#  ['agile'],
#  ['algorithms'],
#  ['alliances'],
#  ['analysis'],
#  ['analytical'],
#  ['analytical skills'],
#  ['analytics'],
#  ['analyze data'],
#  ['analyzing data'],
#  ['android'],
#  ['annual budget'],
#  ['API'],
#  ['APIs'],
#  ['architecture'],
#  ['architectures'],
#  ['assembly'],
#  ['asset management'],
#  ['audio'],
#  ['audit'],
#  ['auditing'],
#  ['AutoCAD'],
#  ['automation'],
#  ['aviation'],
#  ['AWS'],
#  ['banking'],
#  ['benchmark'],
#  ['beverage'],
#  ['BI'],
#  ['big data'],
#  ['billing'],
#  ['biology'],
#  ['brand'],
#  ['branding'],
#  ['broadcast'],
#  ['budget'],
#  ['budget management'],
#  ['budgeting'],
#  ['build relationships'],
#  ['business administration'],
#  ['business analysis'],
#  ['business cases'],
#  ['business continuity'],
#  ['business development'],
#  ['business intelligence'],
#  ['business issues'],
#  ['business management'],
#  ['business planning'],
#  ['business plans'],
#  ['business process'],
#  ['business requirements'],
#  ['business stakeholders'],
#  ['business strategy'],
#  ['business systems'],
#  ['C (programming language)'],
#  ['C#'],
#  ['C++'],
#  ['CAD'],
#  ['call center'],
#  ['case management'],
#  ['cash flow'],
#  ['certification'],
#  ['CFA'],
#  ['change management'],
#  ['chemicals'],
#  ['chemistry'],
#  ['circuits'],
#  ['Cisco'],
#  ['client relationships'],
#  ['client service'],
#  ['client services'],
#  ['cloud'],
#  ['CMS'],
#  ['co-op'],
#  ['coaching'],
#  ['coding'],
#  ['commissioning'],
#  ['complex projects'],
#  ['compliance'],
#  ['computer applications'],
#  ['computer science'],
#  ['computer software'],
#  ['construction'],
#  ['consulting'],
#  ['consulting experience'],
#  ['consulting services'],
#  ['consumers'],
#  ['content'],
#  ['continuous improvement'],
#  ['contract management'],
#  ['contracts'],
#  ['controls'],
#  ['conversion'],
#  ['correspondence'],
#  ['cost effective'],
#  ['cost reduction'],
#  ['counsel'],
#  ['counseling'],
#  ['CPG'],
#  ['CPR'],
#  ['CRM'],
#  ['cross-functional team'],
#  ['CSS'],
#  ['customer experience'],
#  ['customer facing'],
#  ['customer requirements'],
#  ['customer service'],
#  ['customer-facing'],
#  ['D (programming language)'],
#  ['daily operations'],
#  ['data analysis'],
#  ['data center'],
#  ['data collection'],
#  ['data entry'],
#  ['data management'],
#  ['data quality'],
#  ['database'],
#  ['datasets'],
#  ['deposits'],
#  ['design'],
#  ['development activities'],
#  ['digital marketing'],
#  ['digital media'],
#  ['distribution'],
#  ['DNS'],
#  ['documentation'],
#  ['documenting'],
#  ['drafting'],
#  ['drawings'],
#  ['driving record'],
#  ['due diligence'],
#  ['dynamic environment'],
#  ['e-commerce'],
#  ['ecommerce'],
#  ['economics'],
#  ['editing'],
#  ['editorial'],
#  ['electrical'],
#  ['electrical engineering'],
#  ['electronics'],
#  ['EMEA'],
#  ['employee engagement'],
#  ['employee relations'],
#  ['end user'],
#  ['engagement'],
#  ['engineering'],
#  ['ERP'],
#  ['ETL'],
#  ['event planning'],
#  ['expenses'],
#  ['experimental'],
#  ['experiments'],
#  ['external partners'],
#  ['fabrication'],
#  ['Facebook'],
#  ['FDA'],
#  ['field sales'],
#  ['filing'],
#  ['finance'],
#  ['financial analysis'],
#  ['financial management'],
#  ['financial performance'],
#  ['financial reporting'],
#  ['financial reports'],
#  ['financial services'],
#  ['financial statements'],
#  ['financing'],
#  ['fitness'],
#  ['Flex'],
#  ['forecasting'],
#  ['forecasts'],
#  ['frameworks'],
#  ['front-end'],
#  ['fulfillment'],
#  ['fundraising'],
#  ['GAAP'],
#  ['general ledger'],
#  ['German'],
#  ['GIS'],
#  ['governance'],
#  ['graphic design'],
#  ['hardware'],
#  ['health'],
#  ['healthcare'],
#  ['help desk'],
#  ['higher education'],
#  ['hing'],
#  ['hospital'],
#  ['hospitality'],
#  ['hotel'],
#  ['hotels'],
#  ['HRIS'],
#  ['HTML'],
#  ['HTML5'],
#  ['human resource'],
#  ['I-DEAS'],
#  ['IBM'],
#  ['immigration'],
#  ['in-store'],
#  ['InDesign'],
#  ['industry experience'],
#  ['industry trends'],
#  ['information management'],
#  ['information security'],
#  ['information system'],
#  ['information systems'],
#  ['information technology'],
#  ['installation'],
#  ['instructional design'],
#  ['instrumentation'],
#  ['internal audit'],
#  ['internal communications'],
#  ['internal controls'],
#  ['internal customers'],
#  ['internal stakeholders'],
#  ['international'],
#  ['internship'],
#  ['intranet'],
#  ['inventory'],
#  ['inventory management'],
#  ['investigate'],
#  ['investigation'],
#  ['investigations'],
#  ['invoices'],
#  ['invoicing'],
#  ['iOS'],
#  ['iPhone'],
#  ['ISO'],
#  ['IT infrastructure'],
#  ['ITIL'],
#  ['Java'],
#  ['Javascript'],
#  ['JIRA'],
#  ['journal entries'],
#  ['journalism'],
#  ['key performance indicators'],
#  ['KPI'],
#  ['KPIs'],
#  ['LAN'],
#  ['law enforcement'],
#  ['leadership development'],
#  ['lean'],
#  ['legal'],
#  ['legislation'],
#  ['licensing'],
#  ['life cycle'],
#  ['lifecycle'],
#  ['lighting'],
#  ['Linux'],
#  ['litigation'],
#  ['logistics'],
#  ['machine learning'],
#  ['man resources'],
#  ['manage projects'],
#  ['management consulting'],
#  ['management experience'],
#  ['market research'],
#  ['marketing'],
#  ['marketing materials'],
#  ['marketing plans'],
#  ['marketing programs'],
#  ['marketing strategy'],
#  ['mathematics'],
#  ['MATLAB'],
#  ['matrix'],
#  ['mechanical engineering'],
#  ['media relations'],
#  ['medical device'],
#  ['merchandising'],
#  ['metrics'],
#  ['Microsoft Office'],
#  ['Microsoft Office Suite'],
#  ['Microsoft Word'],
#  ['migration'],
#  ['mining'],
#  ['MIS'],
#  ['mobile'],
#  ['modeling'],
#  ['mortgage'],
#  ['MS Excel'],
#  ['MS Office'],
#  ['MS Project'],
#  ['negotiation'],
#  ['networking'],
#  ['non-profit'],
#  ['nursing'],
#  ['office software'],
#  ['on-boarding'],
#  ['on-call'],
#  ['operating systems'],
#  ['operational excellence'],
#  ['operations'],
#  ['operations management'],
#  ['oracle'],
#  ['ordering'],
#  ['OS'],
#  ['outreach'],
#  ['outsourcing'],
#  ['partnership'],
#  ['partnerships'],
#  ['payments'],
#  ['payroll'],
#  ['PeopleSoft'],
#  ['performance improvement'],
#  ['performance management'],
#  ['performance metrics'],
#  ['pharmaceutical'],
#  ['pharmacy'],
#  ['phone calls'],
#  ['photography'],
#  ['Photoshop'],
#  ['physical security'],
#  ['physics'],
#  ['PMP'],
#  ['policies'],
#  ['portfolio management'],
#  ['positioning'],
#  ['PR'],
#  ['presentation'],
#  ['presentations'],
#  ['process development'],
#  ['process improvements'],
#  ['procurement'],
#  ['product design'],
#  ['product development'],
#  ['product knowledge'],
#  ['product line'],
#  ['product management'],
#  ['product marketing'],
#  ['product quality'],
#  ['program development'],
#  ['program management'],
#  ['programming'],
#  ['project delivery'],
#  ['project management'],
#  ['project management skills'],
#  ['project plan'],
#  ['project planning'],
#  ['proposal'],
#  ['prospecting'],
#  ['protocols'],
#  ['prototype'],
#  ['psychology'],
#  ['public health'],
#  ['public policy'],
#  ['public relations'],
#  ['publications'],
#  ['publishing'],
#  ['purchase orders'],
#  ['purchasing'],
#  ['Python'],
#  ['QA'],
#  ['quality assurance'],
#  ['quality control'],
#  ['quality management'],
#  ['quality standards'],
#  ['R (programming language)'],
#  ['raw materials'],
#  ['real estate'],
#  ['real-time'],
#  ['reconcile'],
#  ['reconciliation'],
#  ['recruit'],
#  ['recruiting'],
#  ['recruitment'],
#  ['regulations'],
#  ['regulatory'],
#  ['regulatory compliance'],
#  ['regulatory requirements'],
#  ['relationship building'],
#  ['relationship management'],
#  ['repairs'],
#  ['reporting'],
#  ['research'],
#  ['research projects'],
#  ['researching'],
#  ['resource management'],
#  ['retail'],
#  ['retention'],
#  ['revenue growth'],
#  ['RFP'],
#  ['RFPs'],
#  ['risk assessment'],
#  ['risk assessments'],
#  ['risk management'],
#  ['root cause'],
#  ['root cause'],
#  ['routing'],
#  ['SaaS'],
#  ['safety'],
#  ['sales'],
#  ['sales experience'],
#  ['sales goals'],
#  ['sales management'],
#  ['sales operations'],
#  ['Salesforce'],
#  ['SAP'],
#  ['SAS'],
#  ['scheduling'],
#  ['SCI'],
#  ['scripting'],
#  ['scrum'],
#  ['SDLC'],
#  ['security clearance'],
#  ['segmentation'],
#  ['SEO'],
#  ['service delivery'],
#  ['SharePoint'],
#  ['six sigma'],
#  ['small business'],
#  ['social media'],
#  ['software development'],
#  ['software development life cycle'],
#  ['software engineering'],
#  ['SolidWorks'],
#  ['SOPs'],
#  ['sourcing'],
#  ['specifications'],
#  ['spelling'],
#  ['sports'],
#  ['spreadsheets'],
#  ['SQL'],
#  ['SQL server'],
#  ['staffing'],
#  ['stakeholder management'],
#  ['standard operating procedures'],
#  ['standardization'],
#  ['start-up'],
#  ['startup'],
#  ['statistical analysis'],
#  ['statistics'],
#  ['status reports'],
#  ['strategic direction'],
#  ['strategic initiatives'],
#  ['strategic planning'],
#  ['strategic plans'],
#  ['strategy'],
#  ['strong analytical skills'],
#  ['supervising'],
#  ['supervisory experience'],
#  ['supply chain'],
#  ['supply chain management'],
#  ['support services'],
#  ['Tableau'],
#  ['tablets'],
#  ['talent acquisition'],
#  ['talent management'],
#  ['tax'],
#  ['technical'],
#  ['technical issues'],
#  ['technical knowledge'],
#  ['technical skills'],
#  ['technical support'],
#  ['telecom'],
#  ['test cases'],
#  ['test plans'],
#  ['testing'],
#  ['therapeutic'],
#  ['trade shows'],
#  ['training'],
#  ['transactions'],
#  ['transport'],
#  ['transportation'],
#  ['travel'],
#  ['travel arrangements'],
#  ['troubleshooting'],
#  ['TV'],
#  ['Twitter'],
#  ['UI'],
#  ['underwriting'],
#  ['Unix'],
#  ['usability'],
#  ['user experience'],
#  ['UX'],
#  ['valid drivers license'],
#  ['value proposition'],
#  ['variances'],
#  ['vendor management'],
#  ['vendors'],
#  ['video'],
#  ['VMware'],
#  ['warehouse'],
#  ['web services'],
#  ['windows'],
#  ['workflows'],
#  ['writing'],
#  ['Accomplished'],
#  ['Achieved'],
#  ['Acquired'],
#  ['Acted'],
#  ['Adapted'],
#  ['Addressed'],
#  ['Adjusted'],
#  ['Administered'],
#  ['Advanced'],
#  ['Advertised'],
#  ['Advised'],
#  ['Advocated'],
#  ['Aided'],
#  ['Aligned'],
#  ['Allocated'],
#  ['Amplified'],
#  ['Amplify'],
#  ['Analyzed'],
#  ['Answered'],
#  ['Applied'],
#  ['Appointed'],
#  ['Appraised'],
#  ['Approved'],
#  ['Arbitrated'],
#  ['Architected'],
#  ['Arranged'],
#  ['Articulated'],
#  ['Assembled'],
#  ['Assessed'],
#  ['Assigned'],
#  ['Assisted'],
#  ['Attained'],
#  ['Audited'],
#  ['Augmented'],
#  ['Authored'],
#  ['Authorized'],
#  ['Automated'],
#  ['Awarded'],
#  ['Balanced'],
#  ['Began'],
#  ['Blocked'],
#  ['Boosted'],
#  ['Brainstormed'],
#  ['Briefed'],
#  ['Budgeted'],
#  ['Built'],
#  ['Calculated'],
#  ['Campaigned'],
#  ['Capitalized'],
#  ['Captured'],
#  ['Cared'],
#  ['Cataloged'],
#  ['Categorized'],
#  ['Centralized'],
#  ['Chaired'],
#  ['Championed'],
#  ['Charted'],
#  ['Checked'],
#  ['Clarified'],
#  ['Classified'],
#  ['Co-Authored'],
#  ['Coached'],
#  ['Coded'],
#  ['Collaborated'],
#  ['Collected'],
#  ['Combined'],
#  ['Communicated'],
#  ['Compared'],
#  ['Compiled'],
#  ['Completed'],
#  ['Composed'],
#  ['Computed'],
#  ['Conceptualized'],
#  ['Condensed'],
#  ['Conducted'],
#  ['Conferred'],
#  ['Conserved'],
#  ['Considered'],
#  ['Consolidated'],
#  ['Constructed'],
#  ['Consulted'],
#  ['Contacted'],
#  ['Contracted'],
#  ['Contributed'],
#  ['Controlled'],
#  ['Convert'],
#  ['Converted'],
#  ['Conveyed'],
#  ['Convinced'],
#  ['Cooperated'],
#  ['Coordinated'],
#  ['Corrected'],
#  ['Corresponded'],
#  ['Counseled'],
#  ['Crafted'],
#  ['Created'],
#  ['Creative'],
#  ['Critiqued'],
#  ['Cultivated'],
#  ['Curated'],
#  ['Customized'],
#  ['Debated'],
#  ['Debugged'],
#  ['Decided'],
#  ['Deciphered'],
#  ['Decreased'],
#  ['Deducted'],
#  ['Defined'],
#  ['Delegated'],
#  ['Delivered'],
#  ['Demonstrated'],
#  ['Deployed'],
#  ['Derived'],
#  ['Described'],
#  ['Designed'],
#  ['Detected'],
#  ['Determined'],
#  ['Developed'],
#  ['Devised'],
#  ['Diagnosed'],
#  ['Diagramed'],
#  ['Differentiated'],
#  ['Directed'],
#  ['Discerned'],
#  ['Discovered'],
#  ['Discussed'],
#  ['Dispatched'],
#  ['Dispensed'],
#  ['Displayed'],
#  ['Distributed'],
#  ['Documented'],
#  ['Drafted'],
#  ['Drew'],
#  ['Drove'],
#  ['Earned'],
#  ['Edited'],
#  ['Educated'],
#  ['Elicited'],
#  ['Eliminated'],
#  ['Emphasized'],
#  ['Empowered'],
#  ['Enabled'],
#  ['Enacted'],
#  ['Encouraged'],
#  ['Endeavored'],
#  ['Endorsed'],
#  ['Enforced'],
#  ['Engineered'],
#  ['Enhanced'],
#  ...]

# %%
len(keywords_data)
# Out:
# 1410

# %%
keyword_list=[]
for keyword in keywords_data:
    keyword_list.append(keyword[0])
keyword_list
len(keyword_list)
# Out:
# 1410

# %%
all_keywords_set=set(keyword_list)
all_keywords_list=list(all_keywords_set)
len(all_keywords_list)
# Out:
# 1054

# %%
len(keyword_list)-len(all_keywords_list)
# Out:
# 356

# %% [markdown]
# There are **356** keyword repetitions

# %% [markdown]
# ### 1.3 Creating a new column with the number of question per role

# %%
df["number_of_questions"]=df["questions"].str.split("[^a-e]', ?'[^a-e]").str.len()
df
# Out:
#                            title  \
# 0          Collection Specialist
# 1                Billing Analyst
# 2                 Tax Accountant
# 3    Accounts Receivable Manager
# 4                Cost Accountant
# ..                           ...
# 278                Sales Advisor
# 279                 Retail Buyer
# 280             Category Manager
# 281                 Merchandiser
# 282                Store Manager
#
#                                        job description  \
# 0    <h4>Job brief</h4><p>We are looking for a comp...
# 1    <h4>Job brief</h4><p>We are looking for a Bill...
# 2    <h4>Job brief</h4><p>We are looking for a Tax ...
# 3    <h4>Job brief</h4><p>We are looking for an Acc...
# 4    <h4>Job brief</h4><p>We are looking for a Cost...
# ..                                                 ...
# 278  <h4>Job brief</h4><p><span style="font-weight:...
# 279  <h4>Job brief</h4><p><span style="font-weight:...
# 280  <h4>Job brief</h4><p><span style="font-weight:...
# 281  <h4>Job brief</h4><p>We are looking for an exp...
# 282  <h4>Job brief</h4><p>We are looking for a resu...
#
#                                              questions  number_of_questions
# 0    ['A debtor has missed six months of payments. ...                   16
# 1    ['How would you create a report on debts from ...                   14
# 2    ['What would you do if you received a B-Notice...                   14
# 3    ['What would be the first thing you’d check if...                   17
# 4    ['If you could use only Excel, how would you o...                   15
# ..                                                 ...                  ...
# 278  ['Imagine a customer asks you a question about...                   16
# 279  ['If I asked you to eliminate one line of our ...                   19
# 280  ['Here’s a spreadsheet with data. Can you spot...                   15
# 281  ['As a merchandiser, what do you think is the ...                   15
# 282  ['Who are our main competitors?', 'What tasks,...                   14
#
# [283 rows x 4 columns]

# %%
df.describe()
# Out:
#        number_of_questions
# count           283.000000
# mean             15.342756
# std               3.106703
# min               7.000000
# 25%              13.000000
# 50%              15.000000
# 75%              17.000000
# max              29.000000

# %% [markdown]
# On **average**, we have **15** questions per role. Also, the role with **less** questions has **7** and the role with the max questions has **29** questions.

# %% [markdown]
# ### 1.4 Cheking if there are any duplicated roles

# %%
all_jobs=df["title"].tolist()
all_jobs_set=set(all_jobs)
all_jobs_list=list(all_jobs_set)
len(all_jobs_list)
# Out:
# 283

# %% [markdown]
# All the rows have a different role and no role is duplicated

# %% [markdown]
# ### 1.5 Checking if any of the columns has null values

# %%
df.isnull().any()
# Out:
# title                  False
# job description        False
# questions              False
# number_of_questions    False
# dtype: bool

# %% [markdown]
# No null values on the dataset

# %% [markdown]
# ### 1.6 Inspecting the total number of questions and questions repetitions

# %% [markdown]
# First, we are goint to split the questions in every row of the questions column into a list of lists:

# %%
df["questions"]=df["questions"].str.split("[^a-e]', ?'[^a-e]")
df
# Out:
#                            title  \
# 0          Collection Specialist
# 1                Billing Analyst
# 2                 Tax Accountant
# 3    Accounts Receivable Manager
# 4                Cost Accountant
# ..                           ...
# 278                Sales Advisor
# 279                 Retail Buyer
# 280             Category Manager
# 281                 Merchandiser
# 282                Store Manager
#
#                                        job description  \
# 0    <h4>Job brief</h4><p>We are looking for a comp...
# 1    <h4>Job brief</h4><p>We are looking for a Bill...
# 2    <h4>Job brief</h4><p>We are looking for a Tax ...
# 3    <h4>Job brief</h4><p>We are looking for an Acc...
# 4    <h4>Job brief</h4><p>We are looking for a Cost...
# ..                                                 ...
# 278  <h4>Job brief</h4><p><span style="font-weight:...
# 279  <h4>Job brief</h4><p><span style="font-weight:...
# 280  <h4>Job brief</h4><p><span style="font-weight:...
# 281  <h4>Job brief</h4><p>We are looking for an exp...
# 282  <h4>Job brief</h4><p>We are looking for a resu...
#
#                                              questions  number_of_questions
# 0    [['A debtor has missed six months of payments....                   16
# 1    [['How would you create a report on debts from...                   14
# 2    [['What would you do if you received a B-Notic...                   14
# 3    [['What would be the first thing you’d check i...                   17
# 4    [['If you could use only Excel, how would you ...                   15
# ..                                                 ...                  ...
# 278  [['Imagine a customer asks you a question abou...                   16
# 279  [['If I asked you to eliminate one line of our...                   19
# 280  [['Here’s a spreadsheet with data. Can you spo...                   15
# 281  [['As a merchandiser, what do you think is the...                   15
# 282  [['Who are our main competitors, hat tasks, wh...                   14
#
# [283 rows x 4 columns]

# %% [markdown]
# After having a list of questions for every role, we are going to create a list of all the questions in the dataset:

# %%
all_questions=[]
for questions in df["questions"]:
    for question in questions:
        all_questions.append(question)
all_questions
# Out:
# ["['A debtor has missed six months of payments. When you call the individual, they bring up financial difficulties and get emotional. How do you handle this",
#  'hat payback plan would you recommend for a long-term client whose payments are due to be collected in X months',
#  'f you called a client to update them on their payment status and they were aggressive or rude to you, how would you handle it',
#  'an you think of a few common excuses that debtors make? How would you respond to each of them',
#  'hat collection methods do you know? Which technique do you think would be more effective for our company/clients',
#  'ow do you keep historical data for each account',
#  'ow often do you follow up with delinquent account holders and what’s your approach when you get in touch',
#  'ention three things a Collection Specialist should avoid saying when speaking to a debtor',
#  'ow do you keep track of all payments',
#  'hat software do you use to increase your productivity',
#  'hat do you find interesting about this job',
#  'escribe a time you had to deal with a difficult client. How did you handle the situation',
#  'escribe a time you persuaded a client to pay off a large debt. How did you handle it, from beginning to end',
#  'ave you ever faced an ethical dilemma at work? If so, what was the situation and what did you do',
#  'ave your negotiations with a creditor ever failed? If so, what would you do different',
#  "ow does empathy help you build trusting, long-term relationships? Give an example of a time when you were able to better understand and address a client’s needs.']",
#  "['How would you create a report on debts from the previous quarter",
#  'ow would you contact clients who haven’t paid their bills',
#  'f a long-term client had a debt at the end of the fiscal year, how would you address it with him/her',
#  'ow would you make sure we collect invoices in a timely manner',
#  'ow would you handle an invoice discrepancy with a client',
#  'riefly explain the financial transactions involved in the billing process and your experience with each',
#  'hat accounting software have you used',
#  'ow do you keep updated records of accounts receivable from clients',
#  'ow do you ensure financial information remains confidential',
#  'hat are your responsibilities during annual audits',
#  'ave you ever made a mistake at work (e.g. a wrong calculation)? How did you figure it out and what happened',
#  'ow do you manage to meet tight deadlines',
#  'ow do you stay up-to-date with new financial regulations? Do you read any specific blogs, magazines or newspapers? If so, what are they',
#  "hat keeps you motivated during repetitive tasks?']",
#  "['What would you do if you received a B-Notice on behalf of your client",
#  'hat information would you use to create a forecasting report for next year’s tax returns',
#  'ou thought the deadline for tax payment submission was in a month, but it’s actually in a week. How would you handle this',
#  'ow would you inform your manager that your company needs to pay a fine because you weren’t aware of a regulatory change',
#  'hat accounting software are you familiar with',
#  'hat monthly and annual reports do you create',
#  'hat information do you need to submit a 1096? What’s different when you e-file a 1099',
#  'hat is an IRS Backup Withholding Notice',
#  'ow do you avoid numerical errors in your reports',
#  'hat attracted you to tax accounting versus other fields, like forensic or auditing',
#  'ow do you stay on top of regulatory changes',
#  'ow do you keep up to date on global economic issues',
#  'escribe a time you saved your client/employer money',
#  "ave you ever faced an ethical dilemma at work? If so, how did you manage it?']",
#  "['What would be the first thing you’d check if you found a billing discrepancy",
#  'ow would you negotiate with a client who has a debt',
#  'hat are the steps you would take to close the accounts receivable period',
#  'hat time management tips would you give to a newly-hired Accounts Receivable Clerk',
#  'hat information would you use to forecast next month’s payments',
#  'hat objectives would you set for your team? (monthly, quarterly and annual goals',
#  'hat accounting software have you used? How do they facilitate your daily tasks',
#  'riefly describe the steps of the journal entry process',
#  'ow often do you conduct bank reconciliation? Why',
#  'hat accounting reports do you create on a regular basis',
#  'hat data do you include in an invoice for services rendered',
#  'ow do you prefer to share the results from your team: with a detailed report or a verbal presentation? Why',
#  'ow do you handle inconsistent payments from clients',
#  'ow do you evaluate employee performance? Tell us about a time you had to deliver a negative review to one of your team members',
#  'ave you ever made a mistake at work that cost you (or your company) money? If so, what was the situation and what did you learn from that experience',
#  'ow do you check your work for accuracy and how do you ensure you meet all deadlines',
#  "ow do you stay up-to-date with changes in finance legislation?']",
#  "['If you could use only Excel, how would you organize the company’s fixed costs to ensure they’re accurate and accessible",
#  'f the CEO asked you to help decide if opening a new branch would be profitable, how would you go about analyzing the situation',
#  'hat information would you need to forecast quarterly and annual costs',
#  ' manager has trouble understanding charts and asks you to explain a report in simple terms. How would you explain a budgeting report to the manager',
#  'e are in front of a business opportunity that involves taking big risks but has large profit margins. What data would you collect and analyze to help us make a decision',
#  'n which cases do you use discounted cash flow (DCF)',
#  'ow familiar are you with SFAS (Statement of Financial Accounting Standards)',
#  'ow do you check data accuracy in large spreadsheets',
#  'hat accounting software have you previously used',
#  'hat invoice processing systems do you know',
#  'ave you ever suggested a way to improve a regular accounting process? What was it',
#  'ow do you stay up-to-date with changes to financial regulations',
#  'ave you ever made a mistake in calculations that resulted in false forecasts? How did you find out about the mistake and what did you do to correct it',
#  'ow do you manage workflow under tight deadlines',
#  "ave you ever discovered a cost-effective solution? If yes, what was it, and how did you present your idea to senior managers?']",
#  "['If you missed the deadline for paying our company’s taxes, what would you do? How would you inform your manager if we had to pay a fine, in this case",
#  'ow would you help a manager decide if an investment was a good idea',
#  'ow would you set up an internal control system for processing invoices',
#  'f you had to explain a financial procedure to non-financial audience, how would you ensure they understand all the details? For example, tell us in plain terms about the process of preparing a department’s budget',
#  'hat accounting software have you used? What features increase your productivity',
#  'ow do you check large datasheets for accuracy',
#  'escribe your familiarity with accounting standards such as FASB and GAAP',
#  'hat information and tools do you need to create an annual tax return forecast',
#  'here and how do you use discounted cash flow (DCF)',
#  'hat is your role in the month-end closing process',
#  'escribe a time when you helped your company or a client decrease costs',
#  'ow do you keep up with tax law changes',
#  'ecall a time you analyzed financial risks and prevented senior executives from making a bad investment',
#  'ow do you stay motivated while doing repetitive tasks, like processing invoices',
#  "escribe a time when your attention to detail saved you from making a mistake at work (e.g. in a report.)']",
#  "['What measures would you take if you discovered an invoice discrepancy",
#  'hat goals would you set for your team during your first year? How would you keep track of progress',
#  'hat would you do if you found a mistake in a report you prepared but your manager hadn’t noticed',
#  'hat transactions should Junior Accountants know and how would you train them on more advanced financial topics',
#  'hat accounting software do you use',
#  'ow do you check a report for numerical errors',
#  'hat’s your role during regular tax audits',
#  'hat financial data and metrics do you use to prepare a department’s annual budget',
#  'hat reports and invoices do you gather and manage during the year-end closing',
#  'ow do you stay up-to-date with changes in accounting legislation',
#  'ell us about a time your attention to detail saved you from making a mistake (e.g. in a forecasting report.',
#  'escribe the most challenging financial project you’ve managed so far. How did you overcome difficulties',
#  "escribe a time when you motivated your team to achieve goals. What team management techniques did you use?']",
#  "['What would you do if a client/manager asked you to cover up fraud",
#  'f a high-performer on your team started delivering reports with errors, how would you handle it',
#  'f hired, how would you convince your team members to adjust to your way of working',
#  'f you discovered that a process in our company is not as cost-effective as it could be, how would you present your findings to senior executives',
#  'ave you used any audit software or Computer Assisted Audit Techniques (CAATs?) If so, which ones and how have they helped you',
#  'ow do you check other people’s work for accuracy (e.g. reports or flowcharts?',
#  'ow do periodical internal audits add value to a company',
#  'hat control management processes do you apply to minimize risks',
#  'hat’s your experience with accounting software like Zoho or QuickBooks',
#  'alk me through your fraud detection process',
#  'ave you ever suggested an improvement in the audit process? If so, what was it and why was or wasn’t it finally implemented',
#  'escribe a time when your attention to detail helped you detect a potential law violation',
#  'ow do you keep up with changes in accounting regulations',
#  "ave you ever made a mistake at work? If so, what was it and what did you do to resolve the problem? If not, how do you check your work for accuracy?']",
#  "['Describe your typical day at your current/previous job. How do you prioritize your work",
#  'ow would you rate your proficiency with Microsoft Office programs, especially Excel',
#  'escribe your familiarity with billing and invoice software',
#  'ow many invoices do you handle on a daily basis',
#  'escribe a time you had an invoice discrepancy with a client. How did you resolve it',
#  'xplain the financial transactions involved in the billing process and your experience with each (i.e. classifying, computing, posting, verifying, recording',
#  'ow do you keep track of incoming payments and ensure that it is in compliance with financial procedures? How  do you ensure that they’re properly posted and accounted for',
#  'ow do you ensure the timely collection of invoices',
#  'escribe your most hostile payment collection call. How did you handle it',
#  'escribe a time you went the extra mile to deliver excellent customer service',
#  'escribe a time you worked with a team to complete a project on a tight deadline',
#  's a billing specialist, have you ever faced an ethical dilemma at work? How did you respond',
#  'hat skills do you deem necessary for a billing specialist with our firm. Do you think you possess these skills',
#  "his job can be repetitive. What motivates you to do well?']",
#  "['What data would you present to inform your manager about significant debts from clients",
#  'hat would you say to customers who haven’t paid their bills, if we were close to the end of the fiscal year',
#  'hat would you check first if you found a billing discrepancy',
#  'ow would you make sure we collected invoices in a timely manner',
#  'hat would you do if you realized you made a numerical mistake on an invoice right after you issued it',
#  'hat are a Billing Clerk’s tasks when a customer makes a digital order',
#  'ow do you keep track of payments',
#  'ow often do you update the accounts receivable report',
#  'hat is your experience with accounting software? (e.g. QuickBooks',
#  'hat’s the most effective way to keep records of invoices',
#  'hat bookkeeping tasks are you familiar with',
#  'ow do you make sure financial documents remain confidential',
#  'ave you ever had an invoice discrepancy with a client? How did you resolve it',
#  'ell us about a time you had a tight deadline for a project. How did you manage to complete it in time',
#  'his job can be repetitive. What motivates you to perform routine tasks',
#  "ow do you stay up-to-date with new financial regulations?']",
#  "['What data would you collect to forecast next year’s tax returns",
#  'hat would you do if you found significant numerical errors in a tax estimation only after you sent your report to a client',
#  'ow would you check the accuracy of an accountant’s work',
#  'ow would you present in simple terms the tax risks a client would face by making an investment',
#  'hat are the main differences between state and federal taxes',
#  'hat kind of accounting software have you used',
#  'ow do you organize physical records of important paperwork',
#  'ow do you manage foreign affiliate returns',
#  'o you have experience with employee performance? How do you give feedback to your team members',
#  'ave you ever faced an ethical dilemma at work? If so, how did you manage it',
#  'escribe a time you helped a company minimize its tax obligations',
#  'ow do you stay up-to-date with changes in finance law? For example, do you read any job-related forums or magazines',
#  "ow do you manage deadlines when working for different clients at the same time?']",
#  "['What steps do you take in preparing a budget",
#  'escribe your experience with financial forecasting and projections.',
#  'ow do you stay current on accounting and auditing standards',
#  'ow do you keep track of what you’ve delegated to your team',
#  'ow do you monitor your team’s performance',
#  'ow do you go about directing internal and external audits',
#  'hat is your experience presenting financial data to non-financial staff',
#  'escribe a time you persuaded leadership to make a decision based on financial data',
#  'ow do you explain complicated processes to staff members',
#  'escribe a time you were dissatisfied with an accounting process. What wasn’t working? What did you do to improve it',
#  "escribe your experience with executing a complicated financial project on a tight deadline. How did you coordinate your team in collecting and analyzing data? How did you ensure accuracy?']",
#  "['What are your primary responsibilities as an Accounting Clerk",
#  'hat’s the Accounting department’s role in a company',
#  'hich accounting software programs have you used',
#  'alk me through a successful bank reconciliation step-by-step',
#  'ow would you design a spreadsheet to keep track of accounts payable',
#  'ow do you ensure data typing accuracy',
#  'hat suggestions would you make to improve our invoice keeping process',
#  'ow familiar are you with Excel? Mention some projects you worked on and some regular accounting tasks you completed on excel',
#  'hat do you identify as confidential information and how do you secure it',
#  'ow familiar are you with SFAS (Statement of Financial Accounting Standards)',
#  'ive an example of a goal you had in your previous position. What did you do to reach it',
#  'escribe a situation where you had multiple deadlines. How did you handle them',
#  'ave you ever implemented a change to speed up an accounting process',
#  "hat would you like to learn more about?']",
#  "['How does a balance sheet or cash flow statement help you in determining credit risk",
#  'alk me through the process of determining whether we should loan $5 million to a compan',
#  'f an important long-time customer applied for a loan, but after your analysis you found the risk was too high, how would you handle it',
#  'magine one of the company’s salespeople strongly wants to acquire a particular customer, but you’ve found their creditworthiness is lacking. How do you resolve this',
#  'hat’s your quantitative analysis experience',
#  'hat financial software have you used in the past',
#  'hich financial ratios do you use more often? Which is the most important and why',
#  'hat types of customers have you dealt with in the past',
#  'an you explain the meaning of Credit Default Swap (CDS)',
#  'hat’s different with Basel III',
#  'o you like working in a team',
#  'ell me about a time your judgement on a case was proven incorrect. What should you have done differently',
#  'ecall a time you used your communication skills to resolve an issue at wor',
#  "ell me about a time you developed an effective method or model to assess profitability']",
#  "['Talk about your previous work experience as a bookkeeper",
#  'hat have you done recently to become a better bookkeeper',
#  'ow do you stay updated on regulatory changes that impact on your work',
#  'hat sort of financial reports were you responsible for preparing',
#  'hich bookkeeping systems are you familiar with',
#  'ow would you rate your computer skills',
#  's a bookkeeper, how do you avoid errors in your work',
#  'xplain the balance sheet equation',
#  'he ledger is off by $0.80. What process would you use to find the error',
#  'ow would you record an insurance premium using the accrual accounting method versus the cost accounting method',
#  'hat process would you use to prepare and process invoices',
#  'ow have you contributed to cost savings or profits in your department',
#  'ow often did you interact with vendors and clients',
#  'ave you faced any ethical dilemmas in your work? How did you handle it',
#  "ecall a time you worked with your team to complete a complex project under a deadline.']",
#  "['What interests you about working in accounts receivable at a company like ours",
#  'hat training or experience has prepared you for the role of accounts receivable clerk',
#  'n your own words, explain the accounts receivable process',
#  'hat are the most important goals of AR',
#  'hat types of financial statements or reports do you routinely prepare',
#  'hat are the steps you would take to close the AR period',
#  'escribe your familiarity with accounting software. Which ones have you used',
#  'escribe a time you found a billing discrepancy. How did you resolve it',
#  'n as much detail as possible, describe the journal entry process from the time of generating an invoice to receiving payment',
#  'hat is your role, if any, in the collections process',
#  'hat’s the difference between back end collections and front end collections',
#  'hat types of information do you include in a bill for services rendered',
#  "ecall a challenging problem you encountered as an accounts receivable clerk. How did you resolve it?']",
#  "['What interests you about working in accounts payable at a company like ours",
#  'hat training or experience has prepared you for the role of accounts payable clerk',
#  'escribe your familiarity with accounting software. Which ones have you used',
#  'n as much detail as possible, describe the accounts payable process',
#  'hat differentiates accounts payable from bills payable',
#  'ow would you define a workflow',
#  'rom the bank’s point of view, what is debit and credit? What is it from the customer’s point of view',
#  'his position requires a fair amount of data entry. How do you ensure accuracy in your work',
#  'escribe a time you found an invoice discrepancy. How did you resolve it',
#  'hat types of documents do you need to verify an invoice',
#  'hat steps would you take to make a payment',
#  'hat does it mean when a vendor has \\xa0a debit balance and what would you do in this case',
#  'escribe a time you negotiated vendor terms. How did you handle it',
#  "escribe a time you suggested a way to lower costs, increase revenue, or improve efficiency.']",
#  "['How do you get new business at your current/previous workplace",
#  'ow would you describe your selling style',
#  'hat interests you about the mortgage business',
#  'ow would you learn about our sales culture during your first week on the job',
#  'ow many clients do you have in your portfolio? How many of those did you bring in',
#  'ow would you walk a client through the loan process',
#  'escribe your experience with brokered loans',
#  'hat do you do when you don’t have new prospect appointments scheduled for the day',
#  'ow many prospect appointments did you schedule for this week',
#  'ow would you handle being transferred to the same team as a difficult coworker',
#  'ecall the most difficult sale you’ve ever closed',
#  'ecall a time you had to resolve a problem with an angry client',
#  'ow do you ensure excellent customer service for your clients',
#  "ecall a time you turned a negative situation with a client into a positive one.']",
#  "['Walk me through the process of preparing a budge",
#  'ell me how you go about preparing a forecasting repor',
#  'hen reviewing a funding request, what kind of information do you need',
#  'magine an executive tells you there’s some inconsistency between approved budget and actual expenditure at a department.\\xa0What do you do',
#  'f you had to prepare several budget at the same time, how would you prioritize',
#  'ell me about your experience with cost-benefit analysi',
#  'ow would you rate your data analysis skills, on a scale of 1 to 10',
#  'o you think the job of a budget analyst requires teamwork? Why',
#  'ow do you maintain attention to detail when preparing a budget',
#  'ell me about a time you made a suggestion that resulted in a significant spending cu',
#  'ecall a time you had to defend a budget recommendation to a demanding executive. Was the recommendation approved in the end',
#  'escribe a time when you had to present a budget recommendation to an multi-disciplinary audience. How did you make yourself understood to all of them',
#  'ive me an example of a time you used financial information to solve a proble',
#  "ell me about a time you had a disagreement with a department’s manager over budget']",
#  "['What does a credit mean for the accounting equation",
#  'here and how would you use discounted cash flow (DCF)',
#  'f a manager asked you to help them decide if an investment is a good idea, how would you go about it',
#  'magine you are asked to find a way to reduce a specific cost. Where would you start and how would you make a decision',
#  'hat information do you need for different types of forecasting',
#  'hat would you do if you had to present a report to a non-financial audience',
#  'hat’s your experience with cost-accounting? Financial accounting',
#  'alk about your experience in budgetin',
#  'o you have a specialty area',
#  'ow do you maintain attention to detail',
#  'hat do you do to enhance your knowledge',
#  'ow would you rate your skills in Excel on a scale from 1 to 10',
#  'hat do you know about six sigma',
#  'ive me an example of a time you helped reduce cost',
#  'ell me about a time you played an important role in an important decisio',
#  "ecall a time you prevented senior management from making a bad decision with help from financial data', 'Give me an example of a time you explained financial information to a non-financial perso",
#  'hat project are you most proud of',
#  'ell me about a time you thought of a new process to promote efficienc',
#  "ave you ever faced an ethical dilemma in your job? How did you approach it?']",
#  "['Can you mention three types of special journals",
#  'hat methods have you used to estimate bad debt',
#  'hat accounting software have you used',
#  'hat is fraud analysis? Can you walk me through the process you’d follow step-by-step',
#  'hat ERP systems have you experience working with',
#  'ow do you track your team’s progress on delegated tasks? Name any tools you use',
#  'hat information and metrics do you need to prepare an annual budget',
#  're you familiar with SFAS (Statement of Financial Accounting Standards)',
#  'ow do you ensure data accuracy and minimum errors in your reports',
#  'ow would you deal with an error in customer payment',
#  'hat resources do you use to stay up-to-date with changes in legislation',
#  'ave you ever implemented any improvements to accounting procedures',
#  'escribe a time when your team managed to achieve ambitious goals you set. What did you do to support them and how did you motivate them',
#  "hat’s the most challenging analysis problem you’ve faced at work?']",
#  "['What’s important to consider when updating a journal entry",
#  'hat steps are needed for bank reconciliation',
#  'ow familiar are you with SFAS (Statement of Financial Accounting Standards)',
#  'ave you used any ERP systems (e.g. Tally) before',
#  'ow do you prepare yourself for a senior accountant position',
#  'hat actions do you take to protect confidential information',
#  'ow do you prioritize your tasks',
#  'hat do you do to avoid mistakes in your job',
#  'f you realized you made a mistake on a report, what would you do',
#  'f a manager pressured you to provide them with information they don’t have permission for, how would you handle it',
#  'ell me about a difficult project you worked on during your studies/internship/etc',
#  'escribe the accounting project you are most proud o',
#  'hat was the most important thing you learned during your internship? What was your most significant contribution',
#  'ave you ever made a mistake due to misunderstanding instructions? What have you learned',
#  "ave you ever been asked to do something that you didn’t agree with? What did you do?']",
#  "['What do you know about our business model",
#  'ow do ensure accuracy in your work',
#  'ow have you handled tight deadlines',
#  'ow do you stay motivated while doing repetitive tasks',
#  'escribe an accounting process that you developed or improved',
#  'escribe a time you helped your company reduce costs',
#  'ow would you set up an internal control system for processing invoices',
#  'hare your experience with accounts receivable and accounts payable',
#  'hich accounting software programs have you used',
#  "escribe your familiarity with accounting standards such as FASB and GAAP.']",
#  "['You need to retrieve data from a spreadsheet, but there are some formulas you don’t recognize. How would you go about getting what you need",
#  ' coworker asks to see the expense reports of another department. How would you respond',
#  'f you realized you made a mistake on a report, what would you do',
#  'hat information would you need to compile a report on accounts receivable',
#  'hat would you do if our system broke down while you were in the middle of a transaction? What would you tell a customer who was waiting for the transaction to go through',
#  'hat would you do if your manager gave you inadequate instructions for a process you were unfamiliar with',
#  'hat would you check first if you found a billing discrepancy',
#  'escribe your main duties as a Finance Clerk',
#  'hat accounting software have you used',
#  'hat recordkeeping system do you use to ensure records remain confidential',
#  'escribe the process of a bank reconciliation',
#  'hat types of documents do you need to verify an invoice',
#  'ow do you ensure data entry accuracy',
#  'ow do you prioritize your work when you have multiple duties',
#  'ow do you stay focused when dealing with repetitive tasks',
#  'ow do you learn about new finance regulations and laws',
#  "escribe a time when you had to complete a project under a tight deadline. How did you organize your schedule to make sure you wouldn’t fall behind?']",
#  "['What data would you collect to conduct a benchmark analysis",
#  'he CEO informs you they plan to make an investment (e.g. open a new store in a foreign country.) How would you begin advising them',
#  'hat factors would you take into consideration before advising a company to take (or not take) a loan',
#  'hat would you do if you found a mistake in a report you prepared but your manager hadn’t noticed',
#  'hat metrics would you present to investors to describe the company’s financial health',
#  'escribe the budgeting process step-by-step',
#  'hat financial and statistical analysis software have you used',
#  'hat kinds of reports do you prepare or monitor on a regular basis? How do you use this information',
#  'hat kind of financial model will help you build an annual forecasting report',
#  'hat’s the use of the Weighted Average Cost Of Capital (WACC)? How will an increase in debt affect it',
#  'hat is a good Internal Rate of Return (IRR) on an investment? What formula do you use to calculate it',
#  'escribe a time when you coordinated a challenging financial task, e.g. audits or tax collections',
#  'ive an example of a time when your attention to detail saved you from a making a mistake at work',
#  'ow do you learn about global economic issues? What are the biggest challenges that companies of our industry will face in the next years',
#  "ow would you describe your leadership style? How do you delegate tasks to your team members?']",
#  "['If hired, what are the biggest economic risks you would advise us on",
#  'hat kinds of investments would you recommend to increase our revenues within the next five years',
#  'f you want to prevent a manager from making an investment, how do you ensure they understand the risks',
#  's a positive cash flow enough to tell whether a company is profitable',
#  'e are planning to expand our business with two new stores/offices. What are your main responsibilities in this project',
#  'hat is your client portfolio',
#  'ow often do you evaluate the financial results for a company of our size',
#  'hat information do you use to forecast next year’s financial status? How do you organize your data and how do you present your results',
#  'ow do you check your work for accuracy? (e.g. ensuring correct data entry in large spreadsheets',
#  'hat financial analysis software do you use',
#  'hat metrics do you check when reviewing a department’s budget',
#  'hat are some ground rules you follow in designing investment models, regardless the client’s financial status',
#  'escribe a situation when you undervalued potential risks from an investment. What happened and what did you learn from that experience',
#  'ow do you ensure you’re up-to-date with finance industry developments and regulations? What resources (e.g. newspapers, blogs) do you follow',
#  'escribe a time when your advice to senior managers resulted in higher revenues',
#  'hat’s the most difficult loan/debt problem you’ve faced with a client? How did you address it',
#  "ow would you explain complex financial concepts in simple terms to managers who may not understand industry-speak?']",
#  "['What’s key to a healthy investment",
#  'ow would you explain liquidity risk management to a non-finance person',
#  'hen would you issue a debt and how',
#  'hat information do you need to measure interest rate risk',
#  'hat’s your experience in hedging',
#  'hat cash management software do you prefer and why',
#  'o you pay more attention to direct reports or subordinates',
#  'hat do you do to follow money markets',
#  'escribe a time where your good management allowed your company to save mone',
#  'ell me about a time you coached others towards succes',
#  'ave you ever had trouble enforcing a specific regulation? How did you handle\\xa0it',
#  'escribe a time you spotted a mistake in the company’s cash statement',
#  "xplain how you maintained good relationships with partners and/or\\xa0agencies\\xa0in your previous job']",
#  "['What would you do if revenue forecasts for next year decreased",
#  'f you had to decide whether a possible investment is profitable, how would you do it',
#  'xplain the evolution of the product of your current/previous company. Give me an example of a landmark decision that was made in the product strategy and your opinion of that decisio',
#  'hat type of customer does your company sell to? Has it changed',
#  'hat is a pricing or packaging decision that the company made and what was your view on that decision',
#  'hat was the personality of the company you were just working at and did it fit you',
#  "ive me an example of your investment strategy when funding departments during the annual budget cycle', 'What do you think was key to your current/previous company’s success",
#  'hat are two metrics a CFO should always monitor',
#  'ell me about a time when you faced conflict with stakeholders. How did you resolve it',
#  'ecall a time you showed excellent leadership in managing your departmen',
#  "escribe your most important contribution to your current/previous company']",
#  "['What visual aids would you use to deliver a presentation on a new financial plan to senior managers? Why",
#  'f you want to prevent a manager from making an investment, how do you ensure they understand the risks',
#  'e are planning to open a new store in the next two years. When does your role in this project begin and what do you think are your main responsibilities',
#  'ow would you help employees shift from a “this is how it’s always done” approach to embracing new processes you implement',
#  'hat are the first questions you ask about a new client or project',
#  'hat is your client portfolio',
#  'alk me through the process of assessing our current financial status',
#  'ow do you check your work for accuracy? (e.g. ensuring correct data entry in large spreadsheets',
#  'hat methods/metrics do you use to evaluate a company’s performance',
#  'hat is a cash flow statement? Is this enough to tell whether a company is profitable',
#  'hat financial management software do you have experience working with',
#  'n your opinion, what are the biggest untapped markets and most challenging financial regulations in our industry',
#  'ow do you stay up-to-date with changes to tax and investment regulations',
#  'ell me about a time your advice to senior managers resulted in higher revenues',
#  'escribe a time you used analytical skills to explain the risks of a potential investment',
#  'ave you ever made a bad financial decision? If so, what happened and what did you learn from that experience',
#  "o you prefer giving presentations or preparing written reports? Why?']",
#  "['What are the most important factors to consider in budget development",
#  'hat is the most challenging financial project you’ve ever worked on',
#  'ecall a time you identified a financial opportunity for your company',
#  'ow have you reduced expenses at previous companies',
#  'hat are the financial strengths and weaknesses of our industry',
#  'ow has your leadership contributed to the success of your current/previous team',
#  'ow have you increased revenues in previous companies you’ve worked for',
#  'ecall a time when you improved the quality of financial information or the efficiency of sharing financial information',
#  'hat kinds of reports or presentations have you developed for executive teams',
#  'o you have any experience in setting up accounting/financial reporting controls? If so, please give an example of a control you were able to design and implement',
#  'ecall a time when you introduced new technology to your staff',
#  'hat kind of accounting/financial reporting software are you familiar with',
#  'hat is your approach to hiring financial staff',
#  'ow have you helped junior financial staff advance in their careers',
#  'ecall a time you had to motivate your team to complete a complex project under a tight deadline',
#  'ow do you monitor and evaluate the performance of your team',
#  "ecall a time you had to persuade an executive team to make an important financial decision.']",
#  "['How would you describe your leadership style",
#  'escribe a time you led by example',
#  'hat’s your approach to delegating employees? How do you ensure that tasks are carried out to completion',
#  'escribe someone you coached or mentored. What were they doing initially, and what are they doing now',
#  'ow would you tell a colleague that he/she was underperforming',
#  'alk about the time you led an important meeting',
#  'alk about a successful work project involving multiple teams. What was your role in facilitating the project? What was the result',
#  'ave you ever had to execute a project with a small budget, or a lack of resources? How did you address these issues',
#  'ell me about a time when your team was struggling to meet business goals. What happened? What did you do about it',
#  'alk about a successful work project. What was your goal? What was the result',
#  'hat changes did you make that resulted in increasing productivity, improving efficiency, or lowering costs',
#  'alk us through a typical day at your last position. How do you prioritize your tasks',
#  'hat are some industry trends that have an impact on your role as a manager',
#  "hy are you interested in our company? What is the relationship between this job and your career goals?']",
#  "['What information would you keep in a spreadsheet about incoming mail? (e.g. date, sender, description",
#  'n which cases do you think express delivery is appropriate',
#  'hat would you do if a customer/partner claimed they had sent a package two weeks ago, but you hadn’t received it yet',
#  'hat would you do if you realized you sent a package to the wrong address',
#  'hat resources do you use to check how much a delivery costs',
#  'escribe a regular day at work as a Mail Clerk. What are your main responsibilities',
#  'hat’s the process you follow to send a package to a client? Mention if and how you weigh the package and how you verify the recipient’s address',
#  'escribe how you organize incoming mail. How and when do you distribute mail to appropriate departments or employees',
#  'hat office equipment have you used before',
#  'escribe a time when your attention to detail saved you from making a mistake in the mailroom',
#  'his job can be repetitive. How do you stay motivated',
#  'ow do you prioritize tasks? (e.g. when you have to send packages to multiple clients',
#  "s part of your job, you will have to handle personal data and sensitive information. How will you ensure its confidentiality?']",
#  "['You booked a venue for a company conference, but a day before the event, you learn that there has been a mix-up and it’s not available. What do you do",
#  'hat information would you ask for from new hires in order to update the company’s employee records',
#  'f you have no specific deadlines, how do you prioritize work from different departments',
#  'our manager assigns you with a task you’re not familiar with and doesn’t give you clear instructions. How would you approach this',
#  'hat’s your experience with office equipment? (e.g. printers, scanners and fax machines',
#  'ow do you keep digital and physical records organized and how often do you update them',
#  'ow do you organize your daily workload? Which time management and/or calendar tools do you use, if any',
#  'ow do you create a report on expenditures in Excel',
#  'ow do you check your data-entry work for accuracy',
#  'ave you ever been on a team with a difficult coworker? Tell us about the situation. How did you handle it',
#  'escribe a time you helped complete a project before its due date and under budget',
#  'hat keeps you motivated during repetitive tasks',
#  "uring a project, do you prefer working on a team or individually? Why?']",
#  "['You spot a mistake in a contract that we’ve used for a long time, but bringing it up means our company will have to pay a fine. What would you do",
#  'ow would you search for a 10-year-old contract in a digital database if you didn’t know the file name',
#  'ow would you ensure both digital and physical contracts remain confidential',
#  'ow would you handle a situation where an employee or business partner doesn’t honor a contract agreement with us',
#  'hat’s the best way to organize physical records of contracts',
#  'ow do you file updates to contracts',
#  'ow do you keep track of deadlines (e.g. when each contract needs to be signed and submitted?',
#  'ow do you prioritize your workload when you have many contracts to review',
#  'hat resources do you use when writing terms of use for sales contracts',
#  'ow do you stay up-to-date with legislative changes in this field',
#  'escribe a time when you had to explain complex contract terms to your managers. How did you ensure they complied with all requirements',
#  'hat’s your experience with negotiating contract terms? How do you make sure that the interested parties reach an agreement',
#  'ave you ever missed a deadline? If so, what happened and how did you inform your manager or client',
#  "escribe a time when you had to monitor future expenditures of a contract. How did you do it?']",
#  "['What would you do if you had an urgent question, but couldn’t find anyone online",
#  'hat would you do if you were working under a tight deadline and your computer crashed',
#  'ou need important information from a co-worker who’s in a different time zone and won’t be available for the next four hours. How and when do you choose to communicate your request? Why',
#  'ow would you organize employees’ contact information (e.g. in a spreadsheet) to ensure you have all necessary information in-hand and updated',
#  'ow do you ensure accuracy in routine tasks such as processing expenses and preparing reports',
#  'hat calendar management tools have you used',
#  'hat’s your familiarity with online group communication tools? (e.g. Skype, Hangouts, Slack',
#  'escribe the steps you’d take to plan a meeting for 10 people',
#  'ow do you make sure you find the best deal when booking travel accommodations',
#  'hen you work from home, how do you juggle personal matters (e.g. phone calls or distractions from family members) with getting your work done',
#  'ow do you stay motivated during repetitive tasks',
#  'o you have experience working as part of a distributed team or working remotely? What do you think are its biggest challenges',
#  "ow do you prioritize work when you don’t have specific deadlines?']",
#  "['How would you motivate a team member who seems discouraged or lacks energy",
#  'ow would you mitigate a dispute between two team members who were arguing over their project responsibilities',
#  'f your team members considered a goal unrealistic, how would you change their minds',
#  ' manager from a different department wants to collaborate with a member of your team. How would you handle this request',
#  'wo employees left from your team just before the deadline on a big project. How would you change your leadership style to meet the deadline',
#  'ou learn that one of your top performers is stealing the company’s stationery. How would you handle this situation',
#  'hich performance appraisal systems have you previously used',
#  'ow do you prefer to communicate with your team',
#  'ave you participated in or organized team-building activities? What were they',
#  'ow do you keep track of tasks and goals? Name any productivity tools you’ve used',
#  'o you prefer to provide individual or team-wide feedback? Why? (Or, in which cases do you choose each approach?',
#  'hat’s the most difficult part of your job',
#  'o you have experience laying off an employee? If so, how did you handle the situation',
#  'hat onboarding processes do you use for new team members',
#  "ell me about a time your team successfully completed a challenging project. What did you do to keep employees on track and motivated?']",
#  "['How would you describe your leadership style",
#  'escribe a time you led by example',
#  'hat’s your approach to delegating employees? How do you ensure that tasks are carried out to completion',
#  'escribe someone you coached or mentored. What were they doing initially, and what are they doing now',
#  'alk about the time you led an important meeting',
#  'alk about a successful work project involving multiple teams. What was your role in facilitating the project? What was the result',
#  'ave you ever had to execute a project with a small budget, or a lack of resources? How did you address these issues',
#  'alk about a successful work project. What was your goal? What was the result',
#  'hat changes did you make that resulted in increasing productivity, improving efficiency, or lowering costs',
#  'alk us through a typical day at your last position. How do you prioritize your tasks',
#  'hat are some industry trends that have an impact on your role as a manager',
#  "hat did you learn about our company in your research? Why do you think you are a strong fit for this role?']",
#  "['If an important decision had to be made, but you couldn’t reach the manager, what would you do",
#  'magine there are too many customers on a particular day and employees are barely managing to attend to all of them. Given that customer service standards are beginning to slip, how would you handle this',
#  'hat would you do if an employee was underperforming',
#  'f you had to attend to customers, the manager and a shipment at the same time, what would you do',
#  'hy does a department need an assistant manager',
#  'hat kind of reports should an assistant manager prepare',
#  'ow do you decide how to delegate responsibilities',
#  'o you mind working with targets',
#  'hat’s your experience with hiring personnel',
#  'hat financial statements do you have experience with',
#  "ecall a time you showed excellent customer service', 'Tell me about a time you had to fire someone. What was the reason and how did you do it",
#  'ave you ever made a mistake as an assistant manager? What happened',
#  'ive me an example of a time you reviewed a process to make it more efficien',
#  'ell me about a time you took the lead over a difficult project and helped the team achieve succes',
#  'escribe a time you had to make a decision without adequate information. How did you do it',
#  "ell me about a time you had a conflict with your supervisor. How did you resolve it?']",
#  "['What are the most common reasons that projects fail",
#  'hen having to monitor different projects, how do you prioritize them',
#  'f you were assigned a program with a 6-month deadline, how would go about planning and delivering outcome',
#  'magine you’re halfway through the completion of a program, when there’s a change in the company’s business strategy or objectives. How would you handle this',
#  'hat does a program manager do that project managers don’t',
#  'hat’s the role of technology in program management',
#  'hich metrics do you use most frequently',
#  'hat’s your experience with program charters',
#  're you familiar with the PMI code of ethics',
#  'hat would you use six sigma for',
#  'hy is change management important for this role',
#  'ow do you avoid scope creep',
#  'ow do you keep up with industry trends',
#  'escribe the most recent program you managed. What was your contribution',
#  'ell me about the biggest challenge you’ve faced while managing a team of project manager',
#  'ow did you measure the success of deliverables in your last program? How did you choose the best metrics',
#  'escribe how you developed a budget and allocated resources for a past progra',
#  'ave you ever had to deal with a program that was falling behind schedule',
#  'ave you ever faced a communication problem while managing a program? Who with and how did you resolve it',
#  "ell me about a time you found it difficult to negotiate with a sponsor/stakeholder. What did you do?']",
#  "['Imagine you have to schedule and plan a conference from start to finish. What things would you consider and what steps would you follow",
#  'hat would you do if an internal client were bothering you with insignificant questions while you had an important task to finish',
#  'ow has your background prepared you for this role',
#  'ow do you think you can contribute to this position',
#  'hat’s your experience with budgeting/bookkeeping',
#  'hat kind of technology tools/software should a program coordinator be familiar with? How proficient are you in using them',
#  'o you have experience in dealing with diversity? How do you increase diversity awareness',
#  'hat’s your experience with fundraising',
#  'ate your skills in creating proposals/presentations on a scale of 1 to 1',
#  'his role involves managing multiple objectives simultaneously. How do you manage your time and prioritize tasks',
# ...
#  'ow does the PageRank algorithm work',
#  'hat is dependency parsing',
#  'hat are the difficulties in building and using an annotated corpus of text such as the Brown Corpus and what can be done to mitigate them',
#  'hat tools for training NLP models (nltk, Apache OpenNLP, GATE, MALLET etc…) have you used',
#  'o you have any experience in building ontologies',
#  're you familiar with WordNet or other related linguistic resources',
#  "o you speak any foreign languages?',]",
#  "['What type of problem does the model try to solve",
#  's it prone to over-fitting? If so – what can be done about this',
#  'oes the model make any important assumptions about the data? When might these be unrealistic? How do we examine the data to test whether these assumptions are satisfied',
#  'oes the model have convergence problems? Does it have a random component or will the same training data always generate the same model? How do we deal with random effects in training',
#  'hat types of data (numerical, categorical etc…) can the model handle',
#  'an the model handle missing data? What could we do if we find missing fields in our data',
#  'ow interpretable is the model',
#  'hat alternative models might we use for the same type of problem that this one attempts to solve, and how does it compare to those',
#  'an we update the model without retraining it from the beginning',
#  'ow fast is prediction compared to other models? How fast is training compared to other models',
#  'oes the model have any meta-parameters and thus require tuning? How do we do this',
#  'hat is the EM algorithm? Give a couple of application',
#  'hat is deep learning and what are some of the main characteristics that distinguish it from traditional machine learnin',
#  'hat is linear in a generalized linear model',
#  'hat is a probabilistic graphical model? What is the difference between Markov networks and Bayesian networks',
#  'ive an example of an application of non-negative matrix factorizatio',
#  'n what type of ensemble technique is a random forest based? What particular limitation does it try to address',
#  'hat methods for dimensionality reduction do you know and how do they compare with each other',
#  'hat are some good ways for performing feature selection that do not involve exhaustive search',
#  'ow would you evaluate the quality of the clusters that are generated by a run of K-means',
#  'o you have any research experience in machine learning or a related field? Do you have any publications',
#  'hat tools and environments have you used to train and assess models',
#  "o you have experience with Spark ML or another platform for building machine learning models using very large datasets?']",
#  "['Discuss the common pitfalls and risks in planning a data science project such as building a model that predicts whether a bank customer will default on their loan",
#  'hat is the biggest team that you have ever managed and what challenges had you faced',
#  'o you have experience in managing agile teams',
#  ' model your team has built performs 90% accuracy. What do you need to know in order to interpret whether this is good or not',
#  'iscuss a data-driven product that has really impressed you in recent year',
#  'ow do you think one becomes a data scientist? What do you look for when you want someone to join your team',
#  'hat is big data, really? Are you familiar with big data architectures',
#  'ff the top of your head describe a product that uses data from twitter to build something that people could conceivably pay money for',
#  'ow do you stay current in your job and what are the challenges to doing this when you are a data scientis',
#  "ow would you evaluate a feature such as Spotify’s Discover Weekly playlist?']",
#  "['Using pseudo-code, implement binary search of a sorted array of integer",
#  'hat constitutes a good unit test and what a functional one',
#  'escribe the core principles of a REST API. How is this a different philosophy from RPC',
#  'o arguments in Python get passed by reference or by value',
#  'hy are functions considered first class objects in Python',
#  'hat tools do you use for linting, debugging and profiling',
#  'ive an example of filter and reduce over an iterable objec',
#  'hat are list and dict comprehensions',
#  'hat do we mean when we say that a certain Lambda expression forms a closure',
#  'ame a few differences between Python 2.x and 3.',
#  'ow is memory managed in python?\', "What will be the output of the following code?\\nlist = [\'a\', \'b\', \'c\', \'d\', \'e\']print list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]\\n", \'Python uses a Global Interpreter Lock. Does that mean it doesn’t use real threads',
#  's it possible to have a producer thread reading from the network and a consumer thread writing to a file, really work in parallel? What about the GIL',
#  ' palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99. Find the largest palindrome made from the product of two 3-digit numbers',
#  "hat will be the output of the following code in each step?\\nclass C:  dangerous = 2c1 = C()c2 = C()print c1.dangerousc1.dangerous = 3print c1.dangerousprint c2.dangerousdel c1.dangerousprint c1.dangerousC.dangerous = 3print c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous\\n\\nc1.dangerous = 3\\nprint c1.dangerous\\nprint c2.dangerous\\n\\ndel c1.dangerous\\nprint c1.dangerous\\n\\nC.dangerous = 3\\nprint c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous\\n\\nc1.dangerous = 3\\nprint c1.dangerous\\nprint c2.dangerous\\n\\ndel c1.dangerous\\nprint c1.dangerous\\n\\nC.dangerous = 3\\nprint c2.dangerous\\n']",
#  "['Using pseudo-code, reverse a String iteratively and recursivel",
#  'hat constitutes a good unit test and what a functional one',
#  'o arguments in Python get passed by reference or by value',
#  'hy are functions considered first class objects in Python',
#  'hat tools do you use for linting, debugging and profiling',
#  'ive an example of filter and reduce over an iterable objec',
#  'mplement the linux whereis command that locates the binary, source, and manual page files for a command',
#  'hat are list and dict comprehensions',
#  'hat do we mean when we say that a certain Lambda expression forms a closure',
#  'hat is the difference between list and tuple?\', "What will be the output of the following code?\\nlist = [\'a\', \'b\', \'c\', \'d\', \'e\']print list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]\\n", \'What will be the output of the following code in each step?\\nclass C:  dangerous = 2c1 = C()c2 = C()print c1.dangerous c1.dangerous = 3print c1.dangerous print c2.dangerous del c1.dangerousprint c1.dangerous C.dangerous = 3print c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous \\n\\nc1.dangerous = 3\\nprint c1.dangerous \\nprint c2.dangerous \\n\\ndel c1.dangerous\\nprint c1.dangerous \\n\\nC.dangerous = 3\\nprint c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous \\n\\nc1.dangerous = 3\\nprint c1.dangerous \\nprint c2.dangerous \\n\\ndel c1.dangerous\\nprint c1.dangerous \\n\\nC.dangerous = 3\\nprint c2.dangerous\\n\\n\']',
#  "['Using pseudo-code, reverse a String iteratively and recursivel",
#  'hat constitutes a good unit test and what a functional one',
#  'escribe the core principles of a REST API. How is this a different philosophy from RPC',
#  'hen do you think is the best time in a project’s lifecycle, to set up its test infrastructure',
#  'hat do you expect to find in a regression test suite and why',
#  'hat constitutes a good unit test and what a functional one',
#  'o arguments in Ruby get passed by reference or by value',
#  'hat tools do you use for linting, debugging and profiling',
#  'uby MRI uses a Global Interpreter Lock. Does that mean it doesn’t use real threads',
#  'hat do we mean when we say that a lambda or block forms a closure',
#  'hat’s the following program going to print?\\nx = 1class MyClass  y = 2 def foo     z = 4     y ||= 0     puts z + y end  define_method :bar do |x|     z = 5     y ||= 0     puts z + y + x endendmy_class = MyClass.newmy_class.foomy_class.bar(10)my_class.barx = 1\\nclass MyClass\\n  y = 2\\n  def foo\\n     z = 4\\n     y ||= 0\\n     puts z + y\\n  end\\n  define_method :bar do |x|\\n     z = 5\\n     y ||= 0\\n     puts z + y + x\\n  end\\nend\\nmy_class = MyClass.new\\nmy_class.foo\\nmy_class.bar(10)\\nmy_class.barx = 1\\nclass MyClass\\n  y = 2\\n  def foo\\n     z = 4\\n     y ||= 0\\n     puts z + y\\n  end\\n  define_method :bar do |x|\\n     z = 5\\n     y ||= 0\\n     puts z + y + x\\n  end\\nend\\nmy_class = MyClass.new\\nmy_class.foo\\nmy_class.bar(10)\\nmy_class.bar\\',
#  'ow is a block different from a Proc ',
#  's it possible to have a producer thread reading from the network and a consumer thread writing to a file, really work in parallel? What about the GIL',
#  'uby 2.1 introduced generational garbage collection. Describe how that works and why it’s considered an improvement',
#  'rite a single line of Ruby code that prints the Fibonacci sequence of any length as an array',
#  "mplement a class macro :benchmark that can be used to print the time an instance method takes to execute (advanced).\\nclass Foo def bar     ... end  def qux     ... end  benchmark :bar, :quxendfoo = Foo.newfoo.bar# => bar took 0.12 msfoo.qux# => qux took 1.15 msclass Foo\\n  def bar\\n     ...\\n  end\\n \\n  def qux\\n     ...\\n  end\\n  benchmark :bar, :qux\\nend\\nfoo = Foo.new\\nfoo.bar\\n# => bar took 0.12 ms\\nfoo.qux\\n# => qux took 1.15 msclass Foo\\n  def bar\\n     ...\\n  end\\n \\n  def qux\\n     ...\\n  end\\n  benchmark :bar, :qux\\nend\\nfoo = Foo.new\\nfoo.bar\\n# => bar took 0.12 ms\\nfoo.qux\\n# => qux took 1.15 ms\\n']",
#  "['What does a Just in Time compiler has to offer? Do you know of any programming language runtimes that use one",
#  'ow is a preemptive threading model different from the cooperative threading model',
#  'hat tools & practices would you consider necessary for a Continuous Delivery solution',
#  'ow is a code point related to a code unit in Unicode',
#  'hat do you think makes a unit test good? What about functional ones',
#  'ow does MSIL (intermediate language) fit into the whole .NET framework architecture',
#  'hat do you mean by polymorphism, inheritance and encapsulation',
#  'hat is the await keyword? Describe a use case and the needed code modifications in order to use it',
#  'ow can lazy initialization be accomplished in .NET',
#  "lease explain the “virtual” keyword', 'Why would you declare a field as volatile",
#  'hat is the Entity Framework and what are the benefits of using it',
#  'hat is Reflection in .NET? Please describe a use case and the benefits of using it',
#  'hat is the dynamic type in .NET? Please describe a use case',
#  'hat do we mean when we say that a certain Lambda expression forms a closure',
#  'ow are anonymous classes instantiated in .NET? Can they be passed as function params',
#  'n LINQ, what is the difference between the IQueryable and IEnumerable interface',
#  'hat are the benefits of using the Aggregate method in LINQ',
#  's it possible in .NET to extend a class (any class) with some extra methods? If yes, how can it be accomplished',
#  "n .NET, attributes are a method of associating declarative information with C# code. Please describe the way they are used and a proper use case.']",
#  "['What does a Just in Time compiler have to offer? Do you know of any programming language runtimes that use one",
#  'ow is preemptive threading model different from the cooperative threading model',
#  'hat tools & practices would you consider necessary for a Continuous Delivery solution',
#  'ow is a code point related to a code unit in Unicode',
#  'hat do you think makes a unit test good? What about functional ones',
#  'o arguments in Java get passed by reference or by value',
#  'hy would it be pointless for a static or final method to use dynamic binding',
#  'ow is Java SE related to Java EE',
#  'ow are Runtime exceptions different from Checked exceptions',
#  'hat are the most important features introduced in Java 5, 7 and 8 respectively',
#  's ForkJoinPool introduced in Java 7 always a better alternative to ThreadPoolExecutor',
#  'hat is the difference between HashMap, ConcurrentHashMap and Map returned by Collections.synchronizedMa',
#  'ou want to synchronize 5 threads to start at the same time. Describe a solution',
#  'hat is a weak reference and how could it be useful to us',
#  'hoose a Java EE platform API and give a short description of it',
#  'n a 3-tier application running a Java application server you notice freezes for several seconds during high load. What are the most likely reasons? How would you troubleshoot them',
#  'ervlets 3.0 introduced async support. Describe a use case for it',
#  'hy do you think lambda expressions are considered such a big thing for Java 8',
#  'hat do you know about the Java Scripting API? Can you think of a use case',
#  "s this possible in Java?\\nA extends B, CA extends B, CA extends B, C\\n']",
#  "['How do you know if a linked list has a cycle in it? As in, one of the nodes in the linked list points to a previous node in the list",
#  'ow is preemptive threading model different from the cooperative threading model',
#  'hat tools & practices would you consider necessary for a Continuous Delivery solution',
#  's Java a statically or dynamically typed language',
#  'o arguments in Java get passed by reference or by value',
#  'hat is the difference between an abstract class and an interface and when would you use one over the other',
#  'hat is a factory pattern and how would you implement the Singleton pattern',
#  'hat is the difference between “==” and equals(…) method? What is the difference between shallow comparison and deep comparison of objects',
#  'ow is Java SE related to Java EE',
#  'ow are Runtime exceptions different from Checked exceptions',
#  'hat are the most important features introduced in Java 5, 7 and 8 respectively',
#  'hoose a Java EE platform API and give a short description of it',
#  'n a 3-tier application running a Java application server you notice freezes for several seconds during high load. What are the most likely reasons? How would you troubleshoot them',
#  'ervlets 3.0 introduced async support. Describe a use case for it',
#  'hy do you think lambda expressions are considered such a big thing for Java 8',
#  "s this possible in Java?\\nA extends B, CA extends B, CA extends B, C\\n']",
#  "['How would you approach unrealistic requests of your team from executives or other teams",
#  'f we wanted to redesign our corporate website, how would you go about gathering user and system requirements',
#  'ell me about an application you regularly use. How would you improve its functionality',
#  'f a developer on your team is underperforming, when and how would you approach them',
#  'ou have an idea you want to try out quickly. What tools would you use to prototype it',
#  'alk me through the process of creating a web page from scratch',
#  'ow do you check other people’s code for bugs',
#  'rovide a basic overview of push technology. What are its benefits and drawbacks',
#  'ow can Page Visibility API be useful',
#  'hat user interface and security principles do you consider when building a website or online application',
#  'escribe a time when your program didn’t run. How did you troubleshoot your code',
#  'as your team ever failed to meet a deadline? What went wrong and how did you address the situation',
#  'ow do you help your team members improve their coding skills? Do you conduct on-the-job coaching or encourage them to attend meetups and conferences',
#  'ow do you handle conflicts on your team',
#  "ow do you stay current with the latest technology developments?']",
#  ...]

# %%
len(all_questions)
# Out:
# 4342

# %% [markdown]
# There are **4342** total questions

# %%
set_allquestions=set(all_questions)
unique_questions=list(set_allquestions)
len(unique_questions)
# Out:
# 4141

# %% [markdown]
# There are **4141** different questions

# %%
num_repeated_questions=len(all_questions)-len(unique_questions)
num_repeated_questions
# Out:
# 201

# %% [markdown]
# There are **201** question repetitions

# %% [markdown]
# Now, we are going to create a frequency table of questions to double check total number and repetitions:

# %%
questions_freq={}
for questions in df["questions"]:
    for question in questions:
        if question in questions_freq.keys():
            questions_freq[question]+=1
        else:
            questions_freq[question]=1
            
questions_freq
# Out:
# {"['A debtor has missed six months of payments. When you call the individual, they bring up financial difficulties and get emotional. How do you handle this": 1,
#  'hat payback plan would you recommend for a long-term client whose payments are due to be collected in X months': 1,
#  'f you called a client to update them on their payment status and they were aggressive or rude to you, how would you handle it': 1,
#  'an you think of a few common excuses that debtors make? How would you respond to each of them': 1,
#  'hat collection methods do you know? Which technique do you think would be more effective for our company/clients': 1,
#  'ow do you keep historical data for each account': 1,
#  'ow often do you follow up with delinquent account holders and what’s your approach when you get in touch': 1,
#  'ention three things a Collection Specialist should avoid saying when speaking to a debtor': 1,
#  'ow do you keep track of all payments': 1,
#  'hat software do you use to increase your productivity': 1,
#  'hat do you find interesting about this job': 1,
#  'escribe a time you had to deal with a difficult client. How did you handle the situation': 1,
#  'escribe a time you persuaded a client to pay off a large debt. How did you handle it, from beginning to end': 1,
#  'ave you ever faced an ethical dilemma at work? If so, what was the situation and what did you do': 1,
#  'ave your negotiations with a creditor ever failed? If so, what would you do different': 1,
#  "ow does empathy help you build trusting, long-term relationships? Give an example of a time when you were able to better understand and address a client’s needs.']": 1,
#  "['How would you create a report on debts from the previous quarter": 1,
#  'ow would you contact clients who haven’t paid their bills': 1,
#  'f a long-term client had a debt at the end of the fiscal year, how would you address it with him/her': 1,
#  'ow would you make sure we collect invoices in a timely manner': 1,
#  'ow would you handle an invoice discrepancy with a client': 1,
#  'riefly explain the financial transactions involved in the billing process and your experience with each': 1,
#  'hat accounting software have you used': 3,
#  'ow do you keep updated records of accounts receivable from clients': 1,
#  'ow do you ensure financial information remains confidential': 1,
#  'hat are your responsibilities during annual audits': 1,
#  'ave you ever made a mistake at work (e.g. a wrong calculation)? How did you figure it out and what happened': 1,
#  'ow do you manage to meet tight deadlines': 1,
#  'ow do you stay up-to-date with new financial regulations? Do you read any specific blogs, magazines or newspapers? If so, what are they': 1,
#  "hat keeps you motivated during repetitive tasks?']": 1,
#  "['What would you do if you received a B-Notice on behalf of your client": 1,
#  'hat information would you use to create a forecasting report for next year’s tax returns': 1,
#  'ou thought the deadline for tax payment submission was in a month, but it’s actually in a week. How would you handle this': 1,
#  'ow would you inform your manager that your company needs to pay a fine because you weren’t aware of a regulatory change': 1,
#  'hat accounting software are you familiar with': 1,
#  'hat monthly and annual reports do you create': 1,
#  'hat information do you need to submit a 1096? What’s different when you e-file a 1099': 1,
#  'hat is an IRS Backup Withholding Notice': 1,
#  'ow do you avoid numerical errors in your reports': 1,
#  'hat attracted you to tax accounting versus other fields, like forensic or auditing': 1,
#  'ow do you stay on top of regulatory changes': 1,
#  'ow do you keep up to date on global economic issues': 1,
#  'escribe a time you saved your client/employer money': 1,
#  "ave you ever faced an ethical dilemma at work? If so, how did you manage it?']": 1,
#  "['What would be the first thing you’d check if you found a billing discrepancy": 1,
#  'ow would you negotiate with a client who has a debt': 1,
#  'hat are the steps you would take to close the accounts receivable period': 1,
#  'hat time management tips would you give to a newly-hired Accounts Receivable Clerk': 1,
#  'hat information would you use to forecast next month’s payments': 1,
#  'hat objectives would you set for your team? (monthly, quarterly and annual goals': 1,
#  'hat accounting software have you used? How do they facilitate your daily tasks': 1,
#  'riefly describe the steps of the journal entry process': 1,
#  'ow often do you conduct bank reconciliation? Why': 1,
#  'hat accounting reports do you create on a regular basis': 1,
#  'hat data do you include in an invoice for services rendered': 1,
#  'ow do you prefer to share the results from your team: with a detailed report or a verbal presentation? Why': 1,
#  'ow do you handle inconsistent payments from clients': 1,
#  'ow do you evaluate employee performance? Tell us about a time you had to deliver a negative review to one of your team members': 1,
#  'ave you ever made a mistake at work that cost you (or your company) money? If so, what was the situation and what did you learn from that experience': 1,
#  'ow do you check your work for accuracy and how do you ensure you meet all deadlines': 1,
#  "ow do you stay up-to-date with changes in finance legislation?']": 1,
#  "['If you could use only Excel, how would you organize the company’s fixed costs to ensure they’re accurate and accessible": 1,
#  'f the CEO asked you to help decide if opening a new branch would be profitable, how would you go about analyzing the situation': 1,
#  'hat information would you need to forecast quarterly and annual costs': 1,
#  ' manager has trouble understanding charts and asks you to explain a report in simple terms. How would you explain a budgeting report to the manager': 1,
#  'e are in front of a business opportunity that involves taking big risks but has large profit margins. What data would you collect and analyze to help us make a decision': 1,
#  'n which cases do you use discounted cash flow (DCF)': 1,
#  'ow familiar are you with SFAS (Statement of Financial Accounting Standards)': 3,
#  'ow do you check data accuracy in large spreadsheets': 1,
#  'hat accounting software have you previously used': 1,
#  'hat invoice processing systems do you know': 1,
#  'ave you ever suggested a way to improve a regular accounting process? What was it': 1,
#  'ow do you stay up-to-date with changes to financial regulations': 1,
#  'ave you ever made a mistake in calculations that resulted in false forecasts? How did you find out about the mistake and what did you do to correct it': 1,
#  'ow do you manage workflow under tight deadlines': 1,
#  "ave you ever discovered a cost-effective solution? If yes, what was it, and how did you present your idea to senior managers?']": 1,
#  "['If you missed the deadline for paying our company’s taxes, what would you do? How would you inform your manager if we had to pay a fine, in this case": 1,
#  'ow would you help a manager decide if an investment was a good idea': 1,
#  'ow would you set up an internal control system for processing invoices': 2,
#  'f you had to explain a financial procedure to non-financial audience, how would you ensure they understand all the details? For example, tell us in plain terms about the process of preparing a department’s budget': 1,
#  'hat accounting software have you used? What features increase your productivity': 1,
#  'ow do you check large datasheets for accuracy': 1,
#  'escribe your familiarity with accounting standards such as FASB and GAAP': 1,
#  'hat information and tools do you need to create an annual tax return forecast': 1,
#  'here and how do you use discounted cash flow (DCF)': 1,
#  'hat is your role in the month-end closing process': 1,
#  'escribe a time when you helped your company or a client decrease costs': 1,
#  'ow do you keep up with tax law changes': 1,
#  'ecall a time you analyzed financial risks and prevented senior executives from making a bad investment': 1,
#  'ow do you stay motivated while doing repetitive tasks, like processing invoices': 1,
#  "escribe a time when your attention to detail saved you from making a mistake at work (e.g. in a report.)']": 1,
#  "['What measures would you take if you discovered an invoice discrepancy": 1,
#  'hat goals would you set for your team during your first year? How would you keep track of progress': 1,
#  'hat would you do if you found a mistake in a report you prepared but your manager hadn’t noticed': 2,
#  'hat transactions should Junior Accountants know and how would you train them on more advanced financial topics': 1,
#  'hat accounting software do you use': 1,
#  'ow do you check a report for numerical errors': 1,
#  'hat’s your role during regular tax audits': 1,
#  'hat financial data and metrics do you use to prepare a department’s annual budget': 1,
#  'hat reports and invoices do you gather and manage during the year-end closing': 1,
#  'ow do you stay up-to-date with changes in accounting legislation': 1,
#  'ell us about a time your attention to detail saved you from making a mistake (e.g. in a forecasting report.': 1,
#  'escribe the most challenging financial project you’ve managed so far. How did you overcome difficulties': 1,
#  "escribe a time when you motivated your team to achieve goals. What team management techniques did you use?']": 1,
#  "['What would you do if a client/manager asked you to cover up fraud": 1,
#  'f a high-performer on your team started delivering reports with errors, how would you handle it': 1,
#  'f hired, how would you convince your team members to adjust to your way of working': 1,
#  'f you discovered that a process in our company is not as cost-effective as it could be, how would you present your findings to senior executives': 1,
#  'ave you used any audit software or Computer Assisted Audit Techniques (CAATs?) If so, which ones and how have they helped you': 1,
#  'ow do you check other people’s work for accuracy (e.g. reports or flowcharts?': 1,
#  'ow do periodical internal audits add value to a company': 1,
#  'hat control management processes do you apply to minimize risks': 1,
#  'hat’s your experience with accounting software like Zoho or QuickBooks': 1,
#  'alk me through your fraud detection process': 1,
#  'ave you ever suggested an improvement in the audit process? If so, what was it and why was or wasn’t it finally implemented': 1,
#  'escribe a time when your attention to detail helped you detect a potential law violation': 1,
#  'ow do you keep up with changes in accounting regulations': 1,
#  "ave you ever made a mistake at work? If so, what was it and what did you do to resolve the problem? If not, how do you check your work for accuracy?']": 1,
#  "['Describe your typical day at your current/previous job. How do you prioritize your work": 1,
#  'ow would you rate your proficiency with Microsoft Office programs, especially Excel': 1,
#  'escribe your familiarity with billing and invoice software': 1,
#  'ow many invoices do you handle on a daily basis': 1,
#  'escribe a time you had an invoice discrepancy with a client. How did you resolve it': 1,
#  'xplain the financial transactions involved in the billing process and your experience with each (i.e. classifying, computing, posting, verifying, recording': 1,
#  'ow do you keep track of incoming payments and ensure that it is in compliance with financial procedures? How  do you ensure that they’re properly posted and accounted for': 1,
#  'ow do you ensure the timely collection of invoices': 1,
#  'escribe your most hostile payment collection call. How did you handle it': 1,
#  'escribe a time you went the extra mile to deliver excellent customer service': 1,
#  'escribe a time you worked with a team to complete a project on a tight deadline': 1,
#  's a billing specialist, have you ever faced an ethical dilemma at work? How did you respond': 1,
#  'hat skills do you deem necessary for a billing specialist with our firm. Do you think you possess these skills': 1,
#  "his job can be repetitive. What motivates you to do well?']": 2,
#  "['What data would you present to inform your manager about significant debts from clients": 1,
#  'hat would you say to customers who haven’t paid their bills, if we were close to the end of the fiscal year': 1,
#  'hat would you check first if you found a billing discrepancy': 2,
#  'ow would you make sure we collected invoices in a timely manner': 1,
#  'hat would you do if you realized you made a numerical mistake on an invoice right after you issued it': 1,
#  'hat are a Billing Clerk’s tasks when a customer makes a digital order': 1,
#  'ow do you keep track of payments': 1,
#  'ow often do you update the accounts receivable report': 1,
#  'hat is your experience with accounting software? (e.g. QuickBooks': 1,
#  'hat’s the most effective way to keep records of invoices': 1,
#  'hat bookkeeping tasks are you familiar with': 1,
#  'ow do you make sure financial documents remain confidential': 1,
#  'ave you ever had an invoice discrepancy with a client? How did you resolve it': 1,
#  'ell us about a time you had a tight deadline for a project. How did you manage to complete it in time': 1,
#  'his job can be repetitive. What motivates you to perform routine tasks': 1,
#  "ow do you stay up-to-date with new financial regulations?']": 1,
#  "['What data would you collect to forecast next year’s tax returns": 1,
#  'hat would you do if you found significant numerical errors in a tax estimation only after you sent your report to a client': 1,
#  'ow would you check the accuracy of an accountant’s work': 1,
#  'ow would you present in simple terms the tax risks a client would face by making an investment': 1,
#  'hat are the main differences between state and federal taxes': 1,
#  'hat kind of accounting software have you used': 1,
#  'ow do you organize physical records of important paperwork': 1,
#  'ow do you manage foreign affiliate returns': 1,
#  'o you have experience with employee performance? How do you give feedback to your team members': 1,
#  'ave you ever faced an ethical dilemma at work? If so, how did you manage it': 1,
#  'escribe a time you helped a company minimize its tax obligations': 1,
#  'ow do you stay up-to-date with changes in finance law? For example, do you read any job-related forums or magazines': 1,
#  "ow do you manage deadlines when working for different clients at the same time?']": 1,
#  "['What steps do you take in preparing a budget": 1,
#  'escribe your experience with financial forecasting and projections.': 1,
#  'ow do you stay current on accounting and auditing standards': 1,
#  'ow do you keep track of what you’ve delegated to your team': 1,
#  'ow do you monitor your team’s performance': 2,
#  'ow do you go about directing internal and external audits': 1,
#  'hat is your experience presenting financial data to non-financial staff': 1,
#  'escribe a time you persuaded leadership to make a decision based on financial data': 1,
#  'ow do you explain complicated processes to staff members': 1,
#  'escribe a time you were dissatisfied with an accounting process. What wasn’t working? What did you do to improve it': 1,
#  "escribe your experience with executing a complicated financial project on a tight deadline. How did you coordinate your team in collecting and analyzing data? How did you ensure accuracy?']": 1,
#  "['What are your primary responsibilities as an Accounting Clerk": 1,
#  'hat’s the Accounting department’s role in a company': 1,
#  'hich accounting software programs have you used': 2,
#  'alk me through a successful bank reconciliation step-by-step': 1,
#  'ow would you design a spreadsheet to keep track of accounts payable': 1,
#  'ow do you ensure data typing accuracy': 1,
#  'hat suggestions would you make to improve our invoice keeping process': 1,
#  'ow familiar are you with Excel? Mention some projects you worked on and some regular accounting tasks you completed on excel': 1,
#  'hat do you identify as confidential information and how do you secure it': 1,
#  'ive an example of a goal you had in your previous position. What did you do to reach it': 1,
#  'escribe a situation where you had multiple deadlines. How did you handle them': 1,
#  'ave you ever implemented a change to speed up an accounting process': 1,
#  "hat would you like to learn more about?']": 1,
#  "['How does a balance sheet or cash flow statement help you in determining credit risk": 1,
#  'alk me through the process of determining whether we should loan $5 million to a compan': 1,
#  'f an important long-time customer applied for a loan, but after your analysis you found the risk was too high, how would you handle it': 1,
#  'magine one of the company’s salespeople strongly wants to acquire a particular customer, but you’ve found their creditworthiness is lacking. How do you resolve this': 1,
#  'hat’s your quantitative analysis experience': 1,
#  'hat financial software have you used in the past': 1,
#  'hich financial ratios do you use more often? Which is the most important and why': 1,
#  'hat types of customers have you dealt with in the past': 1,
#  'an you explain the meaning of Credit Default Swap (CDS)': 1,
#  'hat’s different with Basel III': 1,
#  'o you like working in a team': 1,
#  'ell me about a time your judgement on a case was proven incorrect. What should you have done differently': 1,
#  'ecall a time you used your communication skills to resolve an issue at wor': 1,
#  "ell me about a time you developed an effective method or model to assess profitability']": 1,
#  "['Talk about your previous work experience as a bookkeeper": 1,
#  'hat have you done recently to become a better bookkeeper': 1,
#  'ow do you stay updated on regulatory changes that impact on your work': 1,
#  'hat sort of financial reports were you responsible for preparing': 1,
#  'hich bookkeeping systems are you familiar with': 1,
#  'ow would you rate your computer skills': 5,
#  's a bookkeeper, how do you avoid errors in your work': 1,
#  'xplain the balance sheet equation': 1,
#  'he ledger is off by $0.80. What process would you use to find the error': 1,
#  'ow would you record an insurance premium using the accrual accounting method versus the cost accounting method': 1,
#  'hat process would you use to prepare and process invoices': 1,
#  'ow have you contributed to cost savings or profits in your department': 1,
#  'ow often did you interact with vendors and clients': 1,
#  'ave you faced any ethical dilemmas in your work? How did you handle it': 1,
#  "ecall a time you worked with your team to complete a complex project under a deadline.']": 1,
#  "['What interests you about working in accounts receivable at a company like ours": 1,
#  'hat training or experience has prepared you for the role of accounts receivable clerk': 1,
#  'n your own words, explain the accounts receivable process': 1,
#  'hat are the most important goals of AR': 1,
#  'hat types of financial statements or reports do you routinely prepare': 1,
#  'hat are the steps you would take to close the AR period': 1,
#  'escribe your familiarity with accounting software. Which ones have you used': 2,
#  'escribe a time you found a billing discrepancy. How did you resolve it': 1,
#  'n as much detail as possible, describe the journal entry process from the time of generating an invoice to receiving payment': 1,
#  'hat is your role, if any, in the collections process': 1,
#  'hat’s the difference between back end collections and front end collections': 1,
#  'hat types of information do you include in a bill for services rendered': 1,
#  "ecall a challenging problem you encountered as an accounts receivable clerk. How did you resolve it?']": 1,
#  "['What interests you about working in accounts payable at a company like ours": 1,
#  'hat training or experience has prepared you for the role of accounts payable clerk': 1,
#  'n as much detail as possible, describe the accounts payable process': 1,
#  'hat differentiates accounts payable from bills payable': 1,
#  'ow would you define a workflow': 1,
#  'rom the bank’s point of view, what is debit and credit? What is it from the customer’s point of view': 1,
#  'his position requires a fair amount of data entry. How do you ensure accuracy in your work': 1,
#  'escribe a time you found an invoice discrepancy. How did you resolve it': 1,
#  'hat types of documents do you need to verify an invoice': 2,
#  'hat steps would you take to make a payment': 1,
#  'hat does it mean when a vendor has \\xa0a debit balance and what would you do in this case': 1,
#  'escribe a time you negotiated vendor terms. How did you handle it': 1,
#  "escribe a time you suggested a way to lower costs, increase revenue, or improve efficiency.']": 1,
#  "['How do you get new business at your current/previous workplace": 1,
#  'ow would you describe your selling style': 1,
#  'hat interests you about the mortgage business': 1,
#  'ow would you learn about our sales culture during your first week on the job': 1,
#  'ow many clients do you have in your portfolio? How many of those did you bring in': 1,
#  'ow would you walk a client through the loan process': 1,
#  'escribe your experience with brokered loans': 1,
#  'hat do you do when you don’t have new prospect appointments scheduled for the day': 1,
#  'ow many prospect appointments did you schedule for this week': 1,
#  'ow would you handle being transferred to the same team as a difficult coworker': 1,
#  'ecall the most difficult sale you’ve ever closed': 1,
#  'ecall a time you had to resolve a problem with an angry client': 1,
#  'ow do you ensure excellent customer service for your clients': 1,
#  "ecall a time you turned a negative situation with a client into a positive one.']": 1,
#  "['Walk me through the process of preparing a budge": 1,
#  'ell me how you go about preparing a forecasting repor': 1,
#  'hen reviewing a funding request, what kind of information do you need': 1,
#  'magine an executive tells you there’s some inconsistency between approved budget and actual expenditure at a department.\\xa0What do you do': 1,
#  'f you had to prepare several budget at the same time, how would you prioritize': 1,
#  'ell me about your experience with cost-benefit analysi': 1,
#  'ow would you rate your data analysis skills, on a scale of 1 to 10': 1,
#  'o you think the job of a budget analyst requires teamwork? Why': 1,
#  'ow do you maintain attention to detail when preparing a budget': 1,
#  'ell me about a time you made a suggestion that resulted in a significant spending cu': 1,
#  'ecall a time you had to defend a budget recommendation to a demanding executive. Was the recommendation approved in the end': 1,
#  'escribe a time when you had to present a budget recommendation to an multi-disciplinary audience. How did you make yourself understood to all of them': 1,
#  'ive me an example of a time you used financial information to solve a proble': 1,
#  "ell me about a time you had a disagreement with a department’s manager over budget']": 1,
#  "['What does a credit mean for the accounting equation": 1,
#  'here and how would you use discounted cash flow (DCF)': 1,
#  'f a manager asked you to help them decide if an investment is a good idea, how would you go about it': 1,
#  'magine you are asked to find a way to reduce a specific cost. Where would you start and how would you make a decision': 1,
#  'hat information do you need for different types of forecasting': 1,
#  'hat would you do if you had to present a report to a non-financial audience': 1,
#  'hat’s your experience with cost-accounting? Financial accounting': 1,
#  'alk about your experience in budgetin': 1,
#  'o you have a specialty area': 1,
#  'ow do you maintain attention to detail': 1,
#  'hat do you do to enhance your knowledge': 1,
#  'ow would you rate your skills in Excel on a scale from 1 to 10': 1,
#  'hat do you know about six sigma': 1,
#  'ive me an example of a time you helped reduce cost': 1,
#  'ell me about a time you played an important role in an important decisio': 1,
#  "ecall a time you prevented senior management from making a bad decision with help from financial data', 'Give me an example of a time you explained financial information to a non-financial perso": 1,
#  'hat project are you most proud of': 1,
#  'ell me about a time you thought of a new process to promote efficienc': 1,
#  "ave you ever faced an ethical dilemma in your job? How did you approach it?']": 1,
#  "['Can you mention three types of special journals": 1,
#  'hat methods have you used to estimate bad debt': 1,
#  'hat is fraud analysis? Can you walk me through the process you’d follow step-by-step': 1,
#  'hat ERP systems have you experience working with': 1,
#  'ow do you track your team’s progress on delegated tasks? Name any tools you use': 1,
#  'hat information and metrics do you need to prepare an annual budget': 1,
#  're you familiar with SFAS (Statement of Financial Accounting Standards)': 1,
#  'ow do you ensure data accuracy and minimum errors in your reports': 1,
#  'ow would you deal with an error in customer payment': 1,
#  'hat resources do you use to stay up-to-date with changes in legislation': 1,
#  'ave you ever implemented any improvements to accounting procedures': 1,
#  'escribe a time when your team managed to achieve ambitious goals you set. What did you do to support them and how did you motivate them': 1,
#  "hat’s the most challenging analysis problem you’ve faced at work?']": 1,
#  "['What’s important to consider when updating a journal entry": 1,
#  'hat steps are needed for bank reconciliation': 1,
#  'ave you used any ERP systems (e.g. Tally) before': 1,
#  'ow do you prepare yourself for a senior accountant position': 1,
#  'hat actions do you take to protect confidential information': 1,
#  'ow do you prioritize your tasks': 1,
#  'hat do you do to avoid mistakes in your job': 1,
#  'f you realized you made a mistake on a report, what would you do': 2,
#  'f a manager pressured you to provide them with information they don’t have permission for, how would you handle it': 1,
#  'ell me about a difficult project you worked on during your studies/internship/etc': 1,
#  'escribe the accounting project you are most proud o': 1,
#  'hat was the most important thing you learned during your internship? What was your most significant contribution': 1,
#  'ave you ever made a mistake due to misunderstanding instructions? What have you learned': 1,
#  "ave you ever been asked to do something that you didn’t agree with? What did you do?']": 1,
#  "['What do you know about our business model": 1,
#  'ow do ensure accuracy in your work': 1,
#  'ow have you handled tight deadlines': 1,
#  'ow do you stay motivated while doing repetitive tasks': 1,
#  'escribe an accounting process that you developed or improved': 1,
#  'escribe a time you helped your company reduce costs': 1,
#  'hare your experience with accounts receivable and accounts payable': 1,
#  "escribe your familiarity with accounting standards such as FASB and GAAP.']": 1,
#  "['You need to retrieve data from a spreadsheet, but there are some formulas you don’t recognize. How would you go about getting what you need": 1,
#  ' coworker asks to see the expense reports of another department. How would you respond': 1,
#  'hat information would you need to compile a report on accounts receivable': 1,
#  'hat would you do if our system broke down while you were in the middle of a transaction? What would you tell a customer who was waiting for the transaction to go through': 1,
#  'hat would you do if your manager gave you inadequate instructions for a process you were unfamiliar with': 1,
#  'escribe your main duties as a Finance Clerk': 1,
#  'hat recordkeeping system do you use to ensure records remain confidential': 1,
#  'escribe the process of a bank reconciliation': 1,
#  'ow do you ensure data entry accuracy': 1,
#  'ow do you prioritize your work when you have multiple duties': 1,
#  'ow do you stay focused when dealing with repetitive tasks': 1,
#  'ow do you learn about new finance regulations and laws': 1,
#  "escribe a time when you had to complete a project under a tight deadline. How did you organize your schedule to make sure you wouldn’t fall behind?']": 1,
#  "['What data would you collect to conduct a benchmark analysis": 1,
#  'he CEO informs you they plan to make an investment (e.g. open a new store in a foreign country.) How would you begin advising them': 1,
#  'hat factors would you take into consideration before advising a company to take (or not take) a loan': 1,
#  'hat metrics would you present to investors to describe the company’s financial health': 1,
#  'escribe the budgeting process step-by-step': 1,
#  'hat financial and statistical analysis software have you used': 1,
#  'hat kinds of reports do you prepare or monitor on a regular basis? How do you use this information': 1,
#  'hat kind of financial model will help you build an annual forecasting report': 1,
#  'hat’s the use of the Weighted Average Cost Of Capital (WACC)? How will an increase in debt affect it': 1,
#  'hat is a good Internal Rate of Return (IRR) on an investment? What formula do you use to calculate it': 1,
#  'escribe a time when you coordinated a challenging financial task, e.g. audits or tax collections': 1,
#  'ive an example of a time when your attention to detail saved you from a making a mistake at work': 1,
#  'ow do you learn about global economic issues? What are the biggest challenges that companies of our industry will face in the next years': 1,
#  "ow would you describe your leadership style? How do you delegate tasks to your team members?']": 1,
#  "['If hired, what are the biggest economic risks you would advise us on": 1,
#  'hat kinds of investments would you recommend to increase our revenues within the next five years': 1,
#  'f you want to prevent a manager from making an investment, how do you ensure they understand the risks': 2,
#  's a positive cash flow enough to tell whether a company is profitable': 1,
#  'e are planning to expand our business with two new stores/offices. What are your main responsibilities in this project': 1,
#  'hat is your client portfolio': 2,
#  'ow often do you evaluate the financial results for a company of our size': 1,
#  'hat information do you use to forecast next year’s financial status? How do you organize your data and how do you present your results': 1,
#  'ow do you check your work for accuracy? (e.g. ensuring correct data entry in large spreadsheets': 2,
#  'hat financial analysis software do you use': 1,
#  'hat metrics do you check when reviewing a department’s budget': 1,
#  'hat are some ground rules you follow in designing investment models, regardless the client’s financial status': 1,
#  'escribe a situation when you undervalued potential risks from an investment. What happened and what did you learn from that experience': 1,
#  'ow do you ensure you’re up-to-date with finance industry developments and regulations? What resources (e.g. newspapers, blogs) do you follow': 1,
#  'escribe a time when your advice to senior managers resulted in higher revenues': 1,
#  'hat’s the most difficult loan/debt problem you’ve faced with a client? How did you address it': 1,
#  "ow would you explain complex financial concepts in simple terms to managers who may not understand industry-speak?']": 1,
#  "['What’s key to a healthy investment": 1,
#  'ow would you explain liquidity risk management to a non-finance person': 1,
#  'hen would you issue a debt and how': 1,
#  'hat information do you need to measure interest rate risk': 1,
#  'hat’s your experience in hedging': 1,
#  'hat cash management software do you prefer and why': 1,
#  'o you pay more attention to direct reports or subordinates': 1,
#  'hat do you do to follow money markets': 1,
#  'escribe a time where your good management allowed your company to save mone': 1,
#  'ell me about a time you coached others towards succes': 1,
#  'ave you ever had trouble enforcing a specific regulation? How did you handle\\xa0it': 1,
#  'escribe a time you spotted a mistake in the company’s cash statement': 1,
#  "xplain how you maintained good relationships with partners and/or\\xa0agencies\\xa0in your previous job']": 1,
#  "['What would you do if revenue forecasts for next year decreased": 1,
#  'f you had to decide whether a possible investment is profitable, how would you do it': 1,
#  'xplain the evolution of the product of your current/previous company. Give me an example of a landmark decision that was made in the product strategy and your opinion of that decisio': 1,
#  'hat type of customer does your company sell to? Has it changed': 1,
#  'hat is a pricing or packaging decision that the company made and what was your view on that decision': 1,
#  'hat was the personality of the company you were just working at and did it fit you': 1,
#  "ive me an example of your investment strategy when funding departments during the annual budget cycle', 'What do you think was key to your current/previous company’s success": 1,
#  'hat are two metrics a CFO should always monitor': 1,
#  'ell me about a time when you faced conflict with stakeholders. How did you resolve it': 1,
#  'ecall a time you showed excellent leadership in managing your departmen': 1,
#  "escribe your most important contribution to your current/previous company']": 1,
#  "['What visual aids would you use to deliver a presentation on a new financial plan to senior managers? Why": 1,
#  'e are planning to open a new store in the next two years. When does your role in this project begin and what do you think are your main responsibilities': 1,
#  'ow would you help employees shift from a “this is how it’s always done” approach to embracing new processes you implement': 1,
#  'hat are the first questions you ask about a new client or project': 1,
#  'alk me through the process of assessing our current financial status': 1,
#  'hat methods/metrics do you use to evaluate a company’s performance': 1,
#  'hat is a cash flow statement? Is this enough to tell whether a company is profitable': 1,
#  'hat financial management software do you have experience working with': 1,
#  'n your opinion, what are the biggest untapped markets and most challenging financial regulations in our industry': 1,
#  'ow do you stay up-to-date with changes to tax and investment regulations': 1,
#  'ell me about a time your advice to senior managers resulted in higher revenues': 1,
#  'escribe a time you used analytical skills to explain the risks of a potential investment': 1,
#  'ave you ever made a bad financial decision? If so, what happened and what did you learn from that experience': 1,
#  "o you prefer giving presentations or preparing written reports? Why?']": 1,
#  "['What are the most important factors to consider in budget development": 1,
#  'hat is the most challenging financial project you’ve ever worked on': 1,
#  'ecall a time you identified a financial opportunity for your company': 1,
#  'ow have you reduced expenses at previous companies': 1,
#  'hat are the financial strengths and weaknesses of our industry': 1,
#  'ow has your leadership contributed to the success of your current/previous team': 1,
#  'ow have you increased revenues in previous companies you’ve worked for': 1,
#  'ecall a time when you improved the quality of financial information or the efficiency of sharing financial information': 1,
#  'hat kinds of reports or presentations have you developed for executive teams': 1,
#  'o you have any experience in setting up accounting/financial reporting controls? If so, please give an example of a control you were able to design and implement': 1,
#  'ecall a time when you introduced new technology to your staff': 1,
#  'hat kind of accounting/financial reporting software are you familiar with': 1,
#  'hat is your approach to hiring financial staff': 1,
#  'ow have you helped junior financial staff advance in their careers': 1,
#  'ecall a time you had to motivate your team to complete a complex project under a tight deadline': 1,
#  'ow do you monitor and evaluate the performance of your team': 1,
#  "ecall a time you had to persuade an executive team to make an important financial decision.']": 1,
#  "['How would you describe your leadership style": 2,
#  'escribe a time you led by example': 2,
#  'hat’s your approach to delegating employees? How do you ensure that tasks are carried out to completion': 2,
#  'escribe someone you coached or mentored. What were they doing initially, and what are they doing now': 2,
#  'ow would you tell a colleague that he/she was underperforming': 1,
#  'alk about the time you led an important meeting': 2,
#  'alk about a successful work project involving multiple teams. What was your role in facilitating the project? What was the result': 2,
#  'ave you ever had to execute a project with a small budget, or a lack of resources? How did you address these issues': 2,
#  'ell me about a time when your team was struggling to meet business goals. What happened? What did you do about it': 1,
#  'alk about a successful work project. What was your goal? What was the result': 2,
#  'hat changes did you make that resulted in increasing productivity, improving efficiency, or lowering costs': 2,
#  'alk us through a typical day at your last position. How do you prioritize your tasks': 2,
#  'hat are some industry trends that have an impact on your role as a manager': 2,
#  "hy are you interested in our company? What is the relationship between this job and your career goals?']": 1,
#  "['What information would you keep in a spreadsheet about incoming mail? (e.g. date, sender, description": 1,
#  'n which cases do you think express delivery is appropriate': 1,
#  'hat would you do if a customer/partner claimed they had sent a package two weeks ago, but you hadn’t received it yet': 1,
#  'hat would you do if you realized you sent a package to the wrong address': 1,
#  'hat resources do you use to check how much a delivery costs': 1,
#  'escribe a regular day at work as a Mail Clerk. What are your main responsibilities': 1,
#  'hat’s the process you follow to send a package to a client? Mention if and how you weigh the package and how you verify the recipient’s address': 1,
#  'escribe how you organize incoming mail. How and when do you distribute mail to appropriate departments or employees': 1,
#  'hat office equipment have you used before': 1,
#  'escribe a time when your attention to detail saved you from making a mistake in the mailroom': 1,
#  'his job can be repetitive. How do you stay motivated': 1,
#  'ow do you prioritize tasks? (e.g. when you have to send packages to multiple clients': 1,
#  "s part of your job, you will have to handle personal data and sensitive information. How will you ensure its confidentiality?']": 1,
#  "['You booked a venue for a company conference, but a day before the event, you learn that there has been a mix-up and it’s not available. What do you do": 1,
#  'hat information would you ask for from new hires in order to update the company’s employee records': 1,
#  'f you have no specific deadlines, how do you prioritize work from different departments': 1,
#  'our manager assigns you with a task you’re not familiar with and doesn’t give you clear instructions. How would you approach this': 1,
#  'hat’s your experience with office equipment? (e.g. printers, scanners and fax machines': 1,
#  'ow do you keep digital and physical records organized and how often do you update them': 2,
#  'ow do you organize your daily workload? Which time management and/or calendar tools do you use, if any': 1,
#  'ow do you create a report on expenditures in Excel': 1,
#  'ow do you check your data-entry work for accuracy': 1,
#  'ave you ever been on a team with a difficult coworker? Tell us about the situation. How did you handle it': 1,
#  'escribe a time you helped complete a project before its due date and under budget': 1,
#  'hat keeps you motivated during repetitive tasks': 1,
#  "uring a project, do you prefer working on a team or individually? Why?']": 1,
#  "['You spot a mistake in a contract that we’ve used for a long time, but bringing it up means our company will have to pay a fine. What would you do": 1,
#  'ow would you search for a 10-year-old contract in a digital database if you didn’t know the file name': 1,
#  'ow would you ensure both digital and physical contracts remain confidential': 1,
#  'ow would you handle a situation where an employee or business partner doesn’t honor a contract agreement with us': 1,
#  'hat’s the best way to organize physical records of contracts': 1,
#  'ow do you file updates to contracts': 1,
#  'ow do you keep track of deadlines (e.g. when each contract needs to be signed and submitted?': 1,
#  'ow do you prioritize your workload when you have many contracts to review': 1,
#  'hat resources do you use when writing terms of use for sales contracts': 1,
#  'ow do you stay up-to-date with legislative changes in this field': 1,
#  'escribe a time when you had to explain complex contract terms to your managers. How did you ensure they complied with all requirements': 1,
#  'hat’s your experience with negotiating contract terms? How do you make sure that the interested parties reach an agreement': 1,
#  'ave you ever missed a deadline? If so, what happened and how did you inform your manager or client': 1,
#  "escribe a time when you had to monitor future expenditures of a contract. How did you do it?']": 1,
#  "['What would you do if you had an urgent question, but couldn’t find anyone online": 1,
#  'hat would you do if you were working under a tight deadline and your computer crashed': 1,
#  'ou need important information from a co-worker who’s in a different time zone and won’t be available for the next four hours. How and when do you choose to communicate your request? Why': 1,
#  'ow would you organize employees’ contact information (e.g. in a spreadsheet) to ensure you have all necessary information in-hand and updated': 1,
#  'ow do you ensure accuracy in routine tasks such as processing expenses and preparing reports': 4,
#  'hat calendar management tools have you used': 1,
#  'hat’s your familiarity with online group communication tools? (e.g. Skype, Hangouts, Slack': 1,
#  'escribe the steps you’d take to plan a meeting for 10 people': 1,
#  'ow do you make sure you find the best deal when booking travel accommodations': 1,
#  'hen you work from home, how do you juggle personal matters (e.g. phone calls or distractions from family members) with getting your work done': 1,
#  'ow do you stay motivated during repetitive tasks': 1,
#  'o you have experience working as part of a distributed team or working remotely? What do you think are its biggest challenges': 1,
#  "ow do you prioritize work when you don’t have specific deadlines?']": 1,
#  "['How would you motivate a team member who seems discouraged or lacks energy": 1,
#  'ow would you mitigate a dispute between two team members who were arguing over their project responsibilities': 1,
#  'f your team members considered a goal unrealistic, how would you change their minds': 1,
#  ' manager from a different department wants to collaborate with a member of your team. How would you handle this request': 1,
#  'wo employees left from your team just before the deadline on a big project. How would you change your leadership style to meet the deadline': 1,
#  'ou learn that one of your top performers is stealing the company’s stationery. How would you handle this situation': 1,
#  'hich performance appraisal systems have you previously used': 1,
#  'ow do you prefer to communicate with your team': 1,
#  'ave you participated in or organized team-building activities? What were they': 1,
#  'ow do you keep track of tasks and goals? Name any productivity tools you’ve used': 1,
#  'o you prefer to provide individual or team-wide feedback? Why? (Or, in which cases do you choose each approach?': 1,
#  'hat’s the most difficult part of your job': 1,
#  'o you have experience laying off an employee? If so, how did you handle the situation': 1,
#  'hat onboarding processes do you use for new team members': 1,
#  "ell me about a time your team successfully completed a challenging project. What did you do to keep employees on track and motivated?']": 1,
#  "hat did you learn about our company in your research? Why do you think you are a strong fit for this role?']": 1,
#  "['If an important decision had to be made, but you couldn’t reach the manager, what would you do": 1,
#  'magine there are too many customers on a particular day and employees are barely managing to attend to all of them. Given that customer service standards are beginning to slip, how would you handle this': 1,
#  'hat would you do if an employee was underperforming': 1,
#  'f you had to attend to customers, the manager and a shipment at the same time, what would you do': 1,
#  'hy does a department need an assistant manager': 1,
#  'hat kind of reports should an assistant manager prepare': 1,
#  'ow do you decide how to delegate responsibilities': 1,
#  'o you mind working with targets': 1,
#  'hat’s your experience with hiring personnel': 2,
#  'hat financial statements do you have experience with': 1,
#  "ecall a time you showed excellent customer service', 'Tell me about a time you had to fire someone. What was the reason and how did you do it": 1,
#  'ave you ever made a mistake as an assistant manager? What happened': 1,
#  'ive me an example of a time you reviewed a process to make it more efficien': 1,
#  'ell me about a time you took the lead over a difficult project and helped the team achieve succes': 1,
#  'escribe a time you had to make a decision without adequate information. How did you do it': 1,
#  "ell me about a time you had a conflict with your supervisor. How did you resolve it?']": 1,
#  "['What are the most common reasons that projects fail": 1,
#  'hen having to monitor different projects, how do you prioritize them': 1,
#  'f you were assigned a program with a 6-month deadline, how would go about planning and delivering outcome': 1,
#  'magine you’re halfway through the completion of a program, when there’s a change in the company’s business strategy or objectives. How would you handle this': 1,
#  'hat does a program manager do that project managers don’t': 1,
#  'hat’s the role of technology in program management': 1,
#  'hich metrics do you use most frequently': 1,
#  'hat’s your experience with program charters': 1,
#  're you familiar with the PMI code of ethics': 1,
#  'hat would you use six sigma for': 1,
#  'hy is change management important for this role': 1,
#  'ow do you avoid scope creep': 1,
#  'ow do you keep up with industry trends': 1,
#  'escribe the most recent program you managed. What was your contribution': 1,
#  'ell me about the biggest challenge you’ve faced while managing a team of project manager': 1,
#  'ow did you measure the success of deliverables in your last program? How did you choose the best metrics': 1,
#  'escribe how you developed a budget and allocated resources for a past progra': 1,
#  'ave you ever had to deal with a program that was falling behind schedule': 1,
#  'ave you ever faced a communication problem while managing a program? Who with and how did you resolve it': 1,
#  "ell me about a time you found it difficult to negotiate with a sponsor/stakeholder. What did you do?']": 1,
#  "['Imagine you have to schedule and plan a conference from start to finish. What things would you consider and what steps would you follow": 1,
#  'hat would you do if an internal client were bothering you with insignificant questions while you had an important task to finish': 1,
#  'ow has your background prepared you for this role': 1,
#  'ow do you think you can contribute to this position': 1,
#  'hat’s your experience with budgeting/bookkeeping': 1,
#  'hat kind of technology tools/software should a program coordinator be familiar with? How proficient are you in using them': 1,
#  'o you have experience in dealing with diversity? How do you increase diversity awareness': 1,
#  'hat’s your experience with fundraising': 1,
#  'ate your skills in creating proposals/presentations on a scale of 1 to 1': 1,
#  'his role involves managing multiple objectives simultaneously. How do you manage your time and prioritize tasks': 1,
#  'ecall a time you made a significant contribution to a progra': 1,
#  'ell me about a time you had a conflict with a co-worker. How did you handle it': 1,
#  "escribe a time you perceived there was a lag in the execution of a program task. What did you do to fix it?']": 1,
#  "['How does your previous experience relate to this job": 1,
# ...
#  "['Using pseudo-code, reverse a String iteratively and recursivel": 2,
#  'mplement the linux whereis command that locates the binary, source, and manual page files for a command': 1,
#  'hat is the difference between list and tuple?\', "What will be the output of the following code?\\nlist = [\'a\', \'b\', \'c\', \'d\', \'e\']print list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]\\n", \'What will be the output of the following code in each step?\\nclass C:  dangerous = 2c1 = C()c2 = C()print c1.dangerous c1.dangerous = 3print c1.dangerous print c2.dangerous del c1.dangerousprint c1.dangerous C.dangerous = 3print c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous \\n\\nc1.dangerous = 3\\nprint c1.dangerous \\nprint c2.dangerous \\n\\ndel c1.dangerous\\nprint c1.dangerous \\n\\nC.dangerous = 3\\nprint c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous \\n\\nc1.dangerous = 3\\nprint c1.dangerous \\nprint c2.dangerous \\n\\ndel c1.dangerous\\nprint c1.dangerous \\n\\nC.dangerous = 3\\nprint c2.dangerous\\n\\n\']': 1,
#  'hen do you think is the best time in a project’s lifecycle, to set up its test infrastructure': 1,
#  'hat do you expect to find in a regression test suite and why': 1,
#  'o arguments in Ruby get passed by reference or by value': 1,
#  'uby MRI uses a Global Interpreter Lock. Does that mean it doesn’t use real threads': 1,
#  'hat do we mean when we say that a lambda or block forms a closure': 1,
#  'hat’s the following program going to print?\\nx = 1class MyClass  y = 2 def foo     z = 4     y ||= 0     puts z + y end  define_method :bar do |x|     z = 5     y ||= 0     puts z + y + x endendmy_class = MyClass.newmy_class.foomy_class.bar(10)my_class.barx = 1\\nclass MyClass\\n  y = 2\\n  def foo\\n     z = 4\\n     y ||= 0\\n     puts z + y\\n  end\\n  define_method :bar do |x|\\n     z = 5\\n     y ||= 0\\n     puts z + y + x\\n  end\\nend\\nmy_class = MyClass.new\\nmy_class.foo\\nmy_class.bar(10)\\nmy_class.barx = 1\\nclass MyClass\\n  y = 2\\n  def foo\\n     z = 4\\n     y ||= 0\\n     puts z + y\\n  end\\n  define_method :bar do |x|\\n     z = 5\\n     y ||= 0\\n     puts z + y + x\\n  end\\nend\\nmy_class = MyClass.new\\nmy_class.foo\\nmy_class.bar(10)\\nmy_class.bar\\': 1,
#  'ow is a block different from a Proc ': 1,
#  'uby 2.1 introduced generational garbage collection. Describe how that works and why it’s considered an improvement': 1,
#  'rite a single line of Ruby code that prints the Fibonacci sequence of any length as an array': 1,
#  "mplement a class macro :benchmark that can be used to print the time an instance method takes to execute (advanced).\\nclass Foo def bar     ... end  def qux     ... end  benchmark :bar, :quxendfoo = Foo.newfoo.bar# => bar took 0.12 msfoo.qux# => qux took 1.15 msclass Foo\\n  def bar\\n     ...\\n  end\\n \\n  def qux\\n     ...\\n  end\\n  benchmark :bar, :qux\\nend\\nfoo = Foo.new\\nfoo.bar\\n# => bar took 0.12 ms\\nfoo.qux\\n# => qux took 1.15 msclass Foo\\n  def bar\\n     ...\\n  end\\n \\n  def qux\\n     ...\\n  end\\n  benchmark :bar, :qux\\nend\\nfoo = Foo.new\\nfoo.bar\\n# => bar took 0.12 ms\\nfoo.qux\\n# => qux took 1.15 ms\\n']": 1,
#  "['What does a Just in Time compiler has to offer? Do you know of any programming language runtimes that use one": 1,
#  'ow is a preemptive threading model different from the cooperative threading model': 1,
#  'hat tools & practices would you consider necessary for a Continuous Delivery solution': 3,
#  'ow is a code point related to a code unit in Unicode': 2,
#  'hat do you think makes a unit test good? What about functional ones': 2,
#  'ow does MSIL (intermediate language) fit into the whole .NET framework architecture': 1,
#  'hat do you mean by polymorphism, inheritance and encapsulation': 1,
#  'hat is the await keyword? Describe a use case and the needed code modifications in order to use it': 1,
#  'ow can lazy initialization be accomplished in .NET': 1,
#  "lease explain the “virtual” keyword', 'Why would you declare a field as volatile": 1,
#  'hat is the Entity Framework and what are the benefits of using it': 1,
#  'hat is Reflection in .NET? Please describe a use case and the benefits of using it': 1,
#  'hat is the dynamic type in .NET? Please describe a use case': 1,
#  'ow are anonymous classes instantiated in .NET? Can they be passed as function params': 1,
#  'n LINQ, what is the difference between the IQueryable and IEnumerable interface': 1,
#  'hat are the benefits of using the Aggregate method in LINQ': 1,
#  's it possible in .NET to extend a class (any class) with some extra methods? If yes, how can it be accomplished': 1,
#  "n .NET, attributes are a method of associating declarative information with C# code. Please describe the way they are used and a proper use case.']": 1,
#  "['What does a Just in Time compiler have to offer? Do you know of any programming language runtimes that use one": 1,
#  'ow is preemptive threading model different from the cooperative threading model': 2,
#  'o arguments in Java get passed by reference or by value': 3,
#  'hy would it be pointless for a static or final method to use dynamic binding': 1,
#  'ow is Java SE related to Java EE': 2,
#  'ow are Runtime exceptions different from Checked exceptions': 3,
#  'hat are the most important features introduced in Java 5, 7 and 8 respectively': 2,
#  's ForkJoinPool introduced in Java 7 always a better alternative to ThreadPoolExecutor': 1,
#  'hat is the difference between HashMap, ConcurrentHashMap and Map returned by Collections.synchronizedMa': 1,
#  'ou want to synchronize 5 threads to start at the same time. Describe a solution': 1,
#  'hat is a weak reference and how could it be useful to us': 1,
#  'hoose a Java EE platform API and give a short description of it': 2,
#  'n a 3-tier application running a Java application server you notice freezes for several seconds during high load. What are the most likely reasons? How would you troubleshoot them': 2,
#  'ervlets 3.0 introduced async support. Describe a use case for it': 3,
#  'hy do you think lambda expressions are considered such a big thing for Java 8': 2,
#  'hat do you know about the Java Scripting API? Can you think of a use case': 1,
#  "s this possible in Java?\\nA extends B, CA extends B, CA extends B, C\\n']": 2,
#  "['How do you know if a linked list has a cycle in it? As in, one of the nodes in the linked list points to a previous node in the list": 2,
#  's Java a statically or dynamically typed language': 2,
#  'hat is the difference between an abstract class and an interface and when would you use one over the other': 2,
#  'hat is a factory pattern and how would you implement the Singleton pattern': 1,
#  'hat is the difference between “==” and equals(…) method? What is the difference between shallow comparison and deep comparison of objects': 2,
#  "['How would you approach unrealistic requests of your team from executives or other teams": 1,
#  'f we wanted to redesign our corporate website, how would you go about gathering user and system requirements': 1,
#  'ell me about an application you regularly use. How would you improve its functionality': 1,
#  'f a developer on your team is underperforming, when and how would you approach them': 1,
#  'ou have an idea you want to try out quickly. What tools would you use to prototype it': 1,
#  'alk me through the process of creating a web page from scratch': 1,
#  'ow do you check other people’s code for bugs': 1,
#  'rovide a basic overview of push technology. What are its benefits and drawbacks': 1,
#  'ow can Page Visibility API be useful': 1,
#  'hat user interface and security principles do you consider when building a website or online application': 1,
#  'escribe a time when your program didn’t run. How did you troubleshoot your code': 1,
#  'as your team ever failed to meet a deadline? What went wrong and how did you address the situation': 1,
#  'ow do you help your team members improve their coding skills? Do you conduct on-the-job coaching or encourage them to attend meetups and conferences': 1,
#  'ow do you handle conflicts on your team': 2,
#  "ow do you stay current with the latest technology developments?']": 1,
#  "['If a very talented Software Engineer on your team kept questioning your decisions, what would you do? How would you address the individual": 1,
#  'hat techniques would you choose to motivate disengaged employees': 1,
#  'ow would you deal with disagreements related to system requirements between senior managers': 1,
#  'hat advice would you give to a new team member? What’s the best way to onboard a new hire': 1,
#  'ow would you negotiate a bigger budget for your team': 1,
#  'ow regularly do you schedule meetings with your team members': 1,
#  'hat metrics do you use to monitor your team’s performance': 1,
#  'hat are the first things you would check in a legacy system that has frequent downtime': 1,
#  'hat are some alternate ways to store data other than a relational database and when would you choose to use them': 1,
#  'hat are the pros and cons of cloud systems': 1,
#  'hat tests do you perform before deployment of a new system or feature': 1,
#  'hat software configuration management tools are you familiar working with': 2,
#  'hat tools and techniques do you use when reviewing someone else’s code? Where do you put most of your focus': 1,
#  'ave you ever identified a potential problem and proactively implemented a software solution': 1,
#  'ow do you stay up-to-date with changes in technology? For example, do you ever attend seminars or contribute to open source software projects': 1,
#  'hat’s your biggest professional success so far? Why': 1,
#  'o you prefer giving team-wide or individual feedback? In which cases do you choose either method': 1,
#  "hat would you help you become a better manager?']": 1,
#  "['An employee is working from home and has trouble joining a video call. How would you help them": 1,
#  'ome employees are complaining about their Internet speed. What steps would you take to identify the problem': 1,
#  'e would like to create simple manuals to help employees to use our equipment properly. What instructions would you give to help your colleagues use a printer': 1,
#  'ow would you deal with a virus': 1,
#  'hat are your responsibilities during network infrastructure implementations': 1,
#  'escribe the data backup and recovery process on a Mac. How is the process different with a PC': 1,
#  'ow do you install and configure a printer in Windows 10': 1,
#  'ow do you determine a server capacity? Why and how often do you need to upgrade a server': 1,
#  'hat are Forests, Trees, and Domains': 1,
#  'ome of your daily tasks can be repetitive. How do you stay motivated': 1,
#  'escribe a time when you used your knowledge of operating systems to optimize a network': 1,
#  'hen you have to juggle different tasks at the same time, how do you prioritize work': 1,
#  'ecall a time when you didn’t know how to solve a problem. What did you do': 1,
#  'n general, when there’s a challenging project, do you like to work with a team or prefer to come up with a solution on your own': 1,
#  "ow do you stay up-to-date with IT developments?']": 2,
#  "['How do you ensure that debugging a program while it’s being used will not affect its functionality": 1,
#  'f you were reviewing somebody else’s code, where would you place most of your focus': 1,
#  'hat features, if any, would you like to add to Java and/or Ruby? Why': 1,
#  'e want to install a new software system. What steps would you take to meet our needs before software deployment? (e.g. research methods': 1,
#  'hen do you use polymorphism and when do you use delegates': 2,
#  'hat are the most effective techniques to prioritize program requirements': 1,
#  'hat are the differences between String, StringBuilder and StringBuffer in Java': 1,
#  're you familiar with cloud systems? What are their pros and cons': 1,
#  'escribe the programming processes at work from the time you type in a website’s URL to when it finishes loading on your screen': 1,
#  'hat is your field of expertise and what would you like to learn more about? Why': 1,
#  'escribe a time when a program you developed didn’t run. How did you troubleshoot your code': 1,
#  'hat’s a fun project that you’ve worked on recently? What was your role in it': 1,
#  'escribe a time when you managed to reduce the user’s perception of waiting. What features did you use': 1,
#  "hat’s your most successful project so far? What was your role? Describe the challenges you faced during this project.']": 1,
#  "['What data would you compile to forecast our company’s growth for next year": 1,
#  'ow would you organize data into spreadsheets to track performance metrics for each department? What kinds of reports would you produce': 1,
#  'hat models would you use to forecast monthly sales revenues based on historical data': 1,
#  'ow would you explain to senior managers how a big data model works, using simple language': 1,
#  'hat database software have you used': 1,
#  'escribe your experience with statistical analysis tools, like SPSS and SAS': 1,
#  'o you have experience creating a data model from scratch? If so, describe the process step-by-step': 1,
#  'ow do you maximize security of confidential data': 1,
#  'hat are the most effective ways to ensure your predictions are accurate using data correlation': 1,
#  'hat is selection bias and how can you avoid it': 1,
#  'hen presenting performance metrics, how do you make sure your audience understands technical terms': 1,
#  'ow do you stay up-to-date with industry trends': 1,
#  'escribe the most challenging database issue you’ve faced so far. How did you handle it': 1,
#  "ell me about a time your findings helped a company identify areas of improvement and/or reduce costs.']": 1,
#  "['What would you check first if many users complained about the website load speed": 1,
#  'f you identified a bug on our contact page and didn’t know how to address it, how would you inform our engineering team about it': 1,
#  'hat would you do if you spotted unusual numbers in Web Analytics? (e.g. significant drops in traffic or conversion rates': 1,
#  'ow would you make our interface more user-friendly': 1,
#  'hat measures would you take to make our site secure? What guidelines would you give to users to minimize their security risks': 1,
#  'hat data do you collect from Google PageSpeed Insights? How do you use this information': 1,
#  're you familiar with keyword research to improve a page’s rankings? What kinds of tools do you use? (e.g. Keyword Planner and Moz': 1,
#  'hat is your role in designing a new web page': 1,
#  'ow do you check if links work and how do you fix broken links': 1,
#  'hat web management tools have you used': 1,
#  'riefly describe the steps to install and configure a web server': 1,
#  'hat do you consider when managing web access rights for different users': 1,
#  'hat topic would you like to learn more about in web development and/or design? How would this knowledge help you as a webmaster': 1,
#  'ell me about a time when your attention to detail helped you quickly identify a website flaw': 1,
#  'hat’s the biggest challenge you’ve faced so far? What was the situation and how did you overcome the obstacles': 1,
#  "escribe a website you recently visited that had a poor design. What did you feel was wrong with it? In your opinion, what features enhance user experience?']": 1,
#  "['Do you contribute to any open source projects": 1,
#  ...}

# %% [markdown]
# In this step we order the dictionary of questions in descending order to check the "most repeated" questions:

# %%
{k: v for k, v in sorted(questions_freq.items(), key=lambda item: item[1],reverse=True)}
# Out:
# {'ow would you rate your computer skills': 5,
#  'ow do you ensure accuracy in routine tasks such as processing expenses and preparing reports': 4,
#  'hat constitutes a good unit test and what a functional one': 4,
#  'hat accounting software have you used': 3,
#  'ow familiar are you with SFAS (Statement of Financial Accounting Standards)': 3,
#  'ow fast can you type': 3,
#  'escribe your experience with calendar management': 3,
#  'hat tools do you use for linting, debugging and profiling': 3,
#  'hat do we mean when we say that a certain Lambda expression forms a closure': 3,
#  'hat tools & practices would you consider necessary for a Continuous Delivery solution': 3,
#  'o arguments in Java get passed by reference or by value': 3,
#  'ow are Runtime exceptions different from Checked exceptions': 3,
#  'ervlets 3.0 introduced async support. Describe a use case for it': 3,
#  'ow do you troubleshoot a crashing application': 3,
#  'hat’s your current occupation/What are you currently working on': 3,
#  'ake us through a couple of your favorite pieces in your portfolio. What was your design process for these pieces? What problems were you trying to solve? How did you make a certain design decision': 3,
#  'o you have a side project you’d like to talk to us about': 3,
#  'ow do you stay updated on the latest tools and trends': 3,
#  'ow do you prioritize tasks': 3,
#  're you comfortable with cold-calling': 3,
#  'ow do you think people discover our brand': 3,
#  'escribe a marketing campaign you worked on that failed. What happened and what did you learn from the experience': 3,
#  'escribe the relationship between content marketing and SEO': 3,
#  'alk about your experience with mobile marketing': 3,
#  'hat CRM software have you used': 3,
#  'hy do customers buy your product? What are the alternatives': 3,
#  'escribe your customers’ buying decision process. Who approves or blocks the buying decision? What do you need to line up to close the sale': 3,
#  'hat was your sales quota': 3,
#  'ow would you set up an internal control system for processing invoices': 2,
#  'hat would you do if you found a mistake in a report you prepared but your manager hadn’t noticed': 2,
#  "his job can be repetitive. What motivates you to do well?']": 2,
#  'hat would you check first if you found a billing discrepancy': 2,
#  'ow do you monitor your team’s performance': 2,
#  'hich accounting software programs have you used': 2,
#  'escribe your familiarity with accounting software. Which ones have you used': 2,
#  'hat types of documents do you need to verify an invoice': 2,
#  'f you realized you made a mistake on a report, what would you do': 2,
#  'f you want to prevent a manager from making an investment, how do you ensure they understand the risks': 2,
#  'hat is your client portfolio': 2,
#  'ow do you check your work for accuracy? (e.g. ensuring correct data entry in large spreadsheets': 2,
#  "['How would you describe your leadership style": 2,
#  'escribe a time you led by example': 2,
#  'hat’s your approach to delegating employees? How do you ensure that tasks are carried out to completion': 2,
#  'escribe someone you coached or mentored. What were they doing initially, and what are they doing now': 2,
#  'alk about the time you led an important meeting': 2,
#  'alk about a successful work project involving multiple teams. What was your role in facilitating the project? What was the result': 2,
#  'ave you ever had to execute a project with a small budget, or a lack of resources? How did you address these issues': 2,
#  'alk about a successful work project. What was your goal? What was the result': 2,
#  'hat changes did you make that resulted in increasing productivity, improving efficiency, or lowering costs': 2,
#  'alk us through a typical day at your last position. How do you prioritize your tasks': 2,
#  'hat are some industry trends that have an impact on your role as a manager': 2,
#  'ow do you keep digital and physical records organized and how often do you update them': 2,
#  'hat’s your experience with hiring personnel': 2,
#  'hat software tools do you use on a daily basis': 2,
#  'escribe a complex project that you worked on with a group. What was the goal, and how did you work with others to accomplish that goal': 2,
#  'hat steps do you take to protect confidential information': 2,
#  'hat software programs do you use on a daily basis': 2,
#  'ow do you handle employee requests for confidential information': 2,
#  'hat tools do you use to stay organized': 2,
#  "['What interests you about working in an administrative position at this company": 2,
#  'hat kinds of administrative projects do you like to work on': 2,
#  'hat administrative projects are less interesting for you? How do you overcome your disinterest in order to do a good job': 2,
#  'hat kinds of documents have you made from scratch using MS Office programs': 2,
#  'hat is your experience with data entry': 2,
#  'f you support multiple people at one company, how do you decide which projects to work on first': 2,
#  'ave you ever been on a team with a difficult coworker? How did you handle it': 2,
#  'escribe a time you worked with a team to meet a common goal. What was your role': 2,
#  'escribe a time you suggested a way to save time, lower costs, or increase revenue': 2,
#  'hat does “managing up” mean to you? In what ways have you done that': 2,
#  "ome of this work can be repetitive. What motivates you to excel in this role?']": 2,
#  'escribe the core principles of a REST API. How is this a different philosophy from RPC': 2,
#  'o arguments in Python get passed by reference or by value': 2,
#  'hy are functions considered first class objects in Python': 2,
#  'ive an example of filter and reduce over an iterable objec': 2,
#  'hat are list and dict comprehensions': 2,
#  's it possible to have a producer thread reading from the network and a consumer thread writing to a file, really work in parallel? What about the GIL': 2,
#  "['Using pseudo-code, reverse a String iteratively and recursivel": 2,
#  'ow is a code point related to a code unit in Unicode': 2,
#  'hat do you think makes a unit test good? What about functional ones': 2,
#  'ow is preemptive threading model different from the cooperative threading model': 2,
#  'ow is Java SE related to Java EE': 2,
#  'hat are the most important features introduced in Java 5, 7 and 8 respectively': 2,
#  'hoose a Java EE platform API and give a short description of it': 2,
#  'n a 3-tier application running a Java application server you notice freezes for several seconds during high load. What are the most likely reasons? How would you troubleshoot them': 2,
#  'hy do you think lambda expressions are considered such a big thing for Java 8': 2,
#  "s this possible in Java?\\nA extends B, CA extends B, CA extends B, C\\n']": 2,
#  "['How do you know if a linked list has a cycle in it? As in, one of the nodes in the linked list points to a previous node in the list": 2,
#  's Java a statically or dynamically typed language': 2,
#  'hat is the difference between an abstract class and an interface and when would you use one over the other': 2,
#  'hat is the difference between “==” and equals(…) method? What is the difference between shallow comparison and deep comparison of objects': 2,
#  'ow do you handle conflicts on your team': 2,
#  'hat software configuration management tools are you familiar working with': 2,
#  "ow do you stay up-to-date with IT developments?']": 2,
#  'hen do you use polymorphism and when do you use delegates': 2,
#  'an you name the differences between object-oriented and component-based design': 2,
#  're you familiar with design patterns? What design software have you used and in what situations': 2,
#  'hat interfaces would you choose to create a user-friendly application': 2,
#  'hat security best practices do you know': 2,
#  "['Talk to us about your studies; tell us about an aspect of your course that you found the most engaging": 2,
#  'o what extent do you “own” the work in your portfolio, and can you be specific about which aspects': 2,
#  'ow do you prototype your ideas? How do you know when you’ve got it right': 2,
#  'ell us how you put yourself in the mind of the user. What kind of research methods do you use when you’re starting a new project': 2,
#  'ell us about a project that didn’t go as planned and the reasons that led to it. How did you solve the problems that arose': 2,
#  'hat is your preferred development environment? (operating system, text editor, version control, preproccessors': 2,
#  'et’s say you start a new project right now – which solution will you choose for adding icons to the interface': 2,
#  'an you describe the difference between progressive enhancement and graceful degradation': 2,
#  'hat existing CSS/Sass frameworks have you used locally, or in production': 2,
#  're you familiar with BEM or SMACSS? What do you like/don’t like about these conventions': 2,
#  'ow do you optimize a website’s assets & reduce page load time': 2,
#  'alk through your design process and some of your decisions': 2,
#  'hat would you do differently if you had more time': 2,
#  "hat would you do differently if you were under a strict deadline and you couldn’t meet the project scope? Which features would you prioritize?']": 2,
#  'ow do you prepare your work for production': 2,
#  'n employee at your company is late for an appointment with a guest who has already arrived. How would you handle this situation': 2,
#  'ow do you stay updated on news and innovations in the field of education': 2,
#  'f I asked you to identify the training needs of the organization, where would you start': 2,
#  'ow do you keep up with news and trends in employee training': 2,
#  'ow do you ensure accuracy in your work': 2,
#  'escribe a time you were given incomplete instructions about a project. What did you do': 2,
#  'o you know how to cook according to special health requirements': 2,
#  'ow do you handle stress': 2,
#  'o you prefer working independently or under supervision': 2,
#  'hat would you do if you knew you were going to be more than an hour late to work': 2,
#  'escribe a time you turned a negative situation with a customer into a positive one': 2,
#  'escribe a time you resolved a problem with an angry customer': 2,
#  'ow has your work experience prepared you for this position': 2,
#  'escribe a time you successfully resolved differences between an employee and upper-level management': 2,
#  'hat’s included in local taxes withholdings': 2,
#  'hat was difficult about sourcing in companies you’ve previously worked for': 2,
#  'ist and describe your favorite tools for tracking and following up with candidates': 2,
#  'ow do you approach interviews? What is your game plan? What are you trying to find out': 2,
#  'alk about a hiring process from a previous company. What worked well? What didn’t work well? What would you change': 2,
#  'ere’s our current time to hire, cost per hire, and success rate. What could we do to improve these? Where would you start': 2,
#  'ow do the company’s HR needs influence strategic planning': 2,
#  'ow much experience do you have as a professional delivery driver': 2,
#  'ow do you feel about a slip-seating setup': 2,
#  'escribe a time you worked with a team to create a campaign on a tight budget': 2,
#  'hat tools do you use to schedule posts': 2,
#  'escribe an integrated marketing campaign you recently worked on. What channels did you use and why': 2,
#  'hat methods would you use to gather customer feedback': 2,
#  'hich do you prefer: creating a report or giving a presentation to explain marketing results? Why': 2,
#  'hat components make up an effective digital campaign': 2,
#  'hat trends are gaining traction in digital marketing': 2,
#  'ow does social media support content marketing': 2,
#  'ow do you keep your team motivated in the face of tight deadlines': 2,
#  'ow do you keep up with the latest creative tools and technologies': 2,
#  'ho are our customers': 2,
#  'ow familiar are you with statistical analysis software? Name any relevant tools you have used before': 2,
#  "hat has been your most significant achievement so far?']": 2,
#  'ow would you present the results of your work': 2,
#  'hat do you know about our products/firm? Why do you want to work here': 2,
#  'ow do you think people discover our content': 2,
#  're you more comfortable communicating by email, phone or in-person? Why': 2,
#  'his role requires frequent travel. Are you willing to travel for work? What is your flexibility': 2,
#  'hat are the most effective engagement techniques you’ve used to manage client relationships': 2,
#  'ave you ever made a decision that cost you a client? What happened and what did you learn from that experience': 2,
#  'ow do you prefer to contact clients, through email or phone? Why': 2,
#  're you familiar with Salesforce.com? What other CRM software have you used': 2,
#  'hat factors, in your opinion, are more likely to close a deal': 2,
#  'hat do you know of our company’s products': 2,
#  'hat was the most successful sale you made in your previous job': 2,
#  'ave you ever implemented a change that resulted in higher sales': 2,
#  'magine a customer told you they’re looking for a gift. Can you walk me through the process of closing a sale': 2,
#  're you familiar with our products? Which one would you most enjoy selling and why': 2,
#  'hat steps would you take to close the store': 2,
#  'hat was the size of your team at your last company': 2,
#  'ow did you generate leads': 2,
#  'hat kinds of questions do you ask your customer to find out what they need': 2,
#  't what point do you stop pursuing a potential customer': 2,
#  "['A debtor has missed six months of payments. When you call the individual, they bring up financial difficulties and get emotional. How do you handle this": 1,
#  'hat payback plan would you recommend for a long-term client whose payments are due to be collected in X months': 1,
#  'f you called a client to update them on their payment status and they were aggressive or rude to you, how would you handle it': 1,
#  'an you think of a few common excuses that debtors make? How would you respond to each of them': 1,
#  'hat collection methods do you know? Which technique do you think would be more effective for our company/clients': 1,
#  'ow do you keep historical data for each account': 1,
#  'ow often do you follow up with delinquent account holders and what’s your approach when you get in touch': 1,
#  'ention three things a Collection Specialist should avoid saying when speaking to a debtor': 1,
#  'ow do you keep track of all payments': 1,
#  'hat software do you use to increase your productivity': 1,
#  'hat do you find interesting about this job': 1,
#  'escribe a time you had to deal with a difficult client. How did you handle the situation': 1,
#  'escribe a time you persuaded a client to pay off a large debt. How did you handle it, from beginning to end': 1,
#  'ave you ever faced an ethical dilemma at work? If so, what was the situation and what did you do': 1,
#  'ave your negotiations with a creditor ever failed? If so, what would you do different': 1,
#  "ow does empathy help you build trusting, long-term relationships? Give an example of a time when you were able to better understand and address a client’s needs.']": 1,
#  "['How would you create a report on debts from the previous quarter": 1,
#  'ow would you contact clients who haven’t paid their bills': 1,
#  'f a long-term client had a debt at the end of the fiscal year, how would you address it with him/her': 1,
#  'ow would you make sure we collect invoices in a timely manner': 1,
#  'ow would you handle an invoice discrepancy with a client': 1,
#  'riefly explain the financial transactions involved in the billing process and your experience with each': 1,
#  'ow do you keep updated records of accounts receivable from clients': 1,
#  'ow do you ensure financial information remains confidential': 1,
#  'hat are your responsibilities during annual audits': 1,
#  'ave you ever made a mistake at work (e.g. a wrong calculation)? How did you figure it out and what happened': 1,
#  'ow do you manage to meet tight deadlines': 1,
#  'ow do you stay up-to-date with new financial regulations? Do you read any specific blogs, magazines or newspapers? If so, what are they': 1,
#  "hat keeps you motivated during repetitive tasks?']": 1,
#  "['What would you do if you received a B-Notice on behalf of your client": 1,
#  'hat information would you use to create a forecasting report for next year’s tax returns': 1,
#  'ou thought the deadline for tax payment submission was in a month, but it’s actually in a week. How would you handle this': 1,
#  'ow would you inform your manager that your company needs to pay a fine because you weren’t aware of a regulatory change': 1,
#  'hat accounting software are you familiar with': 1,
#  'hat monthly and annual reports do you create': 1,
#  'hat information do you need to submit a 1096? What’s different when you e-file a 1099': 1,
#  'hat is an IRS Backup Withholding Notice': 1,
#  'ow do you avoid numerical errors in your reports': 1,
#  'hat attracted you to tax accounting versus other fields, like forensic or auditing': 1,
#  'ow do you stay on top of regulatory changes': 1,
#  'ow do you keep up to date on global economic issues': 1,
#  'escribe a time you saved your client/employer money': 1,
#  "ave you ever faced an ethical dilemma at work? If so, how did you manage it?']": 1,
#  "['What would be the first thing you’d check if you found a billing discrepancy": 1,
#  'ow would you negotiate with a client who has a debt': 1,
#  'hat are the steps you would take to close the accounts receivable period': 1,
#  'hat time management tips would you give to a newly-hired Accounts Receivable Clerk': 1,
#  'hat information would you use to forecast next month’s payments': 1,
#  'hat objectives would you set for your team? (monthly, quarterly and annual goals': 1,
#  'hat accounting software have you used? How do they facilitate your daily tasks': 1,
#  'riefly describe the steps of the journal entry process': 1,
#  'ow often do you conduct bank reconciliation? Why': 1,
#  'hat accounting reports do you create on a regular basis': 1,
#  'hat data do you include in an invoice for services rendered': 1,
#  'ow do you prefer to share the results from your team: with a detailed report or a verbal presentation? Why': 1,
#  'ow do you handle inconsistent payments from clients': 1,
#  'ow do you evaluate employee performance? Tell us about a time you had to deliver a negative review to one of your team members': 1,
#  'ave you ever made a mistake at work that cost you (or your company) money? If so, what was the situation and what did you learn from that experience': 1,
#  'ow do you check your work for accuracy and how do you ensure you meet all deadlines': 1,
#  "ow do you stay up-to-date with changes in finance legislation?']": 1,
#  "['If you could use only Excel, how would you organize the company’s fixed costs to ensure they’re accurate and accessible": 1,
#  'f the CEO asked you to help decide if opening a new branch would be profitable, how would you go about analyzing the situation': 1,
#  'hat information would you need to forecast quarterly and annual costs': 1,
#  ' manager has trouble understanding charts and asks you to explain a report in simple terms. How would you explain a budgeting report to the manager': 1,
#  'e are in front of a business opportunity that involves taking big risks but has large profit margins. What data would you collect and analyze to help us make a decision': 1,
#  'n which cases do you use discounted cash flow (DCF)': 1,
#  'ow do you check data accuracy in large spreadsheets': 1,
#  'hat accounting software have you previously used': 1,
#  'hat invoice processing systems do you know': 1,
#  'ave you ever suggested a way to improve a regular accounting process? What was it': 1,
#  'ow do you stay up-to-date with changes to financial regulations': 1,
#  'ave you ever made a mistake in calculations that resulted in false forecasts? How did you find out about the mistake and what did you do to correct it': 1,
#  'ow do you manage workflow under tight deadlines': 1,
#  "ave you ever discovered a cost-effective solution? If yes, what was it, and how did you present your idea to senior managers?']": 1,
#  "['If you missed the deadline for paying our company’s taxes, what would you do? How would you inform your manager if we had to pay a fine, in this case": 1,
#  'ow would you help a manager decide if an investment was a good idea': 1,
#  'f you had to explain a financial procedure to non-financial audience, how would you ensure they understand all the details? For example, tell us in plain terms about the process of preparing a department’s budget': 1,
#  'hat accounting software have you used? What features increase your productivity': 1,
#  'ow do you check large datasheets for accuracy': 1,
#  'escribe your familiarity with accounting standards such as FASB and GAAP': 1,
#  'hat information and tools do you need to create an annual tax return forecast': 1,
#  'here and how do you use discounted cash flow (DCF)': 1,
#  'hat is your role in the month-end closing process': 1,
#  'escribe a time when you helped your company or a client decrease costs': 1,
#  'ow do you keep up with tax law changes': 1,
#  'ecall a time you analyzed financial risks and prevented senior executives from making a bad investment': 1,
#  'ow do you stay motivated while doing repetitive tasks, like processing invoices': 1,
#  "escribe a time when your attention to detail saved you from making a mistake at work (e.g. in a report.)']": 1,
#  "['What measures would you take if you discovered an invoice discrepancy": 1,
#  'hat goals would you set for your team during your first year? How would you keep track of progress': 1,
#  'hat transactions should Junior Accountants know and how would you train them on more advanced financial topics': 1,
#  'hat accounting software do you use': 1,
#  'ow do you check a report for numerical errors': 1,
#  'hat’s your role during regular tax audits': 1,
#  'hat financial data and metrics do you use to prepare a department’s annual budget': 1,
#  'hat reports and invoices do you gather and manage during the year-end closing': 1,
#  'ow do you stay up-to-date with changes in accounting legislation': 1,
#  'ell us about a time your attention to detail saved you from making a mistake (e.g. in a forecasting report.': 1,
#  'escribe the most challenging financial project you’ve managed so far. How did you overcome difficulties': 1,
#  "escribe a time when you motivated your team to achieve goals. What team management techniques did you use?']": 1,
#  "['What would you do if a client/manager asked you to cover up fraud": 1,
#  'f a high-performer on your team started delivering reports with errors, how would you handle it': 1,
#  'f hired, how would you convince your team members to adjust to your way of working': 1,
#  'f you discovered that a process in our company is not as cost-effective as it could be, how would you present your findings to senior executives': 1,
#  'ave you used any audit software or Computer Assisted Audit Techniques (CAATs?) If so, which ones and how have they helped you': 1,
#  'ow do you check other people’s work for accuracy (e.g. reports or flowcharts?': 1,
#  'ow do periodical internal audits add value to a company': 1,
#  'hat control management processes do you apply to minimize risks': 1,
#  'hat’s your experience with accounting software like Zoho or QuickBooks': 1,
#  'alk me through your fraud detection process': 1,
#  'ave you ever suggested an improvement in the audit process? If so, what was it and why was or wasn’t it finally implemented': 1,
#  'escribe a time when your attention to detail helped you detect a potential law violation': 1,
#  'ow do you keep up with changes in accounting regulations': 1,
#  "ave you ever made a mistake at work? If so, what was it and what did you do to resolve the problem? If not, how do you check your work for accuracy?']": 1,
#  "['Describe your typical day at your current/previous job. How do you prioritize your work": 1,
#  'ow would you rate your proficiency with Microsoft Office programs, especially Excel': 1,
#  'escribe your familiarity with billing and invoice software': 1,
#  'ow many invoices do you handle on a daily basis': 1,
#  'escribe a time you had an invoice discrepancy with a client. How did you resolve it': 1,
#  'xplain the financial transactions involved in the billing process and your experience with each (i.e. classifying, computing, posting, verifying, recording': 1,
#  'ow do you keep track of incoming payments and ensure that it is in compliance with financial procedures? How  do you ensure that they’re properly posted and accounted for': 1,
#  'ow do you ensure the timely collection of invoices': 1,
#  'escribe your most hostile payment collection call. How did you handle it': 1,
#  'escribe a time you went the extra mile to deliver excellent customer service': 1,
#  'escribe a time you worked with a team to complete a project on a tight deadline': 1,
#  's a billing specialist, have you ever faced an ethical dilemma at work? How did you respond': 1,
#  'hat skills do you deem necessary for a billing specialist with our firm. Do you think you possess these skills': 1,
#  "['What data would you present to inform your manager about significant debts from clients": 1,
#  'hat would you say to customers who haven’t paid their bills, if we were close to the end of the fiscal year': 1,
#  'ow would you make sure we collected invoices in a timely manner': 1,
#  'hat would you do if you realized you made a numerical mistake on an invoice right after you issued it': 1,
#  'hat are a Billing Clerk’s tasks when a customer makes a digital order': 1,
#  'ow do you keep track of payments': 1,
#  'ow often do you update the accounts receivable report': 1,
#  'hat is your experience with accounting software? (e.g. QuickBooks': 1,
#  'hat’s the most effective way to keep records of invoices': 1,
#  'hat bookkeeping tasks are you familiar with': 1,
#  'ow do you make sure financial documents remain confidential': 1,
#  'ave you ever had an invoice discrepancy with a client? How did you resolve it': 1,
#  'ell us about a time you had a tight deadline for a project. How did you manage to complete it in time': 1,
#  'his job can be repetitive. What motivates you to perform routine tasks': 1,
#  "ow do you stay up-to-date with new financial regulations?']": 1,
#  "['What data would you collect to forecast next year’s tax returns": 1,
#  'hat would you do if you found significant numerical errors in a tax estimation only after you sent your report to a client': 1,
#  'ow would you check the accuracy of an accountant’s work': 1,
#  'ow would you present in simple terms the tax risks a client would face by making an investment': 1,
#  'hat are the main differences between state and federal taxes': 1,
#  'hat kind of accounting software have you used': 1,
#  'ow do you organize physical records of important paperwork': 1,
#  'ow do you manage foreign affiliate returns': 1,
#  'o you have experience with employee performance? How do you give feedback to your team members': 1,
#  'ave you ever faced an ethical dilemma at work? If so, how did you manage it': 1,
#  'escribe a time you helped a company minimize its tax obligations': 1,
#  'ow do you stay up-to-date with changes in finance law? For example, do you read any job-related forums or magazines': 1,
#  "ow do you manage deadlines when working for different clients at the same time?']": 1,
#  "['What steps do you take in preparing a budget": 1,
#  'escribe your experience with financial forecasting and projections.': 1,
#  'ow do you stay current on accounting and auditing standards': 1,
#  'ow do you keep track of what you’ve delegated to your team': 1,
#  'ow do you go about directing internal and external audits': 1,
#  'hat is your experience presenting financial data to non-financial staff': 1,
#  'escribe a time you persuaded leadership to make a decision based on financial data': 1,
#  'ow do you explain complicated processes to staff members': 1,
#  'escribe a time you were dissatisfied with an accounting process. What wasn’t working? What did you do to improve it': 1,
#  "escribe your experience with executing a complicated financial project on a tight deadline. How did you coordinate your team in collecting and analyzing data? How did you ensure accuracy?']": 1,
#  "['What are your primary responsibilities as an Accounting Clerk": 1,
#  'hat’s the Accounting department’s role in a company': 1,
#  'alk me through a successful bank reconciliation step-by-step': 1,
#  'ow would you design a spreadsheet to keep track of accounts payable': 1,
#  'ow do you ensure data typing accuracy': 1,
#  'hat suggestions would you make to improve our invoice keeping process': 1,
#  'ow familiar are you with Excel? Mention some projects you worked on and some regular accounting tasks you completed on excel': 1,
#  'hat do you identify as confidential information and how do you secure it': 1,
#  'ive an example of a goal you had in your previous position. What did you do to reach it': 1,
#  'escribe a situation where you had multiple deadlines. How did you handle them': 1,
#  'ave you ever implemented a change to speed up an accounting process': 1,
#  "hat would you like to learn more about?']": 1,
#  "['How does a balance sheet or cash flow statement help you in determining credit risk": 1,
#  'alk me through the process of determining whether we should loan $5 million to a compan': 1,
#  'f an important long-time customer applied for a loan, but after your analysis you found the risk was too high, how would you handle it': 1,
#  'magine one of the company’s salespeople strongly wants to acquire a particular customer, but you’ve found their creditworthiness is lacking. How do you resolve this': 1,
#  'hat’s your quantitative analysis experience': 1,
#  'hat financial software have you used in the past': 1,
#  'hich financial ratios do you use more often? Which is the most important and why': 1,
#  'hat types of customers have you dealt with in the past': 1,
#  'an you explain the meaning of Credit Default Swap (CDS)': 1,
#  'hat’s different with Basel III': 1,
#  'o you like working in a team': 1,
#  'ell me about a time your judgement on a case was proven incorrect. What should you have done differently': 1,
#  'ecall a time you used your communication skills to resolve an issue at wor': 1,
#  "ell me about a time you developed an effective method or model to assess profitability']": 1,
#  "['Talk about your previous work experience as a bookkeeper": 1,
#  'hat have you done recently to become a better bookkeeper': 1,
#  'ow do you stay updated on regulatory changes that impact on your work': 1,
#  'hat sort of financial reports were you responsible for preparing': 1,
#  'hich bookkeeping systems are you familiar with': 1,
#  's a bookkeeper, how do you avoid errors in your work': 1,
#  'xplain the balance sheet equation': 1,
#  'he ledger is off by $0.80. What process would you use to find the error': 1,
#  'ow would you record an insurance premium using the accrual accounting method versus the cost accounting method': 1,
#  'hat process would you use to prepare and process invoices': 1,
#  'ow have you contributed to cost savings or profits in your department': 1,
#  'ow often did you interact with vendors and clients': 1,
#  'ave you faced any ethical dilemmas in your work? How did you handle it': 1,
#  "ecall a time you worked with your team to complete a complex project under a deadline.']": 1,
#  "['What interests you about working in accounts receivable at a company like ours": 1,
#  'hat training or experience has prepared you for the role of accounts receivable clerk': 1,
#  'n your own words, explain the accounts receivable process': 1,
#  'hat are the most important goals of AR': 1,
#  'hat types of financial statements or reports do you routinely prepare': 1,
#  'hat are the steps you would take to close the AR period': 1,
#  'escribe a time you found a billing discrepancy. How did you resolve it': 1,
#  'n as much detail as possible, describe the journal entry process from the time of generating an invoice to receiving payment': 1,
#  'hat is your role, if any, in the collections process': 1,
#  'hat’s the difference between back end collections and front end collections': 1,
#  'hat types of information do you include in a bill for services rendered': 1,
#  "ecall a challenging problem you encountered as an accounts receivable clerk. How did you resolve it?']": 1,
#  "['What interests you about working in accounts payable at a company like ours": 1,
#  'hat training or experience has prepared you for the role of accounts payable clerk': 1,
#  'n as much detail as possible, describe the accounts payable process': 1,
#  'hat differentiates accounts payable from bills payable': 1,
#  'ow would you define a workflow': 1,
#  'rom the bank’s point of view, what is debit and credit? What is it from the customer’s point of view': 1,
#  'his position requires a fair amount of data entry. How do you ensure accuracy in your work': 1,
#  'escribe a time you found an invoice discrepancy. How did you resolve it': 1,
#  'hat steps would you take to make a payment': 1,
#  'hat does it mean when a vendor has \\xa0a debit balance and what would you do in this case': 1,
#  'escribe a time you negotiated vendor terms. How did you handle it': 1,
#  "escribe a time you suggested a way to lower costs, increase revenue, or improve efficiency.']": 1,
#  "['How do you get new business at your current/previous workplace": 1,
#  'ow would you describe your selling style': 1,
#  'hat interests you about the mortgage business': 1,
#  'ow would you learn about our sales culture during your first week on the job': 1,
#  'ow many clients do you have in your portfolio? How many of those did you bring in': 1,
#  'ow would you walk a client through the loan process': 1,
#  'escribe your experience with brokered loans': 1,
#  'hat do you do when you don’t have new prospect appointments scheduled for the day': 1,
#  'ow many prospect appointments did you schedule for this week': 1,
#  'ow would you handle being transferred to the same team as a difficult coworker': 1,
#  'ecall the most difficult sale you’ve ever closed': 1,
#  'ecall a time you had to resolve a problem with an angry client': 1,
#  'ow do you ensure excellent customer service for your clients': 1,
#  "ecall a time you turned a negative situation with a client into a positive one.']": 1,
#  "['Walk me through the process of preparing a budge": 1,
#  'ell me how you go about preparing a forecasting repor': 1,
#  'hen reviewing a funding request, what kind of information do you need': 1,
#  'magine an executive tells you there’s some inconsistency between approved budget and actual expenditure at a department.\\xa0What do you do': 1,
#  'f you had to prepare several budget at the same time, how would you prioritize': 1,
#  'ell me about your experience with cost-benefit analysi': 1,
#  'ow would you rate your data analysis skills, on a scale of 1 to 10': 1,
#  'o you think the job of a budget analyst requires teamwork? Why': 1,
#  'ow do you maintain attention to detail when preparing a budget': 1,
#  'ell me about a time you made a suggestion that resulted in a significant spending cu': 1,
#  'ecall a time you had to defend a budget recommendation to a demanding executive. Was the recommendation approved in the end': 1,
#  'escribe a time when you had to present a budget recommendation to an multi-disciplinary audience. How did you make yourself understood to all of them': 1,
#  'ive me an example of a time you used financial information to solve a proble': 1,
#  "ell me about a time you had a disagreement with a department’s manager over budget']": 1,
#  "['What does a credit mean for the accounting equation": 1,
#  'here and how would you use discounted cash flow (DCF)': 1,
#  'f a manager asked you to help them decide if an investment is a good idea, how would you go about it': 1,
#  'magine you are asked to find a way to reduce a specific cost. Where would you start and how would you make a decision': 1,
#  'hat information do you need for different types of forecasting': 1,
#  'hat would you do if you had to present a report to a non-financial audience': 1,
#  'hat’s your experience with cost-accounting? Financial accounting': 1,
#  'alk about your experience in budgetin': 1,
#  'o you have a specialty area': 1,
#  'ow do you maintain attention to detail': 1,
#  'hat do you do to enhance your knowledge': 1,
#  'ow would you rate your skills in Excel on a scale from 1 to 10': 1,
#  'hat do you know about six sigma': 1,
#  'ive me an example of a time you helped reduce cost': 1,
#  'ell me about a time you played an important role in an important decisio': 1,
#  "ecall a time you prevented senior management from making a bad decision with help from financial data', 'Give me an example of a time you explained financial information to a non-financial perso": 1,
#  'hat project are you most proud of': 1,
#  'ell me about a time you thought of a new process to promote efficienc': 1,
#  "ave you ever faced an ethical dilemma in your job? How did you approach it?']": 1,
#  "['Can you mention three types of special journals": 1,
#  'hat methods have you used to estimate bad debt': 1,
#  'hat is fraud analysis? Can you walk me through the process you’d follow step-by-step': 1,
#  'hat ERP systems have you experience working with': 1,
#  'ow do you track your team’s progress on delegated tasks? Name any tools you use': 1,
#  'hat information and metrics do you need to prepare an annual budget': 1,
#  're you familiar with SFAS (Statement of Financial Accounting Standards)': 1,
#  'ow do you ensure data accuracy and minimum errors in your reports': 1,
#  'ow would you deal with an error in customer payment': 1,
#  'hat resources do you use to stay up-to-date with changes in legislation': 1,
#  'ave you ever implemented any improvements to accounting procedures': 1,
#  'escribe a time when your team managed to achieve ambitious goals you set. What did you do to support them and how did you motivate them': 1,
#  "hat’s the most challenging analysis problem you’ve faced at work?']": 1,
#  "['What’s important to consider when updating a journal entry": 1,
#  'hat steps are needed for bank reconciliation': 1,
#  'ave you used any ERP systems (e.g. Tally) before': 1,
#  'ow do you prepare yourself for a senior accountant position': 1,
#  'hat actions do you take to protect confidential information': 1,
#  'ow do you prioritize your tasks': 1,
#  'hat do you do to avoid mistakes in your job': 1,
#  'f a manager pressured you to provide them with information they don’t have permission for, how would you handle it': 1,
#  'ell me about a difficult project you worked on during your studies/internship/etc': 1,
#  'escribe the accounting project you are most proud o': 1,
#  'hat was the most important thing you learned during your internship? What was your most significant contribution': 1,
#  'ave you ever made a mistake due to misunderstanding instructions? What have you learned': 1,
#  "ave you ever been asked to do something that you didn’t agree with? What did you do?']": 1,
#  "['What do you know about our business model": 1,
#  'ow do ensure accuracy in your work': 1,
#  'ow have you handled tight deadlines': 1,
#  'ow do you stay motivated while doing repetitive tasks': 1,
#  'escribe an accounting process that you developed or improved': 1,
#  'escribe a time you helped your company reduce costs': 1,
#  'hare your experience with accounts receivable and accounts payable': 1,
#  "escribe your familiarity with accounting standards such as FASB and GAAP.']": 1,
#  "['You need to retrieve data from a spreadsheet, but there are some formulas you don’t recognize. How would you go about getting what you need": 1,
#  ' coworker asks to see the expense reports of another department. How would you respond': 1,
#  'hat information would you need to compile a report on accounts receivable': 1,
#  'hat would you do if our system broke down while you were in the middle of a transaction? What would you tell a customer who was waiting for the transaction to go through': 1,
#  'hat would you do if your manager gave you inadequate instructions for a process you were unfamiliar with': 1,
#  'escribe your main duties as a Finance Clerk': 1,
#  'hat recordkeeping system do you use to ensure records remain confidential': 1,
#  'escribe the process of a bank reconciliation': 1,
#  'ow do you ensure data entry accuracy': 1,
#  'ow do you prioritize your work when you have multiple duties': 1,
#  'ow do you stay focused when dealing with repetitive tasks': 1,
#  'ow do you learn about new finance regulations and laws': 1,
#  "escribe a time when you had to complete a project under a tight deadline. How did you organize your schedule to make sure you wouldn’t fall behind?']": 1,
#  "['What data would you collect to conduct a benchmark analysis": 1,
#  'he CEO informs you they plan to make an investment (e.g. open a new store in a foreign country.) How would you begin advising them': 1,
#  'hat factors would you take into consideration before advising a company to take (or not take) a loan': 1,
#  'hat metrics would you present to investors to describe the company’s financial health': 1,
#  'escribe the budgeting process step-by-step': 1,
#  'hat financial and statistical analysis software have you used': 1,
#  'hat kinds of reports do you prepare or monitor on a regular basis? How do you use this information': 1,
#  'hat kind of financial model will help you build an annual forecasting report': 1,
#  'hat’s the use of the Weighted Average Cost Of Capital (WACC)? How will an increase in debt affect it': 1,
#  'hat is a good Internal Rate of Return (IRR) on an investment? What formula do you use to calculate it': 1,
#  'escribe a time when you coordinated a challenging financial task, e.g. audits or tax collections': 1,
#  'ive an example of a time when your attention to detail saved you from a making a mistake at work': 1,
#  'ow do you learn about global economic issues? What are the biggest challenges that companies of our industry will face in the next years': 1,
#  "ow would you describe your leadership style? How do you delegate tasks to your team members?']": 1,
#  "['If hired, what are the biggest economic risks you would advise us on": 1,
#  'hat kinds of investments would you recommend to increase our revenues within the next five years': 1,
#  's a positive cash flow enough to tell whether a company is profitable': 1,
#  'e are planning to expand our business with two new stores/offices. What are your main responsibilities in this project': 1,
#  'ow often do you evaluate the financial results for a company of our size': 1,
#  'hat information do you use to forecast next year’s financial status? How do you organize your data and how do you present your results': 1,
#  'hat financial analysis software do you use': 1,
#  'hat metrics do you check when reviewing a department’s budget': 1,
#  'hat are some ground rules you follow in designing investment models, regardless the client’s financial status': 1,
#  'escribe a situation when you undervalued potential risks from an investment. What happened and what did you learn from that experience': 1,
#  'ow do you ensure you’re up-to-date with finance industry developments and regulations? What resources (e.g. newspapers, blogs) do you follow': 1,
#  'escribe a time when your advice to senior managers resulted in higher revenues': 1,
#  'hat’s the most difficult loan/debt problem you’ve faced with a client? How did you address it': 1,
#  "ow would you explain complex financial concepts in simple terms to managers who may not understand industry-speak?']": 1,
#  "['What’s key to a healthy investment": 1,
#  'ow would you explain liquidity risk management to a non-finance person': 1,
#  'hen would you issue a debt and how': 1,
#  'hat information do you need to measure interest rate risk': 1,
#  'hat’s your experience in hedging': 1,
#  'hat cash management software do you prefer and why': 1,
#  'o you pay more attention to direct reports or subordinates': 1,
#  'hat do you do to follow money markets': 1,
#  'escribe a time where your good management allowed your company to save mone': 1,
#  'ell me about a time you coached others towards succes': 1,
#  'ave you ever had trouble enforcing a specific regulation? How did you handle\\xa0it': 1,
#  'escribe a time you spotted a mistake in the company’s cash statement': 1,
#  "xplain how you maintained good relationships with partners and/or\\xa0agencies\\xa0in your previous job']": 1,
#  "['What would you do if revenue forecasts for next year decreased": 1,
#  'f you had to decide whether a possible investment is profitable, how would you do it': 1,
#  'xplain the evolution of the product of your current/previous company. Give me an example of a landmark decision that was made in the product strategy and your opinion of that decisio': 1,
#  'hat type of customer does your company sell to? Has it changed': 1,
#  'hat is a pricing or packaging decision that the company made and what was your view on that decision': 1,
#  'hat was the personality of the company you were just working at and did it fit you': 1,
#  "ive me an example of your investment strategy when funding departments during the annual budget cycle', 'What do you think was key to your current/previous company’s success": 1,
#  'hat are two metrics a CFO should always monitor': 1,
#  'ell me about a time when you faced conflict with stakeholders. How did you resolve it': 1,
#  'ecall a time you showed excellent leadership in managing your departmen': 1,
#  "escribe your most important contribution to your current/previous company']": 1,
#  "['What visual aids would you use to deliver a presentation on a new financial plan to senior managers? Why": 1,
#  'e are planning to open a new store in the next two years. When does your role in this project begin and what do you think are your main responsibilities': 1,
#  'ow would you help employees shift from a “this is how it’s always done” approach to embracing new processes you implement': 1,
#  'hat are the first questions you ask about a new client or project': 1,
#  'alk me through the process of assessing our current financial status': 1,
#  'hat methods/metrics do you use to evaluate a company’s performance': 1,
#  'hat is a cash flow statement? Is this enough to tell whether a company is profitable': 1,
#  'hat financial management software do you have experience working with': 1,
#  'n your opinion, what are the biggest untapped markets and most challenging financial regulations in our industry': 1,
#  'ow do you stay up-to-date with changes to tax and investment regulations': 1,
#  'ell me about a time your advice to senior managers resulted in higher revenues': 1,
#  'escribe a time you used analytical skills to explain the risks of a potential investment': 1,
#  'ave you ever made a bad financial decision? If so, what happened and what did you learn from that experience': 1,
#  "o you prefer giving presentations or preparing written reports? Why?']": 1,
#  "['What are the most important factors to consider in budget development": 1,
#  'hat is the most challenging financial project you’ve ever worked on': 1,
#  'ecall a time you identified a financial opportunity for your company': 1,
#  'ow have you reduced expenses at previous companies': 1,
#  'hat are the financial strengths and weaknesses of our industry': 1,
#  'ow has your leadership contributed to the success of your current/previous team': 1,
#  'ow have you increased revenues in previous companies you’ve worked for': 1,
#  'ecall a time when you improved the quality of financial information or the efficiency of sharing financial information': 1,
#  'hat kinds of reports or presentations have you developed for executive teams': 1,
#  'o you have any experience in setting up accounting/financial reporting controls? If so, please give an example of a control you were able to design and implement': 1,
#  'ecall a time when you introduced new technology to your staff': 1,
#  'hat kind of accounting/financial reporting software are you familiar with': 1,
#  'hat is your approach to hiring financial staff': 1,
#  'ow have you helped junior financial staff advance in their careers': 1,
#  'ecall a time you had to motivate your team to complete a complex project under a tight deadline': 1,
#  'ow do you monitor and evaluate the performance of your team': 1,
# ...
#  'hat is the biggest challenge you have faced in your career? How did you overcome it and what did you learn from it': 1,
#  'ow do you prefer to communicate with your team to assign responsibilities to them?\\xa': 1,
#  'hat’s your biggest challenge when it comes to people management': 1,
#  'ow would others define your communication style? Do you prefer to be close to your employees or maintain a healthy distance, and why': 1,
#  'escribe a time when two team leaders or executives had a conflict. How did you handle the situation': 1,
#  "escribe a time you had to make a tough decision (e.g. budget cuts, organizational restructuring, market withdrawal, etc.). What did you do and what was the result?']": 1,
#  "['If hired, what objectives would you set with your manager for your first year at work": 1,
#  'ow would you approach an employee of your team who was underperforming': 1,
#  'hat would you do if the director needed to be out of office during your first month and left you in charge of organizing a company/department event': 1,
#  'ow would you handle a higher than usual staff turnover': 1,
#  'ow would you create a spreadsheet or database to monitor employee attendance': 1,
#  'ou get a call from an important client, and at the same time, you need to receive an order and submit a presentation to your director. How would you multi-task in this situation': 1,
#  'hat does a typical day at work look like for an Assistant Director': 1,
#  'ow do you prepare and review a department’s annual budget? What information and tools do you need to use': 1,
#  'hat are the most important policies for a company? Why': 1,
#  'hat kinds of reports do you prepare on a regular basis? (e.g. weekly and monthly': 1,
#  'escribe a time when you identified and managed a workplace safety issue': 1,
#  'ell me about a time you had a conflict with your manager. How did you resolve it': 1,
#  'ive me an example of a time you reviewed a process to make it more efficient': 1,
#  'ow do you remain calm when handling various tasks at the same time? How do you make sure you’re not missing any deadlines': 1,
#  "ave you ever faced any complaints about the way you delegated tasks? If so, what were the complaints and how did you handle the situation?']": 1,
#  "['How do you plan your schedule for the day": 1,
#  'escribe your range of responsibilities at your previous position': 1,
#  'hat goals did you set for yourself at your last position? How did you achieve them': 1,
#  'escribe a time you resolved an office conflict. What did you do and why': 1,
#  'escribe what you would classify as an office crisis. How did you deal with it': 1,
#  'ow do you keep track of office resources? (e.g. documents, office supplies': 1,
#  'hat did you do to ensure the security of office records at your last organization': 1,
#  'hat administrative process worked well at your last position? What didn’t work so well': 1,
#  'ow have you ensured the adoption of a new procedure throughout an organization': 1,
#  'hat’s the most challenging thing about being an office manager': 1,
#  'n what ways have you worked with your team to increase productivity': 1,
#  "escribe your approach to conducting training sessions with employees.']": 1,
#  "['Describe a problem/risk you identified before it became urgent. What steps did you take to alleviate the problem": 1,
#  'hen would you prefer Waterfall or Kanban over Scrum and why': 1,
#  'ive an example of a time you removed an impediment': 1,
#  'hat are the pros and cons of the daily stand-up': 1,
#  'hat were your main responsibilities as a Scrum Master in your previous team': 1,
#  'hat agile frameworks are you familiar with': 1,
#  'hat kind of metrics do you use to track the progress of a sprint': 1,
#  'n average, how long were the sprints under your supervision': 1,
#  'hat is your experience in writing reports for your scrum projects': 1,
#  'ave you managed more than one team at a time': 1,
#  'ow do you give feedback to your teammates': 1,
#  'ow would you motivate your team members when they feel discouraged': 1,
#  'hat would you do to integrate a new team member': 1,
#  'escribe the biggest challenge you have faced as a Scrum Master. What did you learn from it': 1,
#  'roduct Manager interview question': 1,
#  'ystem Engineer interview question': 1,
#  "oftware Engineer interview questions']": 1,
#  "['What is part of speech (POS) tagging? What is the simplest approach to building a POS tagger that you can imagine": 1,
#  'ow would you build a POS tagger from scratch given a corpus of annotated sentences? How would you deal with unknown words': 1,
#  'ow would you train a model that identifies whether the word “Apple” in a sentence belongs to the fruit or the company': 1,
#  'ow would you find all the occurrences of quoted text in a news article': 1,
#  'ow would you build a system that auto corrects text that has been generated by a speech recognition system': 1,
#  'hat is latent semantic indexing and where can it be applied': 1,
#  'ow would you build a system to translate English text to Greek and vice-versa': 1,
#  'ow would you build a system that automatically groups news articles by subject': 1,
#  'hat are stop words? Describe an application in which stop words should be removed': 1,
#  'ow would you design a model to predict whether a movie review was positive or negative': 1,
#  'hat is entropy? How would you estimate the entropy of the English language': 1,
#  'hat is a regular grammar? Does this differ in power to a regular expression and if so, in what way': 1,
#  'hat is the TF-IDF score of a word and in what context is this useful': 1,
#  'ow does the PageRank algorithm work': 1,
#  'hat is dependency parsing': 1,
#  'hat are the difficulties in building and using an annotated corpus of text such as the Brown Corpus and what can be done to mitigate them': 1,
#  'hat tools for training NLP models (nltk, Apache OpenNLP, GATE, MALLET etc…) have you used': 1,
#  'o you have any experience in building ontologies': 1,
#  're you familiar with WordNet or other related linguistic resources': 1,
#  "o you speak any foreign languages?',]": 1,
#  "['What type of problem does the model try to solve": 1,
#  's it prone to over-fitting? If so – what can be done about this': 1,
#  'oes the model make any important assumptions about the data? When might these be unrealistic? How do we examine the data to test whether these assumptions are satisfied': 1,
#  'oes the model have convergence problems? Does it have a random component or will the same training data always generate the same model? How do we deal with random effects in training': 1,
#  'hat types of data (numerical, categorical etc…) can the model handle': 1,
#  'an the model handle missing data? What could we do if we find missing fields in our data': 1,
#  'ow interpretable is the model': 1,
#  'hat alternative models might we use for the same type of problem that this one attempts to solve, and how does it compare to those': 1,
#  'an we update the model without retraining it from the beginning': 1,
#  'ow fast is prediction compared to other models? How fast is training compared to other models': 1,
#  'oes the model have any meta-parameters and thus require tuning? How do we do this': 1,
#  'hat is the EM algorithm? Give a couple of application': 1,
#  'hat is deep learning and what are some of the main characteristics that distinguish it from traditional machine learnin': 1,
#  'hat is linear in a generalized linear model': 1,
#  'hat is a probabilistic graphical model? What is the difference between Markov networks and Bayesian networks': 1,
#  'ive an example of an application of non-negative matrix factorizatio': 1,
#  'n what type of ensemble technique is a random forest based? What particular limitation does it try to address': 1,
#  'hat methods for dimensionality reduction do you know and how do they compare with each other': 1,
#  'hat are some good ways for performing feature selection that do not involve exhaustive search': 1,
#  'ow would you evaluate the quality of the clusters that are generated by a run of K-means': 1,
#  'o you have any research experience in machine learning or a related field? Do you have any publications': 1,
#  'hat tools and environments have you used to train and assess models': 1,
#  "o you have experience with Spark ML or another platform for building machine learning models using very large datasets?']": 1,
#  "['Discuss the common pitfalls and risks in planning a data science project such as building a model that predicts whether a bank customer will default on their loan": 1,
#  'hat is the biggest team that you have ever managed and what challenges had you faced': 1,
#  'o you have experience in managing agile teams': 1,
#  ' model your team has built performs 90% accuracy. What do you need to know in order to interpret whether this is good or not': 1,
#  'iscuss a data-driven product that has really impressed you in recent year': 1,
#  'ow do you think one becomes a data scientist? What do you look for when you want someone to join your team': 1,
#  'hat is big data, really? Are you familiar with big data architectures': 1,
#  'ff the top of your head describe a product that uses data from twitter to build something that people could conceivably pay money for': 1,
#  'ow do you stay current in your job and what are the challenges to doing this when you are a data scientis': 1,
#  "ow would you evaluate a feature such as Spotify’s Discover Weekly playlist?']": 1,
#  "['Using pseudo-code, implement binary search of a sorted array of integer": 1,
#  'ame a few differences between Python 2.x and 3.': 1,
#  'ow is memory managed in python?\', "What will be the output of the following code?\\nlist = [\'a\', \'b\', \'c\', \'d\', \'e\']print list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]\\n", \'Python uses a Global Interpreter Lock. Does that mean it doesn’t use real threads': 1,
#  ' palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99. Find the largest palindrome made from the product of two 3-digit numbers': 1,
#  "hat will be the output of the following code in each step?\\nclass C:  dangerous = 2c1 = C()c2 = C()print c1.dangerousc1.dangerous = 3print c1.dangerousprint c2.dangerousdel c1.dangerousprint c1.dangerousC.dangerous = 3print c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous\\n\\nc1.dangerous = 3\\nprint c1.dangerous\\nprint c2.dangerous\\n\\ndel c1.dangerous\\nprint c1.dangerous\\n\\nC.dangerous = 3\\nprint c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous\\n\\nc1.dangerous = 3\\nprint c1.dangerous\\nprint c2.dangerous\\n\\ndel c1.dangerous\\nprint c1.dangerous\\n\\nC.dangerous = 3\\nprint c2.dangerous\\n']": 1,
#  'mplement the linux whereis command that locates the binary, source, and manual page files for a command': 1,
#  'hat is the difference between list and tuple?\', "What will be the output of the following code?\\nlist = [\'a\', \'b\', \'c\', \'d\', \'e\']print list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]list = [\'a\', \'b\', \'c\', \'d\', \'e\']\\nprint list[10:]\\n", \'What will be the output of the following code in each step?\\nclass C:  dangerous = 2c1 = C()c2 = C()print c1.dangerous c1.dangerous = 3print c1.dangerous print c2.dangerous del c1.dangerousprint c1.dangerous C.dangerous = 3print c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous \\n\\nc1.dangerous = 3\\nprint c1.dangerous \\nprint c2.dangerous \\n\\ndel c1.dangerous\\nprint c1.dangerous \\n\\nC.dangerous = 3\\nprint c2.dangerousclass C:\\n  dangerous = 2\\n\\nc1 = C()\\nc2 = C()\\nprint c1.dangerous \\n\\nc1.dangerous = 3\\nprint c1.dangerous \\nprint c2.dangerous \\n\\ndel c1.dangerous\\nprint c1.dangerous \\n\\nC.dangerous = 3\\nprint c2.dangerous\\n\\n\']': 1,
#  'hen do you think is the best time in a project’s lifecycle, to set up its test infrastructure': 1,
#  'hat do you expect to find in a regression test suite and why': 1,
#  'o arguments in Ruby get passed by reference or by value': 1,
#  'uby MRI uses a Global Interpreter Lock. Does that mean it doesn’t use real threads': 1,
#  'hat do we mean when we say that a lambda or block forms a closure': 1,
#  'hat’s the following program going to print?\\nx = 1class MyClass  y = 2 def foo     z = 4     y ||= 0     puts z + y end  define_method :bar do |x|     z = 5     y ||= 0     puts z + y + x endendmy_class = MyClass.newmy_class.foomy_class.bar(10)my_class.barx = 1\\nclass MyClass\\n  y = 2\\n  def foo\\n     z = 4\\n     y ||= 0\\n     puts z + y\\n  end\\n  define_method :bar do |x|\\n     z = 5\\n     y ||= 0\\n     puts z + y + x\\n  end\\nend\\nmy_class = MyClass.new\\nmy_class.foo\\nmy_class.bar(10)\\nmy_class.barx = 1\\nclass MyClass\\n  y = 2\\n  def foo\\n     z = 4\\n     y ||= 0\\n     puts z + y\\n  end\\n  define_method :bar do |x|\\n     z = 5\\n     y ||= 0\\n     puts z + y + x\\n  end\\nend\\nmy_class = MyClass.new\\nmy_class.foo\\nmy_class.bar(10)\\nmy_class.bar\\': 1,
#  'ow is a block different from a Proc ': 1,
#  'uby 2.1 introduced generational garbage collection. Describe how that works and why it’s considered an improvement': 1,
#  'rite a single line of Ruby code that prints the Fibonacci sequence of any length as an array': 1,
#  "mplement a class macro :benchmark that can be used to print the time an instance method takes to execute (advanced).\\nclass Foo def bar     ... end  def qux     ... end  benchmark :bar, :quxendfoo = Foo.newfoo.bar# => bar took 0.12 msfoo.qux# => qux took 1.15 msclass Foo\\n  def bar\\n     ...\\n  end\\n \\n  def qux\\n     ...\\n  end\\n  benchmark :bar, :qux\\nend\\nfoo = Foo.new\\nfoo.bar\\n# => bar took 0.12 ms\\nfoo.qux\\n# => qux took 1.15 msclass Foo\\n  def bar\\n     ...\\n  end\\n \\n  def qux\\n     ...\\n  end\\n  benchmark :bar, :qux\\nend\\nfoo = Foo.new\\nfoo.bar\\n# => bar took 0.12 ms\\nfoo.qux\\n# => qux took 1.15 ms\\n']": 1,
#  "['What does a Just in Time compiler has to offer? Do you know of any programming language runtimes that use one": 1,
#  'ow is a preemptive threading model different from the cooperative threading model': 1,
#  'ow does MSIL (intermediate language) fit into the whole .NET framework architecture': 1,
#  'hat do you mean by polymorphism, inheritance and encapsulation': 1,
#  'hat is the await keyword? Describe a use case and the needed code modifications in order to use it': 1,
#  'ow can lazy initialization be accomplished in .NET': 1,
#  "lease explain the “virtual” keyword', 'Why would you declare a field as volatile": 1,
#  'hat is the Entity Framework and what are the benefits of using it': 1,
#  'hat is Reflection in .NET? Please describe a use case and the benefits of using it': 1,
#  'hat is the dynamic type in .NET? Please describe a use case': 1,
#  'ow are anonymous classes instantiated in .NET? Can they be passed as function params': 1,
#  'n LINQ, what is the difference between the IQueryable and IEnumerable interface': 1,
#  'hat are the benefits of using the Aggregate method in LINQ': 1,
#  's it possible in .NET to extend a class (any class) with some extra methods? If yes, how can it be accomplished': 1,
#  "n .NET, attributes are a method of associating declarative information with C# code. Please describe the way they are used and a proper use case.']": 1,
#  "['What does a Just in Time compiler have to offer? Do you know of any programming language runtimes that use one": 1,
#  'hy would it be pointless for a static or final method to use dynamic binding': 1,
#  's ForkJoinPool introduced in Java 7 always a better alternative to ThreadPoolExecutor': 1,
#  'hat is the difference between HashMap, ConcurrentHashMap and Map returned by Collections.synchronizedMa': 1,
#  'ou want to synchronize 5 threads to start at the same time. Describe a solution': 1,
#  'hat is a weak reference and how could it be useful to us': 1,
#  'hat do you know about the Java Scripting API? Can you think of a use case': 1,
#  ...}

# %%
count=0
repetitions=0
uniques=0
rep=[]
for key,value in questions_freq.items():
    if value>1:
        count+=1
        repetitions+=value
        rep.append(key)
    else:
        uniques+=1
print("There are",count,"questions with at least 2 appearances")
print("There are",uniques,"unique questions")
print("There are a total of ",(uniques+repetitions),"questions appearances")
# Out:
# There are 169 questions with at least 2 appearances
# There are 3972 unique questions
# There are a total of  4342 questions appearances

# %%
count=0
rep=[]
for key,value in questions_freq.items():
        count+=1
        rep.append(key)
print(count)
len(rep)
# Out:
# 4141
# 4141

# %% [markdown]
# ## 2. Feature Engineering

# %% [markdown]
# ### 2.1 Grouping Keywords with job descriptions

# %%
df_keywords = pd.read_csv("keywords.txt")

# %% [markdown]
# Creating random list to check if the code works

# %%
keywords = ['accounting', 'job', 'Job brief','payments','and']
#df_keywords.Keywords.values.tolist() #changing keywords into a list 
print(keywords)
# Out:
# ['accounting', 'job', 'Job brief', 'payments', 'and']

# %%
key_final = df_keywords.stack().tolist()
#key_final

# %%
df["keyword"] = df["job description"].str.findall('|'.join(keywords)).apply(set).str.join(', ')
df.head()
# Out:
#                          title  \
# 0        Collection Specialist
# 1              Billing Analyst
# 2               Tax Accountant
# 3  Accounts Receivable Manager
# 4              Cost Accountant
#
#                                      job description  \
# 0  <h4>Job brief</h4><p>We are looking for a comp...
# 1  <h4>Job brief</h4><p>We are looking for a Bill...
# 2  <h4>Job brief</h4><p>We are looking for a Tax ...
# 3  <h4>Job brief</h4><p>We are looking for an Acc...
# 4  <h4>Job brief</h4><p>We are looking for a Cost...
#
#                                            questions  number_of_questions  \
# 0  [['A debtor has missed six months of payments....                   16
# 1  [['How would you create a report on debts from...                   14
# 2  [['What would you do if you received a B-Notic...                   14
# 3  [['What would be the first thing you’d check i...                   17
# 4  [['If you could use only Excel, how would you ...                   15
#
#                                      keyword
# 0                   and, payments, Job brief
# 1            accounting, and, Job brief, job
# 2  accounting, and, payments, Job brief, job
# 3  accounting, and, payments, Job brief, job
# 4                 accounting, and, Job brief

# %% [markdown]
# Once we have the keywords that match the job description, we create a list out of them for further processing:

# %%
df["keyword"]=df["keyword"].str.split(", ")
df.head()
# Out:
#                          title  \
# 0        Collection Specialist
# 1              Billing Analyst
# 2               Tax Accountant
# 3  Accounts Receivable Manager
# 4              Cost Accountant
#
#                                      job description  \
# 0  <h4>Job brief</h4><p>We are looking for a comp...
# 1  <h4>Job brief</h4><p>We are looking for a Bill...
# 2  <h4>Job brief</h4><p>We are looking for a Tax ...
# 3  <h4>Job brief</h4><p>We are looking for an Acc...
# 4  <h4>Job brief</h4><p>We are looking for a Cost...
#
#                                            questions  number_of_questions  \
# 0  [['A debtor has missed six months of payments....                   16
# 1  [['How would you create a report on debts from...                   14
# 2  [['What would you do if you received a B-Notic...                   14
# 3  [['What would be the first thing you’d check i...                   17
# 4  [['If you could use only Excel, how would you ...                   15
#
#                                        keyword
# 0                   [and, payments, Job brief]
# 1            [accounting, and, Job brief, job]
# 2  [accounting, and, payments, Job brief, job]
# 3  [accounting, and, payments, Job brief, job]
# 4                 [accounting, and, Job brief]

# %% [markdown]
# ### 2.2 Create a counter of keywords per question

# %%
column_list=[]
question_key_count={}
for role in df["questions"]:
    new_dict={}
    for question in role:
        new_dict[question]=0
    column_list.append(new_dict)
#column_list.append(question_key_count)
print(column_list)
print(len(column_list))
# Out:
# [{"['A debtor has missed six months of payments. When you call the individual, they bring up financial difficulties and get emotional. How do you handle this": 0, 'hat payback plan would you recommend for a long-term client whose payments are due to be collected in X months': 0, 'f you called a client to update them on their payment status and they were aggressive or rude to you, how would you handle it': 0, 'an you think of a few common excuses that debtors make? How would you respond to each of them': 0, 'hat collection methods do you know? Which technique do you think would be more effective for our company/clients': 0, 'ow do you keep historical data for each account': 0, 'ow often do you follow up with delinquent account holders and what’s your approach when you get in touch': 0, 'ention three things a Collection Specialist should avoid saying when speaking to a debtor': 0, 'ow do you keep track of all payments': 0, 'hat software do you use to increase your productivity': 0, 'hat do you find interesting about this job': 0, 'escribe a time you had to deal with a difficult client. How did you handle the situation': 0, 'escribe a time you persuaded a client to pay off a large debt. How did you handle it, from beginning to end': 0, 'ave you ever faced an ethical dilemma at work? If so, what was the situation and what did you do': 0, 'ave your negotiations with a creditor ever failed? If so, what would you do different': 0, "ow does empathy help you build trusting, long-term relationships? Give an example of a time when you were able to better understand and address a client’s needs.']": 0}, {"['How would you create a report on debts from the previous quarter": 0, 'ow would you contact clients who haven’t paid their bills': 0, 'f a long-term client had a debt at the end of the fiscal year, how would you address it with him/her': 0, 'ow would you make sure we collect invoices in a timely manner': 0, 'ow would you handle an invoice discrepancy with a client': 0, 'riefly explain the financial transactions involved in the billing process and your experience with each': 0, 'hat accounting software have you used': 0, 'ow do you keep updated records of accounts receivable from clients': 0, 'ow do you ensure financial information remains confidential': 0, 'hat are your responsibilities during annual audits': 0, 'ave you ever made a mistake at work (e.g. a wrong calculation)? How did you figure it out and what happened': 0, 'ow do you manage to meet tight deadlines': 0, 'ow do you stay up-to-date with new financial regulations? Do you read any specific blogs, magazines or newspapers? If so, what are they': 0, "hat keeps you motivated during repetitive tasks?']": 0}, {"['What would you do if you received a B-Notice on behalf of your client": 0, 'hat information would you use to create a forecasting report for next year’s tax returns': 0, 'ou thought the deadline for tax payment submission was in a month, but it’s actually in a week. How would you handle this': 0, 'ow would you inform your manager that your company needs to pay a fine because you weren’t aware of a regulatory change': 0, 'hat accounting software are you familiar with': 0, 'hat monthly and annual reports do you create': 0, 'hat information do you need to submit a 1096? What’s different when you e-file a 1099': 0, 'hat is an IRS Backup Withholding Notice': 0, 'ow do you avoid numerical errors in your reports': 0, 'hat attracted you to tax accounting versus other fields, like forensic or auditing': 0, 'ow do you stay on top of regulatory changes': 0, 'ow do you keep up to date on global economic issues': 0, 'escribe a time you saved your client/employer money': 0, "ave you ever faced an ethical dilemma at work? If so, how did you manage it?']": 0}, {"['What would be the first thing you’d check if you found a billing discrepancy": 0, 'ow would you negotiate with a client who has a debt': 0, 'hat are the steps you would take to close the accounts receivable period': 0, 'hat t ...
# 283

# %%
column_list=[]
question_key_count={}
for role in df["questions"]:
    new_dict={}
    for question in role:
        new_dict[question]=0
    column_list.append(new_dict)

i=0
keyword_count=0
for role_dict in column_list:  
    for question in role_dict.keys():
        for keyword in df["keyword"][i]: 
            if keyword in question:  
                keyword_count+=1
        role_dict[question]=keyword_count
        keyword_count=0
    i+=1
            
print(column_list)
print(len(column_list))
# Out:
# [{"['A debtor has missed six months of payments. When you call the individual, they bring up financial difficulties and get emotional. How do you handle this": 2, 'hat payback plan would you recommend for a long-term client whose payments are due to be collected in X months': 1, 'f you called a client to update them on their payment status and they were aggressive or rude to you, how would you handle it': 1, 'an you think of a few common excuses that debtors make? How would you respond to each of them': 0, 'hat collection methods do you know? Which technique do you think would be more effective for our company/clients': 0, 'ow do you keep historical data for each account': 0, 'ow often do you follow up with delinquent account holders and what’s your approach when you get in touch': 1, 'ention three things a Collection Specialist should avoid saying when speaking to a debtor': 0, 'ow do you keep track of all payments': 1, 'hat software do you use to increase your productivity': 0, 'hat do you find interesting about this job': 0, 'escribe a time you had to deal with a difficult client. How did you handle the situation': 1, 'escribe a time you persuaded a client to pay off a large debt. How did you handle it, from beginning to end': 1, 'ave you ever faced an ethical dilemma at work? If so, what was the situation and what did you do': 1, 'ave your negotiations with a creditor ever failed? If so, what would you do different': 0, "ow does empathy help you build trusting, long-term relationships? Give an example of a time when you were able to better understand and address a client’s needs.']": 1}, {"['How would you create a report on debts from the previous quarter": 0, 'ow would you contact clients who haven’t paid their bills': 0, 'f a long-term client had a debt at the end of the fiscal year, how would you address it with him/her': 0, 'ow would you make sure we collect invoices in a timely manner': 0, 'ow would you handle an invoice discrepancy with a client': 1, 'riefly explain the financial transactions involved in the billing process and your experience with each': 1, 'hat accounting software have you used': 1, 'ow do you keep updated records of accounts receivable from clients': 0, 'ow do you ensure financial information remains confidential': 0, 'hat are your responsibilities during annual audits': 0, 'ave you ever made a mistake at work (e.g. a wrong calculation)? How did you figure it out and what happened': 1, 'ow do you manage to meet tight deadlines': 0, 'ow do you stay up-to-date with new financial regulations? Do you read any specific blogs, magazines or newspapers? If so, what are they': 0, "hat keeps you motivated during repetitive tasks?']": 0}, {"['What would you do if you received a B-Notice on behalf of your client": 0, 'hat information would you use to create a forecasting report for next year’s tax returns': 0, 'ou thought the deadline for tax payment submission was in a month, but it’s actually in a week. How would you handle this': 1, 'ow would you inform your manager that your company needs to pay a fine because you weren’t aware of a regulatory change': 0, 'hat accounting software are you familiar with': 1, 'hat monthly and annual reports do you create': 1, 'hat information do you need to submit a 1096? What’s different when you e-file a 1099': 0, 'hat is an IRS Backup Withholding Notice': 0, 'ow do you avoid numerical errors in your reports': 0, 'hat attracted you to tax accounting versus other fields, like forensic or auditing': 1, 'ow do you stay on top of regulatory changes': 0, 'ow do you keep up to date on global economic issues': 0, 'escribe a time you saved your client/employer money': 0, "ave you ever faced an ethical dilemma at work? If so, how did you manage it?']": 0}, {"['What would be the first thing you’d check if you found a billing discrepancy": 0, 'ow would you negotiate with a client who has a debt': 0, 'hat are the steps you would take to close the accounts receivable period': 0, 'hat t ...
# 283

# %%
df["keywords_per_question"]=column_list
df.head()
# Out:
#                          title  \
# 0        Collection Specialist
# 1              Billing Analyst
# 2               Tax Accountant
# 3  Accounts Receivable Manager
# 4              Cost Accountant
#
#                                      job description  \
# 0  <h4>Job brief</h4><p>We are looking for a comp...
# 1  <h4>Job brief</h4><p>We are looking for a Bill...
# 2  <h4>Job brief</h4><p>We are looking for a Tax ...
# 3  <h4>Job brief</h4><p>We are looking for an Acc...
# 4  <h4>Job brief</h4><p>We are looking for a Cost...
#
#                                            questions  number_of_questions  \
# 0  [['A debtor has missed six months of payments....                   16
# 1  [['How would you create a report on debts from...                   14
# 2  [['What would you do if you received a B-Notic...                   14
# 3  [['What would be the first thing you’d check i...                   17
# 4  [['If you could use only Excel, how would you ...                   15
#
#                                        keyword  \
# 0                   [and, payments, Job brief]
# 1            [accounting, and, Job brief, job]
# 2  [accounting, and, payments, Job brief, job]
# 3  [accounting, and, payments, Job brief, job]
# 4                 [accounting, and, Job brief]
#
#                                keywords_per_question
# 0  {'['A debtor has missed six months of payments...
# 1  {'['How would you create a report on debts fro...
# 2  {'['What would you do if you received a B-Noti...
# 3  {'['What would be the first thing you’d check ...
# 4  {'['If you could use only Excel, how would you...

# %%
df["keywords_per_question"][0]
# Out:
# {"['A debtor has missed six months of payments. When you call the individual, they bring up financial difficulties and get emotional. How do you handle this": 2,
#  'hat payback plan would you recommend for a long-term client whose payments are due to be collected in X months': 1,
#  'f you called a client to update them on their payment status and they were aggressive or rude to you, how would you handle it': 1,
#  'an you think of a few common excuses that debtors make? How would you respond to each of them': 0,
#  'hat collection methods do you know? Which technique do you think would be more effective for our company/clients': 0,
#  'ow do you keep historical data for each account': 0,
#  'ow often do you follow up with delinquent account holders and what’s your approach when you get in touch': 1,
#  'ention three things a Collection Specialist should avoid saying when speaking to a debtor': 0,
#  'ow do you keep track of all payments': 1,
#  'hat software do you use to increase your productivity': 0,
#  'hat do you find interesting about this job': 0,
#  'escribe a time you had to deal with a difficult client. How did you handle the situation': 1,
#  'escribe a time you persuaded a client to pay off a large debt. How did you handle it, from beginning to end': 1,
#  'ave you ever faced an ethical dilemma at work? If so, what was the situation and what did you do': 1,
#  'ave your negotiations with a creditor ever failed? If so, what would you do different': 0,
#  "ow does empathy help you build trusting, long-term relationships? Give an example of a time when you were able to better understand and address a client’s needs.']": 1}

# %%
string_list=["Hello world, my name is JD and I'm running a little test to see what happens","I love playing a basketball match"]
list_of_words=["world", "JD","see","basketball", "rugby", "match"]
word_count=0
words_per_string={}

for string in string_list:
    words_per_string[string]=0
    for word in list_of_words:
        if word in string:
            words_per_string[string]+=1
print(words_per_string)
# Out:
# {"Hello world, my name is JD and I'm running a little test to see what happens": 2, 'I love playing a basketball match': 2}
